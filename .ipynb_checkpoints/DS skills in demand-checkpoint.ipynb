# %% [markdown]
# # * Data Science skills currently in demand *
# <i>Author : Vinitha Palani</i><br>
# <i>Date   : April 7, 2017<i><br>

# %% [markdown]
# ## Table of contents <a id='Table-of-contents'></a>
#
# 1. [Problem Definition](#Problem)
#
# 2. [Required libraries](#Required-libraries)
#
# 3. [Load data](#Load-data)
#
# 4. [Checking the data](#Checking-the-data)
#     - [Peek at your Data](#Peek)
#     - [Dimensions](#Dimensions)
#     - [Datatype of each feature](#Datatype)
#     - [Descriptive Statistics](#Descriptive-stats)
#     - [Class Distribution](#Class-dist)
#     - [Correlation](#Correlation)
#     - [Skew](#Skew)
#     - [Takeaway](#Takeaway1)
#
# 5. [Missing data](#Missing-data)
#
# 6. [Exploratory Data analysis](#EDA)
#     - [Univariate Analysis](#EDA)
#     - [Takeaway](#Takeaway2)
#     - [Multivariate Analysis](#Multivariate)
#     - [Takeaway](#Takeaway3)
#     - [Outliers](#Outliers)
#
# 7. [Feature Engineering](#Feature)
#     - [Add new Features](#Feature)
#     - [Remove Features](#Feature1)
#     - [Apply Transformations](#Feature12)
#     - [Convert catagorical variables](#Feature2)
#     - [Standardize](#Feature3)
#     - [Normalize](#Feature4)
#     - [Make Binary](#Feature5)
#     - [Scale](#Feature6)
#     - [Bin](#Feature7)
#     - [Correlation and Interaction variables](#Feature8)
#     - [Testing](#Feature9)
#     - [Repeat EDA](#Feature10)
#     - [Takeaway](#Feature11)
#
# 8. [Feature Selection](#Feature-Selection)
#
# 9. [Algorithm Evaluation With Resampling Methods](#Resampling)
#
# 10. [Performance metrics](#metrics)
#
# 11. [Spot-check Algorithms](#Spot-check)
#
# 12. [Hyper-parameter Optimisation](#Hyperparameters)
#
# 13. [A single Pipeline](#Pipeline)
#
# 14. [Finalize the model](#Pickle)
#
# 15. [If I had more time..](#time)
#
# 16. [Acknowledgements](#Acknowledgement)

# %% [markdown]
# <a id='Problem'></a>

# %% [markdown]
# # Problem Definition
#
# [[ go back to the top ]](#Table-of-contents)
#
#
# #### What is the problem?
# I would like to find out which Data Science skills are in demand in Atlanta, GA, as of April 2017.
# Which combination of skills appear together? Is there a reason why they appear together, like is there a group of skills that are often required together for the financial sector(or Insurance or Retail) ?
# What are the job titles that are in vogue ?
# Are more jobs offered FULL TIME (as opposed to PART-TIME or CONTRACT) ?
#
# ###### Similar problems
# Jesse Steinweg-Woods https://jessesw.com/Data-Science-Skills/
#
# #### Why does the problem need to be solved?
# This project is primarily undertaken for educational purposes.But I also hope to get some insights into how marketable my resume is given the current job market for data scientists in Atlanta, GA.
#
# #### How would I solve the problem?
# The plan is to scrape the job postings on Dice.com with the title 'Data Scientist' for job-locations within 30 miles  radius of Atlanta(GA) using the python libraries urllib and BeautifulSoup.Then an exploratory analysis has to be done using Pandas and visualisation libraries such as Matplotlib and Seaborn.Clustering techniques are then to be used (using clustering algorithms in Scikit-learn) to find out if there are groups of skills("clusters") that tend to appear together in these job listings.
#
# #### Data Analysis Checklist
#
# <b>Did you specify the type of data analytic question (e.g. exploration, association causality) before touching the data?</b><br>
# Yes, this is an exploratory problem<br>
# <b>Did you define the metric for success before beginning?</b><br>
# Although "success" cannot be quantified this case, the findings can be verified by comparing the results of the analysis with reports of the similar kind published by reliable sources.<br>
# <b>Did you consider whether the question could be answered with the available data?</b><br>
# I am currently scraping the data from just one job site(dice.com), other job sites like Indeed.com and Monster.com have restrictions placed by the site owners(as given in their respective robots.txt files). I am assuming that the postings on Dice.com are representative of all the current job openings for Data Scientists in Atlanta. Also my search is for the title 'Data Scientist' ,I am hoping the dice.com will bring up all the postings pertaining to Data Scientists even though the job-title is not precisely 'Data Scientist'.I also wanted to calculate the mean salary associated with each skill-set but most postings do not have any salary info.<br>

# %% [markdown]
# <a id='#Required-libraries'></a>

# %% [markdown]
# # Required Libraries
#
# [[ go back to the top ]](#Table-of-contents)

# %%
# Python version
import sys
print('Python: {}'.format(sys.version))
# scipy
import scipy
print('scipy: {}'.format(scipy.__version__))
# numpy
import numpy
print('numpy: {}'.format(numpy.__version__))
# matplotlib
import matplotlib
print('matplotlib: {}'.format(matplotlib.__version__))
# pandas
import pandas
print('pandas: {}'.format(pandas.__version__))
# scikit-learn
import sklearn
print('sklearn: {}'.format(sklearn.__version__))
import seaborn 
print('seaborn: {}'.format(seaborn.__version__))
import urllib
import bs4 #this is beautiful soup
# %matplotlib inline
# Out:
# Python: 3.5.2 |Anaconda 4.2.0 (64-bit)| (default, Jul  5 2016, 11:41:13) [MSC v.1900 64 bit (AMD64)]
# scipy: 0.18.1
# numpy: 1.11.3
# matplotlib: 1.5.3
# pandas: 0.18.1
# sklearn: 0.18.1
# seaborn: 0.7.1

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# <a id='#Load-data'></a>

# %% [markdown]
# # Load data
#
# [[ go back to the top ]](#Table-of-contents)

# %%
url = 'https://www.dice.com/jobs?q=Data+Scientist&l=Atlanta%2C+GA&searchid=6830934449416'
source = urllib.request.urlopen(url).read()
# parse html code
bs_tree = bs4.BeautifulSoup(source)
o = open("dicehtml.txt",'w', newline="\r\n")
for line in bs_tree:
    #print(line)
    o.write(str(line))
o.close()
# Out:
# C:\Users\Vini\Anaconda3\lib\site-packages\bs4\__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 184 of the file C:\Users\Vini\Anaconda3\lib\runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "lxml")
#
#   markup_type=markup_type))

# %%
# total number of job listings
job_count_string = bs_tree.find(id = 'posiCountId').contents[0]
print(str(job_count_string))
# Out:
# 1,078

# %%
# convert the string to a number (remove ',')
job_count = ''.join(n for n in str(job_count_string).split(','))
int(job_count)
# Out:
# 1078

# %%
# 30 results per page, 
# so we need to scrape them page after page
num_pages = int(np.ceil(int(job_count)/30.0))
num_pages
# Out:
# 36

# %%
import time
import socket
import requests
def get_tree(url):
    """
    Returns the BeautifulSoup parse tree 
    """
    # using 'requests' instead of urllib coz it takes care of bad url encoding
    try:
        source = requests.get(url)
        source.raise_for_status()
    except requests.exceptions.HTTPError as err:
        print(err)
        return None
    bs_tree = bs4.BeautifulSoup(source.text)
    return bs_tree

def get_job_urls(bs_tree):
    """
    Returns a list of job urls  
    """
    job_urls = []
    job_postings = []
    job_postings = bs_tree.findAll("ul")
    job_postings = [jp.find_all("a",{"class":"dice-btn-link loggedInVisited"}) for jp in job_postings if not jp.get('class') is None 
                  and ''.join(jp.get('class')) == "list-inline"] 
    job_postings = [jp for jp in job_postings if len(jp) is not 0]
    job_urls = [tag[0].get('href') for tag in job_postings]
    return job_urls 

def process_job_urls(job_urls):
    """
    Go to each job url and get the skill-set and employment-type
    """
    job_info = []
    for url in job_urls:
        print("Accessing  : {0} ".format(url))
        bs_tree = get_tree(url)
        if bs_tree is None: 
            print("Error accessing url : ",url)
            return None
        title = bs_tree.find_all("input",{"id":"estJTitle"})[0].get('value')
        skills = bs_tree.find_all("input",{"id":"estSkillText"})[0].get('value')
        emptype = bs_tree.find_all("input",{"id":"taxTermsTextId"})[0].get('value')
        job_info.append(str(title).replace(":",","))
        job_info.append(str(skills).replace(":",","))
        job_info.append(str(emptype).replace(":",","))
        time.sleep(2)
#        print("job_info",job_info)      
    return job_info

def write_csv(job_info):
    """
    Writes the job_info to a csv file  
    """
    for i in range(0,len(job_info),3):
        line = ':'.join(map(str, job_info[i:i+3])) 
        o.write(line)
        o.write("\r")
                   
o = open("job_info.csv",'a') 
o.write(":Title:Skill-set:Type")
o.write("\r")
#for page in range(num_pages):
#After a cursory glance at the search results though the search brings up 36 pages of hits not all of them are relevant 
#especially the ones towards the end ..hence limiting the pagination logic to the first 25 pages 
for page in range(25):
    if page > 1:
        url = "https://www.dice.com/jobs/q-Data_Scientist-l-Atlanta%2C_GA-radius-30-startPage-" + \
           str(page) + "-jobs?searchid=6830934449416"
        print("Accessing Page no.{0} : {1} ".format(page,url))           
        bs_tree = get_tree(url)
        if bs_tree is None:
            print("error fetching page no :",page)
            break;       
    job_urls = get_job_urls(bs_tree)
    job_info = process_job_urls(job_urls)
    write_csv(job_info)
    time.sleep(2)  
o.close()
print("Done!")
# Out:
# Accessing  : https://www.dice.com/jobs/detail/Sr.-Manager%2C-Data-Scientist-%26%2345-BHJOB2052_13161-Visionaire-Partners-Atlanta-GA-30339/10294321/BHJOB2052_13161?icid=sr1-1p&q=Data Scientist&l=Atlanta, GA
# C:\Users\Vini\Anaconda3\lib\site-packages\bs4\__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 184 of the file C:\Users\Vini\Anaconda3\lib\runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "lxml")
#
#   markup_type=markup_type))
# Accessing  : https://www.dice.com/jobs/detail/Data-Scientist-Kforce-Inc.-Atlanta-GA-30339/kforcecx/ITEQG1605365?icid=sr2-1p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Sr.-Manager%2C-Data-Scientist-%26%2345-Personalization-%26%2345-BHJOB2052_13158-Visionaire-Partners-Atlanta-GA-30339/10294321/BHJOB2052_13158?icid=sr3-1p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Data-Scientist-Benvia-Atlanta-GA-30301/10119901/932391?icid=sr4-1p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Data-Scientist-Themesoft-Inc-Atlanta-GA-30301/10123197/sushil_data?icid=sr5-1p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Data-Scientist-Lorhan-Corporation-Atlanta-GA-30301/10440212/941119?icid=sr6-1p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Data-Scientist-INSYS-Group-Alpharetta-GA-30004/insysus/17-00555?icid=sr7-1p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Data-Scientist-Dimensional-Thinking-Atlanta-GA-30328/10226510/1755?icid=sr8-1p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Data-Scientists-Global-Resource-Management%2C-Inc.-Duluth-GA-30026/grmi/1030?icid=sr9-1p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Data-Scientist-Yochana-IT-soultions-Atlanta-GA-30304/10421780/JPC1530-1531?icid=sr10-1p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Data-Scientist-Technosoft-Corporation-Atlanta-GA-30303/tecnos/954179?icid=sr11-1p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/AEM-Consultant%26%2345%26%2345%26%2345-Blue-Prism-Architect%26%2345%26%2345%26%2345Data-Scientist%26%2345%26%2345%26%2345Drools-Developer-%26%2345%26%2345Big-Data-Architect-E%26%2345Solutions%2C-Inc.-Atlanta-GA-30301/10211255/836556?icid=sr12-1p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Data-Scientist%26%2347Sr.-Data-Analyst-%28Tableau%26%2347SQL%29-Matrix-Resources-Atlanta-GA-30301/matrixga/123633?icid=sr13-1p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Information-security-analyst-%26%2347Data-Scientist-Newt-Global-Alpharetta-GA-30005/10119089/897261?icid=sr14-1p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Data-Scientist-%26%2345-GA-Charter-Global%2C-Inc.-Atlanta-GA-30308/chartpro/SE314_DDS_GA?icid=sr15-1p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Data-Engineer-%28Developer%29-INSYS-Group-Alpharetta-GA-30004/insysus/17-00556?icid=sr16-1p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Data-Analyst%26%2345Data-Movement-State-Farm-Insurance-Dunwoody-GA-30338/RTL906969/63959?icid=sr17-1p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Data-Analyst%26%2345DBA-and-DBSA-State-Farm-Insurance-Dunwoody-GA-30338/RTL906969/63958?icid=sr18-1p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Workday-HCM-Data-Conversion%26%2345-Solution-Engineer-%26%2345-USDC-Deloitte-Atlanta-GA-30301/10106525/24048772000005752?icid=sr19-1p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Data-Conversion%26%2345-Solution-Manager-%26%2345-USDC-Deloitte-Atlanta-GA-30301/10106525/24041922000005752?icid=sr20-1p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Sr.-Data-Center-Engineer-Presidio-LLC-Norcross-GA-30092/10115295/4772?icid=sr21-1p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Senior-.NET-Technical-Lead%26%2347Manager-%26%2345-Data-Focus-NICE-Systems-Atlanta-GA-30301/10115980/8508?icid=sr22-1p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Sr-Big-Data-Architect-Prosoft-Technologies-Inc-Lawrenceville-GA-30044/10520127/ARBDA?icid=sr23-1p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Big-Data-Platform-Engineer-Verizon-Alpharetta-GA-30004/10241294/452046-1C?icid=sr24-1p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Data-Mapper-CGI-Atlanta-GA-30301/cgiamsbot/J1216-0481?icid=sr25-1p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Big-Data-Engineer-Travelport-Atlanta-GA-30301/90719168/4012BR?icid=sr26-1p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Oracle-eBusiness-Suite-Product-Data-Hub-Lead-Identity-and-Access-Solutions-Atlanta-GA-30304/90989382/PIM002?icid=sr27-1p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Data-Architect------Atlanta%2C-GA----Maddy-J-Paramount-Software-Solutions%2C-Inc-Atlanta-GA-30303/10452799/928568?icid=sr28-1p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Data-Quality-Specialist-Steele-Tech-Partners-LLC-Atlanta-GA-30328/90941053/589548?icid=sr29-1p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Data-Analyst-Steele-Tech-Partners-LLC-Atlanta-GA-30328/90941053/589531?icid=sr30-1p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Sr.-Manager%2C-Data-Scientist-%26%2345-BHJOB2052_13161-Visionaire-Partners-Atlanta-GA-30339/10294321/BHJOB2052_13161?icid=sr1-1p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Data-Scientist-Kforce-Inc.-Atlanta-GA-30339/kforcecx/ITEQG1605365?icid=sr2-1p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Sr.-Manager%2C-Data-Scientist-%26%2345-Personalization-%26%2345-BHJOB2052_13158-Visionaire-Partners-Atlanta-GA-30339/10294321/BHJOB2052_13158?icid=sr3-1p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Data-Scientist-Benvia-Atlanta-GA-30301/10119901/932391?icid=sr4-1p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Data-Scientist-Themesoft-Inc-Atlanta-GA-30301/10123197/sushil_data?icid=sr5-1p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Data-Scientist-Lorhan-Corporation-Atlanta-GA-30301/10440212/941119?icid=sr6-1p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Data-Scientist-INSYS-Group-Alpharetta-GA-30004/insysus/17-00555?icid=sr7-1p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Data-Scientist-Dimensional-Thinking-Atlanta-GA-30328/10226510/1755?icid=sr8-1p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Data-Scientists-Global-Resource-Management%2C-Inc.-Duluth-GA-30026/grmi/1030?icid=sr9-1p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Data-Scientist-Yochana-IT-soultions-Atlanta-GA-30304/10421780/JPC1530-1531?icid=sr10-1p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Data-Scientist-Technosoft-Corporation-Atlanta-GA-30303/tecnos/954179?icid=sr11-1p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/AEM-Consultant%26%2345%26%2345%26%2345-Blue-Prism-Architect%26%2345%26%2345%26%2345Data-Scientist%26%2345%26%2345%26%2345Drools-Developer-%26%2345%26%2345Big-Data-Architect-E%26%2345Solutions%2C-Inc.-Atlanta-GA-30301/10211255/836556?icid=sr12-1p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Data-Scientist%26%2347Sr.-Data-Analyst-%28Tableau%26%2347SQL%29-Matrix-Resources-Atlanta-GA-30301/matrixga/123633?icid=sr13-1p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Information-security-analyst-%26%2347Data-Scientist-Newt-Global-Alpharetta-GA-30005/10119089/897261?icid=sr14-1p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Data-Scientist-%26%2345-GA-Charter-Global%2C-Inc.-Atlanta-GA-30308/chartpro/SE314_DDS_GA?icid=sr15-1p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Data-Engineer-%28Developer%29-INSYS-Group-Alpharetta-GA-30004/insysus/17-00556?icid=sr16-1p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Data-Analyst%26%2345Data-Movement-State-Farm-Insurance-Dunwoody-GA-30338/RTL906969/63959?icid=sr17-1p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Data-Analyst%26%2345DBA-and-DBSA-State-Farm-Insurance-Dunwoody-GA-30338/RTL906969/63958?icid=sr18-1p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Workday-HCM-Data-Conversion%26%2345-Solution-Engineer-%26%2345-USDC-Deloitte-Atlanta-GA-30301/10106525/24048772000005752?icid=sr19-1p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Data-Conversion%26%2345-Solution-Manager-%26%2345-USDC-Deloitte-Atlanta-GA-30301/10106525/24041922000005752?icid=sr20-1p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Sr.-Data-Center-Engineer-Presidio-LLC-Norcross-GA-30092/10115295/4772?icid=sr21-1p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Senior-.NET-Technical-Lead%26%2347Manager-%26%2345-Data-Focus-NICE-Systems-Atlanta-GA-30301/10115980/8508?icid=sr22-1p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Sr-Big-Data-Architect-Prosoft-Technologies-Inc-Lawrenceville-GA-30044/10520127/ARBDA?icid=sr23-1p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Big-Data-Platform-Engineer-Verizon-Alpharetta-GA-30004/10241294/452046-1C?icid=sr24-1p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Data-Mapper-CGI-Atlanta-GA-30301/cgiamsbot/J1216-0481?icid=sr25-1p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Big-Data-Engineer-Travelport-Atlanta-GA-30301/90719168/4012BR?icid=sr26-1p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Oracle-eBusiness-Suite-Product-Data-Hub-Lead-Identity-and-Access-Solutions-Atlanta-GA-30304/90989382/PIM002?icid=sr27-1p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Data-Architect------Atlanta%2C-GA----Maddy-J-Paramount-Software-Solutions%2C-Inc-Atlanta-GA-30303/10452799/928568?icid=sr28-1p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Data-Quality-Specialist-Steele-Tech-Partners-LLC-Atlanta-GA-30328/90941053/589548?icid=sr29-1p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Data-Analyst-Steele-Tech-Partners-LLC-Atlanta-GA-30328/90941053/589531?icid=sr30-1p&q=Data Scientist&l=Atlanta, GA
# Accessing Page no.2 : https://www.dice.com/jobs/q-Data_Scientist-l-Atlanta%2C_GA-radius-30-startPage-2-jobs?searchid=6830934449416
# Accessing  : https://www.dice.com/jobs/detail/Data-Architect-Kforce-Inc.-Atlanta-GA-30326/kforcecx/ITEQG1618242?icid=sr31-2p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Data-Solutions-Engineer-eHire-Atlanta-GA-30328/10380692/BHJOB10147_3679?icid=sr32-2p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Data-Architect-Principle-Solutions-Group-Atlanta-GA-30328/10124296/950186?icid=sr33-2p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/MDM-%26%2345-Data-Architect-Staples-Alpharetta-GA-30004/90942229/730426?icid=sr34-2p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Predictive-Data-Analyst-3Ci-Atlanta-GA-30301/comga001/17232CLH?icid=sr35-2p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Data-Architect-Synergis-Kennesaw-GA-30144/SYNERGIS/CC14305?icid=sr36-2p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Solution-Architect-%28Big-Data%29-Halo-Group-Johns-Creek-GA-30097/10204244/5912?icid=sr37-2p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Enterprise-Data-Architect-Innovative-IT-Solutions-Inc-Atlanta-GA-30313/10451163/942146?icid=sr38-2p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Senior-Enterprise-Data-Architect-JLA-Atlanta-GA-30301/90796024/943400?icid=sr39-2p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Cloud%26%2347Big-Data-Technical-Architect-TekShapers-Atlanta-GA-30302/10335759/936154?icid=sr40-2p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Google-Cloud%26%2347Big-Data-Technical-Architect-TekShapers-Atlanta-GA-30301/10335759/935873?icid=sr41-2p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Big-Data-Architect-Professional-Insight-Atlanta-GA-30309/10271870/939723?icid=sr42-2p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Data-Center-Network-Architect-Bradsby-Group-Roswell-GA-30075/10112074/915089?icid=sr43-2p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Senior-Data--Modeler%26%2347Analyst-Techgene-Solutions-LLC-Atlanta-GA-30301/10109301/SRDAMOATGA?icid=sr44-2p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Data-Architect-The-Judge-Group-Atlanta-GA-30301/cxjudgpa/525373?icid=sr45-2p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Data-Analyst-%28Reporting%29-%26%2345-BHJOB2052_13142-Visionaire-Partners-Smyrna-GA-30080/10294321/BHJOB2052_13142?icid=sr46-2p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Cisco-Network-Data-Engineer-%26%2345-BHJOB2052_13153-Visionaire-Partners-Norcross-GA-30071/10294321/BHJOB2052_13153?icid=sr47-2p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Cisco-Data-Center-Network-Engineer-iStaff-Roswell-GA-30075/ISTAFFGA/DY-123?icid=sr48-2p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Sr.-Cisco-Network-Data-Engineer-%26%2345-BHJOB2052_13154-Visionaire-Partners-Norcross-GA-30071/10294321/BHJOB2052_13154?icid=sr49-2p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Jr.-IT-Data-Analyst-SNI-Companies-dba-SNI-Technology-Atlanta-GA-30301/snibot/J3J81F603FV1HM2R73W?icid=sr50-2p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Fraud-Control-Manager-%28Data-Analysis%29-%26%2345-BHJOB2052_13156-Visionaire-Partners-Smyrna-GA-30080/10294321/BHJOB2052_13156?icid=sr51-2p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Linux-System-Data-Center-Design-Engineer-ESG-Consulting-Atlanta-GA-30305/esgcx/922599?icid=sr52-2p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Senior-Data-Security-Analyst-PENTESTER-Merlin-International-Atlanta-GA-30333/merco001/949456?icid=sr53-2p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Hadoop-Design-Lead%26%2347Data-Modeler-Pegasys-Systems-%26-Technologies-Inc-Atlanta-GA-30301/10207951/916735?icid=sr54-2p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Data-Analyst-Lead-Kavaliro-Atlanta-GA-30334/10411514/951167?icid=sr55-2p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Data-Security-Specialist-Data-Resource-Technologies-Marietta-GA-30067/10124769/SASE-GA-JM?icid=sr56-2p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Data-Security-Engineer-Matlen-Silver-Atlanta-GA-30301/MATLENGA/637435?icid=sr57-2p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Technical-Data-Management-Analyst-Principle-Solutions-Group-Atlanta-GA-30328/10124296/949865?icid=sr58-2p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Data-Architect-The-Judge-Group-Atlanta-GA-30301/cxjudgpa/524605?icid=sr59-2p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Data-Analyst-iStaff-Atlanta-GA-30346/ISTAFFGA/165341?icid=sr60-2p&q=Data Scientist&l=Atlanta, GA
# Accessing Page no.3 : https://www.dice.com/jobs/q-Data_Scientist-l-Atlanta%2C_GA-radius-30-startPage-3-jobs?searchid=6830934449416
# Accessing  : https://www.dice.com/jobs/detail/Big-Data-Application-Architect-Saven-Technologies-Alpharetta-GA-30004/10106519/949307?icid=sr61-3p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Revenue-Data-Analyst-The-Judge-Group-Hapeville-GA-30354/cxjudgpa/519866?icid=sr62-3p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Machine-Learning-%26%2347-Big-Data-Expert-VDart%2C-Inc.-Atlanta-GA-30301/10330808/A13C10J592?icid=sr63-3p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Data-Architect-EDI-Staffing-Atlanta-GA-30309/10107595/17-00197?icid=sr64-3p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Big-Data-Architect-Hexaware-Technologies%2C-Inc-Alpharetta-GA-30022/hexaware/HBAGX?icid=sr65-3p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Data-Center-Busines-Analyst-Kavi-Software-Atlanta-GA-30354/10119154/DCBA0001?icid=sr66-3p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Big-Data-Architect-Apidel-Technologies-Alpharetta-GA-30005/10509960/314_SR3?icid=sr67-3p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Big-Data-Architect-HMG-America-Alpharetta-GA-30004/10481867/951540?icid=sr68-3p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Senior-Data-Analyst-I-Kforce-Inc.-Atlanta-GA-30354/kforcecx/ITEQG1618664?icid=sr69-3p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Big-Data-Architect-Saven-Technologies-Alpharetta-GA-30004/10106519/936505?icid=sr70-3p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Big-Data%26%2347Java-Product-Architect-The-Coddington-Group%2C-LLC-Atlanta-GA-30303/10115337/3266?icid=sr71-3p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Dialysis-Data-Analyst-TEKsystems%2C-Inc.-Atlanta-GA-30303/10105424/5965434-614?icid=sr72-3p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Data-Reporting-Analyst-Agile-Atlanta-GA-30303/10112507/BBBH9633-224?icid=sr73-3p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Data-Center-Network-Architect-DCM-Data-Systems-Atlanta-GA-30301/10109811/947162?icid=sr74-3p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Sr-Business-Analyst%26%2345-Data-Center-Mindlance-Atlanta-GA-30354/10114908/D00104?icid=sr75-3p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Data-Analyst-Lead-%26%2345-Monitoring-Tools-Resource-BizTech-Solutions-Inc-Atlanta-GA-30302/10110076/953584?icid=sr76-3p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/ArcGIS-Data-manager-System-Soft-Technologies-Atlanta-GA-30308/10118461/SS_SS_AT_0321?icid=sr77-3p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Teradata-BTEQ-Data-Warehouse-Specialist-Dean-%26-Edwards-Atlanta-GA-30305/10267878/880688?icid=sr78-3p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Enterprise-Data-Architect-SolTech%2C-Inc-Atlanta-GA-30309/10107031/2017-1946?icid=sr79-3p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Business-Data-Analyst-Synergis-Atlanta-GA-30346/SYNERGIS/SH14282?icid=sr80-3p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Big-Data-Architect-IDC-Technologies-Atlanta-GA-30303/10114879/917381?icid=sr81-3p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Data-Analyst-Kforce-Inc.-Norcross-GA-30071/kforcecx/ITEQG1618588?icid=sr82-3p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/IBM-Data-power-consultant-Bitwise-Atlanta-GA-30301/bitwise/SM04?icid=sr83-3p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Data-Specialist%28ETL.Ab-Initio%29-HALLMARK-GLOBAL-TECHNOLOGIES-INC-Atlanta-GA-30303/10116544/946219?icid=sr84-3p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Big-Data-Architect-Softnice-Inc-Alpharetta-GA-30005/10212463/BigData_C2CGA?icid=sr85-3p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Data-Center-Architect-Apex-Systems%2C-Inc-Atlanta-GA-30301/apexsan/945919?icid=sr86-3p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Data-Center-Network-Architect-Bradsby-Group-Atlanta-GA-30303/10112074/945856?icid=sr87-3p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Data-Center-Network-Architect-Bradsby-Group-Atlanta-GA-30303/10112074/945848?icid=sr88-3p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Software-Product-Development-Manager-%28Big-Data%29-The-Coddington-Group%2C-LLC-Atlanta-GA-30303/10115337/119782?icid=sr89-3p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Sr-Analyst-Data-%26-Analytics-Ca-3Ci-Atlanta-GA-30301/comga001/17208CLH?icid=sr90-3p&q=Data Scientist&l=Atlanta, GA
# Accessing Page no.4 : https://www.dice.com/jobs/q-Data_Scientist-l-Atlanta%2C_GA-radius-30-startPage-4-jobs?searchid=6830934449416
# Accessing  : https://www.dice.com/jobs/detail/MS-Access-Developer-%26-Data-Analyst-Genesis10-Norcross-GA-30003/gentx001/17-02355?icid=sr91-4p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Business-Claims-Analyst%26%2345-CMS-Encounter-Data-Processing-System%2C-U.S.-Only-Hire-Technologies%2C-Inc.-Atlanta-GA-30305/10270251/866983?icid=sr92-4p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Oracle-DBA-w%26%2347-Data-Migration-and-Systems-Experience-Corus-Group%2C-LLC-Atlanta-GA-30303/10351101/1054500-317?icid=sr93-4p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Data-Analyst%26%2347Reports-Developer-%2805%29-Pyramid-Consulting%2C-Inc.-Atlanta-GA-30328/pyrmid/17-04994?icid=sr94-4p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Big-Data-Architect%26%2347Developer-role-OmniPoint-Staffing-Atlanta-GA-30339/10294339/J11705?icid=sr95-4p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Data-Entry-Clerk-Job-in-Kennesaw%2C-GA-Modis-Kennesaw-GA-30144/10103170/US_EN_6_21701_54393965?icid=sr96-4p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Financial-Data-Reporting-Analyst-%26%2347%26%2347-6-Month-Contract-to-Hire-%26%2345-Alpharetta%2C-GA-Modis-Alpharetta-GA-30004/cxmodoak1/US_EN_6_17428_56118440?icid=sr97-4p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Big-Data-Developer%26%2345-Immediate-Interview-GreyCell-Labs%2C-Inc-Marietta-GA-30008/10212426/907473?icid=sr98-4p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Application-Support%26%2347-Data-Analyst-Matrix-Resources-Dunwoody-GA-30338/matrixga/124629?icid=sr99-4p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Contract-Data-Analyst-Professional-Insight-Alpharetta-GA-30005/10271870/CDA931?icid=sr100-4p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Big-Data-Architect-%26%2345-Immediately-required-Exafluence-Alpharetta-GA-30004/90962729/872470?icid=sr101-4p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Computer-Operator-%28Data-Center%29-%26%2345-3rd-Shift-Matrix-Resources-Atlanta-GA-30301/matrixga/125260?icid=sr102-4p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Data-Center-Architect-for-GA-Compunnel-Software-Group-Inc.-Atlanta-GA-30301/compun/888434?icid=sr103-4p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Tableau-Consultant-%26%2347-Data-Analyst-%26%2345-Locals-%26%2347--Immediate-F2F-Interviews-Advent-Global-Solutions%2C-Inc.-Atlanta-GA-30309/agsinc/AGSTABMI?icid=sr104-4p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Data-Architect-%26%2347-ETL-Architect-%26%2347-Teradata-Architect-%26%2345-GA%26%2347TX-Charter-Global%2C-Inc.-Atlanta-GA-30303/chartpro/SE314_DAGA?icid=sr105-4p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Senior-UX-Researcher-NCR-Atlanta-GA-30301/NCRGA/223891?icid=sr106-4p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Vice-President-%26%2345-Technology-LocumTenens.com-Alpharetta-GA-30009/10374689/906335?icid=sr107-4p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Mgr%2C-Database-Admin-%28LITS%29-Emory-University-Atlanta-GA-30322/RTX1bf849/4952185?icid=sr108-4p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Senior-Project%26%2347Marketing-Analyst-The-Creative-Group-Atlanta-GA-30328/10466845/00900-0009201482?icid=sr109-4p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Statistician-Travelport-Atlanta-GA-30301/90719168/3984BR?icid=sr110-4p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Database-Developer-%28SSIS%2C-ETL%29-CSRA-Atlanta-GA-30301/srabot/4144456?icid=sr111-4p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Security-Analytics-Manager-Verizon-Alpharetta-GA-30004/10241294/452290-1A?icid=sr112-4p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Database-Administrator-WorldPay-Atlanta-GA-30363/10123218/935046?icid=sr113-4p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Senior-Technical-Project-Manager-Verizon-Alpharetta-GA-30004/10241294/452494-1B?icid=sr114-4p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Sr%26%2347Principal-Network-Automation-Engineer-ACI-Worldwide-Corp.-Norcross-GA-30092/RTX15a7e3/17000179?icid=sr115-4p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Technical-Product-Manager-Travelport-Atlanta-GA-30301/90719168/4374BR?icid=sr116-4p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Senior-Software-Engineer%26%2345-MicroStrategy-NICE-Systems-Atlanta-GA-30301/10115980/8382?icid=sr117-4p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Senior-Manager%2C-Marketing-Technology-The-Creative-Group-Atlanta-GA-30319/10466845/00900-0009189452?icid=sr118-4p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Global-Service-Desk-Operator-Premiere-Global-Services-Atlanta-GA-30301/10271939/2335?icid=sr119-4p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Operations-Analyst-Verizon-Atlanta-GA-30301/10241294/445552-1A?icid=sr120-4p&q=Data Scientist&l=Atlanta, GA
# Accessing Page no.5 : https://www.dice.com/jobs/q-Data_Scientist-l-Atlanta%2C_GA-radius-30-startPage-5-jobs?searchid=6830934449416
# Accessing  : https://www.dice.com/jobs/detail/Solution-Architect-Verizon-Atlanta-GA-30301/10241294/448200-1A?icid=sr121-5p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Business-Analyst-%26%2345-AML-%26%2345-Atlanta-%26%2345-Actimize-division-NICE-Systems-Atlanta-GA-30301/10115980/7986?icid=sr122-5p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Business-Analyst-%26%2345-Software-%26%2345-Actimize-division-NICE-Systems-Atlanta-GA-30301/10115980/7989?icid=sr123-5p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Product-Owner%2C-Cyber-Security-Honeywell%2C-Inc.-Atlanta-GA-30308/10368517/00336807?icid=sr124-5p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Senior-Quality-Assurance-Engineer-WorldPay-Atlanta-GA-30363/10123218/934984?icid=sr125-5p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Project-Manager-%26%2345-PMO-Office-GreenSky-Credit-Atlanta-GA-30301/90790689/565567?icid=sr126-5p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Business-Analyst-Verizon-Alpharetta-GA-30004/10241294/452752-1A?icid=sr127-5p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/UPS-Capital-IT-Software-Development-Intern-UPS-Atlanta-GA-30301/10120942A/123352?icid=sr128-5p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Computer-Operator-Equi%26%2345Tek-LLC-Atlanta-GA-30303/10514548/52076?icid=sr129-5p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Senior-Informatica-Solutions-Engineer-%26%2345-BHJOB2052_12978-Visionaire-Partners-Atlanta-GA-30308/10294321/BHJOB2052_12978?icid=sr130-5p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/BI-Analytics-Developer-H-Hunter-IT-Consulting-Atlanta-GA-30342/10109635/930000?icid=sr131-5p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Mid%26%2345Level-Backend-Java-Developer-%26%2345-BHJOB2052_12173-Visionaire-Partners-Atlanta-GA-30339/10294321/BHJOB2052_12173?icid=sr132-5p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Mid%26%2345Level-Backend-C%23-Developer-%26%2345-BHJOB2052_12161-Visionaire-Partners-Atlanta-GA-30339/10294321/BHJOB2052_12161?icid=sr133-5p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Digital-Analytics-Manager-Matrix-Resources-Duluth-GA-30026/matrixga/122048?icid=sr134-5p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Senior-BI%26%2347SQL-Developer-Robert-Half-Technology-Duluth-GA-30097/rhalfint/00900-0009211396?icid=sr135-5p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/IT-Project-Manager%26%2347HRIS-Robert-Half-Technology-Alpharetta-GA-30004/rhalfint/00900-0009196685?icid=sr136-5p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Hadoop-Engineer-Hexaware-Technologies%2C-Inc-Alpharetta-GA-30022/hexaware/890780?icid=sr137-5p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Business-Analyst-iStaff-Roswell-GA-30076/ISTAFFGA/NBPTBA?icid=sr138-5p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Learning-Tech-Admin-Robert-Half-Technology-Atlanta-GA-30328/rhalfint/04860-9500465349?icid=sr139-5p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/BI-Delivery-Manager-10286200-Atlanta-GA-30303/10286200/TheIntersectGr-253?icid=sr140-5p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/SAP-PLM-Implementation-Consultant-%26%2345-BHJOB2052_13105-Visionaire-Partners-Alpharetta-GA-30022/10294321/BHJOB2052_13105?icid=sr141-5p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Sr.-Solutions-Engineer-%28Aruba%29-Sayers-Atlanta-GA-30328/RTX13483f/402577?icid=sr142-5p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/BI-Delivery-Lead-Noble1-Atlanta-GA-30301/90884761/300?icid=sr143-5p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Sr.-Storage-Engineer-3Ci-Atlanta-GA-30301/comga001/17196NCH?icid=sr144-5p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/BI-Solution-Architect-10286200-Atlanta-GA-30303/10286200/TheIntersectGr-667?icid=sr145-5p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/ETL-Tech-Lead-Veredus-Atlanta-GA-30303/veredus/1070377-613?icid=sr146-5p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/NOC-Engineer-Principle-Solutions-Group-Atlanta-GA-30308/10124296/886477?icid=sr147-5p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Enterprise-Architect-%26%2345-Akka-%26%2347-Scala-%26%2347-Play-CyberCoders-Atlanta-GA-30301/cybercod/AC-PreSalesArchitect-ATL33?icid=sr148-5p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Principal-Software-Architect-CyberCoders-Atlanta-GA-30301/cybercod/DN-1352834GAreloTX47?icid=sr149-5p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Cisco-Contact-Center-Engineer-TeleQuest-Communications-Inc.-Atlanta-GA-30305/90769358/MP2112?icid=sr150-5p&q=Data Scientist&l=Atlanta, GA
# Accessing Page no.6 : https://www.dice.com/jobs/q-Data_Scientist-l-Atlanta%2C_GA-radius-30-startPage-6-jobs?searchid=6830934449416
# Accessing  : https://www.dice.com/jobs/detail/Software-Engineer-in-Test-Velossent-Alpharetta-GA-30022/10274992/857203?icid=sr151-6p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Application-Support-Manager-Comforce-Corporation%2C-Inc.-Duluth-GA-30096/CXCOMFRC/930503?icid=sr152-6p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Manual-%26%2347-Automated-Tester-iStaff-Alpharetta-GA-30005/ISTAFFGA/swstest2?icid=sr153-6p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Solutions-Architect-%28Cisco-UC-%26%2347-Collaboration-%26%2347-Networking%29-CyberCoders-Dunwoody-GA-30338/cybercod/CK-136006917?icid=sr154-6p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Sr.-Solutions-Architect-%26%2345-Cisco-Networking-%26%2347-Collaboration-CyberCoders-Atlanta-GA-30301/cybercod/CK-13638181?icid=sr155-6p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Associate-Platform-Engineer-3Ci-Atlanta-GA-30301/comga001/17234SGR?icid=sr156-6p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Technical-Test-Lead-%26%2345-US-Infosys-Atlanta-GA-30301/10204393/20723BR?icid=sr157-6p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/MS-Dynamics-Solution-Architect-The-Royak-Group-Inc.-Atlanta-GA-30328/10167419/MS2227?icid=sr158-6p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Informatica-Admin-Horizon-Consulting-Inc-Atlanta-GA-30301/90552376/110?icid=sr159-6p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/ETL-Developer-Delta-Information-Systems%2C-Inc.-Atlanta-GA-30318/10112378/814698?icid=sr160-6p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Informatica-Administrator-ICONMA-Atlanta-GA-30326/iconma/949170?icid=sr161-6p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/ETL%26%2347-ODI-Developer-%2815%29-Pyramid-Consulting%2C-Inc.-Alpharetta-GA-30009/pyrmid/17-09465?icid=sr162-6p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Computer-Operator-InfoSmart-Technologies-Inc-Atlanta-GA-30303/10198331/GA-52073?icid=sr163-6p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/BI-Developer-%28Tableau%29-Brooksource-Atlanta-GA-30303/10110651/BBBH39674-218?icid=sr164-6p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Informatica-Administrator-ICONMA-Atlanta-GA-30326/iconma/945881?icid=sr165-6p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Salesforce-Administrator-The-Talmadge-Group%2C-Inc.-Atlanta-GA-30339/10119397/49SalesForce?icid=sr166-6p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/computer-Operator-System-Soft-Technologies-Atlanta-GA-30305/10118461/SST-AK-0410-09?icid=sr167-6p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Technical-Operations-Research-Analyst-%26%2345-BHJOB2052_13127-Visionaire-Partners-Atlanta-GA-30309/10294321/BHJOB2052_13127?icid=sr168-6p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Web-Analytics-Developer-Kavi-Software-Atlanta-GA-30354/10119154/WAD0001?icid=sr169-6p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/BI-Architect-InfiCare-Technologies-Atlanta-GA-30304/10113809/13412-13392?icid=sr170-6p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Tableau-Developer-%26%2345-BHJOB2052_12996-Visionaire-Partners-Atlanta-GA-30346/10294321/BHJOB2052_12996?icid=sr171-6p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Hadoop-Solution-Architect-Open-Systems%2C-Inc.-Alpharetta-GA-30009/opsysga/RXB-04062-83?icid=sr172-6p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Hadoop%2C-Pig-%26-Hive-Developer-The-Judge-Group-Atlanta-GA-30301/cxjudgpa/524442?icid=sr173-6p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Business-Intelligence-Developer-KnackTek-Inc-Atlanta-GA-30334/10285784/BI11?icid=sr174-6p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/EDW%26%2347BI-Project-Manager-Matrix-Resources-Dunwoody-GA-30338/matrixga/124045?icid=sr175-6p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Advanced-Business-Analyst-Mitchell-Martin-Atlanta-GA-30301/mitchmar1/MITCA000J6411?icid=sr176-6p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Hadoop-Engineer-Agile-Alpharetta-GA-30005/10112507/BBBH9580-954?icid=sr177-6p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Senior-Information-Security-Architect-ICONMA-Alpharetta-GA-30009/iconma/920163?icid=sr178-6p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/BigData-Architect-Zodiac-Solutions-Inc.-Alpharetta-GA-30009/10457702/BDA_0315?icid=sr179-6p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Disaster-Recovery-Lead%26%2347Mentor-Business-Analyst-Datum-Software%2C-Inc.-Atlanta-GA-30354/70000132/3240?icid=sr180-6p&q=Data Scientist&l=Atlanta, GA
# Accessing Page no.7 : https://www.dice.com/jobs/q-Data_Scientist-l-Atlanta%2C_GA-radius-30-startPage-7-jobs?searchid=6830934449416
# Accessing  : https://www.dice.com/jobs/detail/Informatica-Admin-USM-Business-Systems-Atlanta-GA-30305/10106782/878790?icid=sr181-7p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/BI-Architect-%28Reporting%29-Softnice-Inc-Alpharetta-GA-30009/10212463/909172?icid=sr182-7p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Senior-Business-Systems-Analyst-Synergis-Alpharetta-GA-30005/SYNERGIS/SH14382?icid=sr183-7p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Technical-Business-Analyst-Matrix-Resources-Atlanta-GA-30301/matrixga/125276?icid=sr184-7p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/BI-Developer-Capricorn-Systems%2C-Inc.-Johns-Creek-GA-30097/capricor/949870?icid=sr185-7p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Software-Engineer-Velossent-Atlanta-GA-30303/10274992/866311?icid=sr186-7p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Sr.-Integration-Developer-Paramount-Software-Solutions%2C-Inc-Alpharetta-GA-30004/10452799/943330?icid=sr187-7p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/OBIA-ETL-Senior-Developer-Ariston-Tek%2C-Inc.-Atlanta-GA-30301/10299454/947421?icid=sr188-7p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/OBIA-ETL-Senior-Developer-Ariston-Tek%2C-Inc.-Atlanta-GA-30301/10299454/947506?icid=sr189-7p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Lead-Infrastructure-Business-Analyst-Dahl-Consulting-Atlanta-GA-30354/10109792/MB?icid=sr190-7p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Excel-%26%2347-BI-Developer-The-Judge-Group-Sandy-Springs-GA-30319/cxjudgpa/524982?icid=sr191-7p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Oracle-DBA-Reliable-Software-Resources-Atlanta-GA-30306/10122703/954183?icid=sr192-7p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Salesforce-Lead%26%2347Architect-Symphony-Enterprises-Atlanta-GA-30301/10334897/DK94?icid=sr193-7p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Product-Manager-%2815%29-Pyramid-Consulting%2C-Inc.-Alpharetta-GA-30022/pyrmid/17-03669?icid=sr194-7p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/ODI-ETL%26%2347ELT-Developer-ERP-Atlanta-GA-30309/10114195/678428?icid=sr195-7p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Information-Security-Analyst-AgreeYa-Solutions-Alpharetta-GA-30004/swapps/943491?icid=sr196-7p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Senior-Level-Cisco-Design-Architect-NEA-Consulting%2C-Inc.-Atlanta-GA-30301/90942565/946775?icid=sr197-7p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Business-Analyst-Expedite-Technology-Solutions-Alpharetta-GA-30005/10317972/1310BA_TSYS?icid=sr198-7p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Sr.-Project-Manager-Artech-Information-Systems-Atlanta-GA-30305/artech/952039?icid=sr199-7p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Oracle-Certified-DBA-MSYS-Inc.-Atlanta-GA-30301/msyca001/RGZ-5649?icid=sr200-7p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Enterprise-Client-Solutions-Architect-Veredus-Atlanta-GA-30303/veredus/1068673-159?icid=sr201-7p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Sr-Business-Analyst-IGT-Solutions-Inc-Atlanta-GA-30301/10124755/951583?icid=sr202-7p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Sr.-Salesforce-Developer-K2-Partnering-Solutions%2C-Inc.-Atlanta-GA-30301/10112561/867942?icid=sr203-7p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/DW-Engineer_Local-to-Atlanta-GA_Only-for-W2-candidates-Primus-Software-Corp-Atlanta-GA-30319/primusga/PC08?icid=sr204-7p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/System-Architect-%26%2347-Engineer-Aricent-Technologies-Mauritius-LTD-Atlanta-GA-30319/10111737/HP-2?icid=sr205-7p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Sr.-Hadoop-Developer%26%2347Architect-%2805%29-Pyramid-Consulting%2C-Inc.-Atlanta-GA-30326/pyrmid/17-05758?icid=sr206-7p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/BI-Analyst-w%26%2347-Fortune-500-Company-in-Atlanta-Robert-Half-Technology-Atlanta-GA-30326/rhalfint/00900-9500466837?icid=sr207-7p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/BI-Development-Manager-Fortune-500-Company-Atlanta-Robert-Half-Technology-Atlanta-GA-30326/rhalfint/00900-9500466848?icid=sr208-7p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Hadoop-Developer-Architect-System-Soft-Technologies-Atlanta-GA-30301/10118461/920667?icid=sr209-7p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Developer%26%2347Architect-%28Talend%29-Open-Systems%2C-Inc.-Atlanta-GA-30301/opsysga/PXP-0406-82?icid=sr210-7p&q=Data Scientist&l=Atlanta, GA
# Accessing Page no.8 : https://www.dice.com/jobs/q-Data_Scientist-l-Atlanta%2C_GA-radius-30-startPage-8-jobs?searchid=6830934449416
# Accessing  : https://www.dice.com/jobs/detail/Systems-Security-Administrator-%26%2345-Sr%26%2347-Sr.-Information-Security-Engineer-Finezi-Alpharetta-GA-30009/10309206/VJ-01-001?icid=sr211-8p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Android-Developer-%26%2347-Mobile-Developer-Comrise-Alpharetta-GA-30005/comrise/915266?icid=sr212-8p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Esri-ArcGIS-Administrator-for-Georgia-Department-of-Transportation-nLeague-Services-Atlanta-GA-30308/10112090/923907?icid=sr213-8p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/BI-Developer-for-Georgia-Department-of-Corrections-nLeague-Services-Atlanta-GA-30334/10112090/953795?icid=sr214-8p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Urgent-Opening-for-%22Network-Engineer-%28Sr.-or-Lead%29%22%21%21%21-Only-W2-Candidate-Primus-Software-Corp-Alpharetta-GA-30004/primusga/A12345?icid=sr215-8p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/TALEO-%26%2347-FUSION-%26%2347-BI-Quality-Assurance_GA-%282-positions%29-Primus-Software-Corp-Atlanta-GA-30319/primusga/560722?icid=sr216-8p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Netscaler-SME-%28-Remote-Opportunity-%29-Metasys-Technologies-Marietta-GA-30067/10117383/828356?icid=sr217-8p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/SR-PEGA-developers%26%2347architect%26%2345GA%28W2-Only%29-Source-Infotech-Atlanta-GA-30301/10240767/950169?icid=sr218-8p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/AbInitio-Technical-Lead-%26%2347Architect-%26%2345-Strong-Development-skills-only-Galax%26%2345Esystems-Corp-Atlanta-GA-30308/10230239/03-29-2017?icid=sr219-8p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Senior-.NET-UI-Developer-ADP-Automatic-Data-Processing%2C-Inc.-Alpharetta-GA-30005/adp/133871?icid=sr220-8p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/L3-Business-Analyst-Travelclick-Atlanta-GA-30301/10432132/1424?icid=sr221-8p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Field-Service-Engineer-III-Scientific-Research-Corporation-Kabul-AF-30339/10115561/ISS-7867?icid=sr222-8p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Software-Engineer-III-Scientific-Research-Corporation-Atlanta-GE-30339/10115561/ATS-7814?icid=sr223-8p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Software-Engineer-III-Scientific-Research-Corporation-Atlanta-GE-30339/10115561/ATS-7545?icid=sr224-8p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Mobile-Developer-Vuesol-Technologies-Inc.-Suwanee-GA-30024/90966045/M_503?icid=sr225-8p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Lead-Business-Systems-Analyst-with-Operations-Background-Scope-Consulting-Inc.-Atlanta-GA-30349/90973142a/879295?icid=sr226-8p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/SQL-BI-Developer-GreenSky-Credit-Atlanta-GA-30301/90790689/565474?icid=sr227-8p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Informatica-Architect-%26%2347-Designer-EITAcies%2C-Inc.-Atlanta-GA-30301/10371948/944406?icid=sr228-8p&q=Data Scientist&l=Atlanta, GA
# ...
# Accessing  : https://www.dice.com/jobs/detail/Web-Developer-III-IHRC%2C-Inc.-Atlanta-GA-30346/RTX192a8b/4940525?icid=sr635-22p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Delivery-Manager-Red-Clay-Consulting-Atlanta-GA-30363/90823961/job_20160728155501_N9S0FQPHZKSETTTR?icid=sr636-22p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Security%26%2347Network-Administrator-GreyStone-Power-Douglasville-GA-30134/RTX188f5c/2017-700-003?icid=sr637-22p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Business-Systems-Analyst-I%26%2345Applications-GreyStone-Power-Douglasville-GA-30134/RTX188f5c/947614?icid=sr638-22p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Level-2-Support-Engineer-PrimeRevenue-Inc.-Atlanta-GA-30309/10224337/942916?icid=sr639-22p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Director-%26%2345-Information-Technology-The-John-Maxwell-Company-Duluth-GA-30097/RTX1bf575/4953455?icid=sr640-22p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Programmer-Discovery-Analytics-Inc%2C-Alpharetta-GA-30005/90957384/DA02?icid=sr641-22p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Sr.-Manager--Finance-%28Sourcing-and-Logistics%29-Rheem-Manufacturing-Company-Atlanta-GA-30328/10491960/913690?icid=sr642-22p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Global-Category-Manager-%28Electronics%29-Rheem-Manufacturing-Company-Atlanta-GA-30328/10491960/913684?icid=sr643-22p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Product-Support-Specialist-Verint-Systems-Inc.-Alpharetta-GA-30005/WITSYS/11572?icid=sr644-22p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Senior-Software-Engineer-Verint-Systems-Inc.-Alpharetta-GA-30005/WITSYS/937120?icid=sr645-22p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Global-Category-Manager-%28Non-Ferrous-Metals-Rheem-Manufacturing-Company-Atlanta-GA-30328/10491960/913703?icid=sr646-22p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Customer-Service-Rep-II-Rheem-Manufacturing-Company-Duluth-GA-30026/10491960/931868?icid=sr647-22p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/ePMO-Project-Analyst-WorldPay-Atlanta-GA-30363/10123218/934946?icid=sr648-22p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Global-Category-Manger-%28Chemicals%29-Rheem-Manufacturing-Company-Atlanta-GA-30328/10491960/913699?icid=sr649-22p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Enterprise-Network-Manager-Greenberg-Traurig%2C-LLP-Atlanta-GA-30305/RTL122275/704419?icid=sr650-22p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Systems-Operations-Support-%26%2345-Windows-Quality-Technology-Services-Suwanee-GA-30024/10214426/191140?icid=sr651-22p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Senior-.Net-Developer-IST-Management-Services-Atlanta-GA-30316/10117728/913115?icid=sr652-22p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Software-Architect-IST-Management-Services-Atlanta-GA-30316/10117728/913214?icid=sr653-22p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Workday-Grants-and-Projects-Solution-Architect-Sierra%26%2345Cedar%2C-Inc.-Atlanta-GA-30301/adrga001/WKDY-2266?icid=sr654-22p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Sr.-Exstream-Dialgoue-Developer-CEDAR-Document-Technologies-Atlanta-GA-30346/RTX15854e/015922?icid=sr655-22p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Lead-Salesforce-Application-Developer-SunTrust-Banks%2C-Inc.-Atlanta-GA-30301/suntrbot/396096600?icid=sr656-22p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Customer-Solutions-Compliance-Liaison-GreenSky-Credit-Atlanta-GA-30301/90790689/567043?icid=sr657-22p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Customer-Solutions-Advocate-II-GreenSky-Credit-Atlanta-GA-30301/90790689/571411?icid=sr658-22p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Director-of-Loss-Mitigation-and-Workout%2C-Merchant-Risk-Management-GreenSky-Credit-Atlanta-GA-30301/90790689/569982?icid=sr659-22p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Loss-Mitigation-and-Workout-Analyst%2C-Merchant-Risk-GreenSky-Credit-Atlanta-GA-30301/90790689/560568?icid=sr660-22p&q=Data Scientist&l=Atlanta, GA
# Accessing Page no.23 : https://www.dice.com/jobs/q-Data_Scientist-l-Atlanta%2C_GA-radius-30-startPage-23-jobs?searchid=6830934449416
# Accessing  : https://www.dice.com/jobs/detail/Sr.-Director%2C-Demand-Generation-GreenSky-Credit-Atlanta-GA-30301/90790689/562783?icid=sr661-23p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Business-Development-Consultant-GreenSky-Credit-Atlanta-GA-30301/90790689/550071?icid=sr662-23p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/SOC-Security-Analyst-%26%2345-SecureWorks-Dell-Atlanta-GA-30301/10126746/170001LN?icid=sr663-23p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Business-Development-Consultant-GreenSky-Credit-Atlanta-GA-30301/90790689/570487?icid=sr664-23p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Tier-II-Technical-Support-Analyst-%28MAC-support%29-GreenSky-Credit-Atlanta-GA-30301/90790689/569836?icid=sr665-23p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Business-Development-Consultant-GreenSky-Credit-Atlanta-GA-30301/90790689/569980?icid=sr666-23p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Lead-Tier-II-Technical-Support-Analyst-GreenSky-Credit-Atlanta-GA-30301/90790689/570347?icid=sr667-23p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Tier-II-Technical-Support-Analyst-GreenSky-Credit-Atlanta-GA-30301/90790689/570350?icid=sr668-23p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Fraud-Investigator-Level-1-GreenSky-Credit-Atlanta-GA-30301/90790689/567544?icid=sr669-23p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Credit-Processor-GreenSky-Credit-Atlanta-GA-30301/90790689/562806?icid=sr670-23p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Digital-Designer-The-Creative-Group-Atlanta-GA-30301/10466845/00900-0009229882?icid=sr671-23p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Release-Coordinator-%26%2345-SAP-%26%2345-Finance-Domain-New-York-Life-Insurance-Company-Alpharetta-GA-30004/10127844a/43825-en_US?icid=sr672-23p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Digital-Marketing-Manager-The-Creative-Group-Atlanta-GA-30326/10466845/00900-9500458112?icid=sr673-23p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Senior-Lead-Technical-Developer-Travelport-Atlanta-GA-30301/90719168/4233BR?icid=sr674-23p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Technology-Optimization-Engineer-Travelport-Atlanta-GA-30301/90719168/2429BR?icid=sr675-23p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Knowledge-Management-Lead-Travelport-Atlanta-GA-30301/90719168/4140BR?icid=sr676-23p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Software-Engineer-%26%2345-metro-Atlanta-%26%2345-Actimize-division-NICE-Systems-Atlanta-GA-30301/10115980/7997?icid=sr677-23p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Principal-Network-Planning-Engineer-Verizon-Alpharetta-GA-30004/10241294/451517-1C?icid=sr678-23p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Senior-IT-Security-Manager-%26%2345-Security-Engineering-Verizon-Alpharetta-GA-30004/10241294/450253-1B?icid=sr679-23p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/IT-Quality-Assurance-Senior-Manager-Verizon-Alpharetta-GA-30004/10241294/452317-1A?icid=sr680-23p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/DevOps-Engineer-Verizon-Alpharetta-GA-30004/10241294/452457-1B?icid=sr681-23p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Selenium-Developer-Verizon-Alpharetta-GA-30004/10241294/452908-1A?icid=sr682-23p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/WMS-Analyst-%28Professional-Services%29-Timlin-Enterprises-Atlanta-GA-30320/10482040/940685?icid=sr683-23p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Senior-IT-Security-Manager-%26%2345-Security-Engineering-Verizon-Alpharetta-GA-30004/appblok/1524_450253-1B?icid=sr684-23p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/IT-Services-Senior-Manager-Georgia%26%2345Pacific-Atlanta-GA-30303/RTL514929/046848?icid=sr685-23p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Business-Process-Outsourcing-Consulting-Manager-Deloitte-Atlanta-GA-30301/appblok/452_E17NATCMGRMF320-SO?icid=sr686-23p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Managed-Services_Workday-Post-Production-Lead-_-Manager-PWC-Atlanta-GA-30301/appblok/2392_92012BR?icid=sr687-23p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Shared-Services-Consulting-Manager-Deloitte-Atlanta-GA-30301/appblok/452_E17NATCMGRMF450-SO?icid=sr688-23p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Manager%2C-Digital-Systems-Implementation-Assurant-Atlanta-GA-30301/10194293/49825?icid=sr689-23p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Technical-Support-Representative-I-FIS-Atlanta-GA-30303/10113445/PCK439100603-995?icid=sr690-23p&q=Data Scientist&l=Atlanta, GA
# Accessing Page no.24 : https://www.dice.com/jobs/q-Data_Scientist-l-Atlanta%2C_GA-radius-30-startPage-24-jobs?searchid=6830934449416
# Accessing  : https://www.dice.com/jobs/detail/Senior-iOS-Developer-Systematix-Software-Atlanta-GA-30309/90621773/856482?icid=sr691-24p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Java-Web-Developer-AGI-Atlanta-GA-30301/10109333/912587?icid=sr692-24p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Automation-Test-Lead-InduTech-Atlanta-GA-30306/10429605/MK-ATE-GA?icid=sr693-24p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Senior-Salesforce-Technical-Lead-Verizon-Alpharetta-GA-30004/10241294/450713-1A?icid=sr694-24p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Sr.-Corporate-Quality-Systems-Manager-Verizon-Atlanta-GA-30301/10241294/452011-1A?icid=sr695-24p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Oracle-Fusion-Reporting-Developer-BC-Forward-Atlanta-GA-30328/10107103E/954241?icid=sr696-24p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Project-Lead-Kofax%2C-Imaging%26%2347-Global-scape-InduTech-Atlanta-GA-30310/10429605/882332?icid=sr697-24p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Java-Developer-w%26%2347-MVC-%26-PL%26%2347SQL-%26%2345-BHJOB2052_13137-Visionaire-Partners-Atlanta-GA-30328/10294321/BHJOB2052_13137?icid=sr698-24p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Cloud-Software-Engineer-%28JAVA-%26%2345-Hadoop%29-Digitangle-Inc.-Duluth-GA-30026/90970767/918028?icid=sr699-24p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Software-Programmer--III%26%2345.Net-Capricorn-Systems%2C-Inc.-Atlanta-GA-30338/capricor/913725?icid=sr700-24p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/.NET-Developer-Hexaware-Technologies%2C-Inc-Alpharetta-GA-30005/hexaware/929798?icid=sr701-24p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Manager%2C-Pricing-Strategy-%26%2345-BHJOB2052_12896-Visionaire-Partners-Atlanta-GA-30339/10294321/BHJOB2052_12896?icid=sr702-24p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Senior-Manager-of-SAP-Finance-Applied-Resource-Group-Atlanta-GA-30339/10447354/917719?icid=sr703-24p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Vmware-System-Engineer-%2805%29-Pyramid-Consulting%2C-Inc.-Kennesaw-GA-30144/pyrmid/16-30022?icid=sr704-24p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Project-Engineer-Corporate-%26-Technical-Recruiters%2C-Inc-Norcross-GA-30071/10352633/917695?icid=sr705-24p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Java-Developer-Nihaki-Systems%2C-Inc.-Atlanta-GA-30303/nihaki/919385?icid=sr706-24p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Project-Engineer-Expert-Technical-Solutions-Norcross-GA-30071/10374726/925011?icid=sr707-24p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/ServiceNow-Developer-%26%2345-BHJOB2052_12920-Visionaire-Partners-Atlanta-GA-30339/10294321/BHJOB2052_12920?icid=sr708-24p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Windows-Desktop%26%2347Server-Support-Engineer-Edvenswa-Tech-LLC-Atlanta-GA-30339/90962424/939071?icid=sr709-24p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Program-Manager-Cognizant-Technology-Solutions-Atlanta-GA-30301/aces/00021595331?icid=sr710-24p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Technical-Product-Owner-%26%2347-Manager-%26%2345-BHJOB2052_12961-Visionaire-Partners-Alpharetta-GA-30022/10294321/BHJOB2052_12961?icid=sr711-24p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Ruby-on-Rails-Engineer-Principle-Solutions-Group-Atlanta-GA-30328/10124296/AC_ATL_RUBY?icid=sr712-24p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/UI-Developer-%26%2347-Angular.JS-firstPRO%2C-Inc.-Atlanta-GA-30309/FIRSTPRO/781893?icid=sr713-24p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/System-Programmer-Analyst-Principle-Solutions-Group-Atlanta-GA-30329/10124296/938313?icid=sr714-24p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Salesforce-Admin-Xtivia-Inc-Smyrna-GA-30082/10114120/SFDCadmin0317?icid=sr715-24p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/IT-Security-Audit-Manager-%26%2345-BHJOB2052_13125-Visionaire-Partners-Atlanta-GA-30346/10294321/BHJOB2052_13125?icid=sr716-24p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Lead-Cloud-Software-Engineer-Spar-Information-Systems-Atlanta-GA-30301/90719156/CJ963?icid=sr717-24p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Software-Engineer-I%2C-II%2C-III-Velossent-Alpharetta-GA-30022/10274992/866284?icid=sr718-24p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/Development-Manager-%26%2345-Engineering-Velossent-Alpharetta-GA-30022/10274992/866362?icid=sr719-24p&q=Data Scientist&l=Atlanta, GA
# Accessing  : https://www.dice.com/jobs/detail/ERP-HCM-Analyst-CSI-IT%2C-LLC-Atlanta-GA-30311/csitall/10505?icid=sr720-24p&q=Data Scientist&l=Atlanta, GA
# Done!

# %%
#Loading to pandas
#Initially got this error 'utf-8' codec can't decode byte 0xa0 in position 1024: invalid start byte 
# tried encodings utf-8,utf-8-sig and finally cp1252 which worked.
j_cols = ['job_title', 'skill_set', 'employment_type']
job_info = pd.read_csv('job_info.csv',delimiter=':',names=j_cols,index_col=False,skiprows=1,encoding='cp1252')
job_info
# Out:
#                                              job_title  \
# 0        Sr. Manager, Data Scientist - BHJOB2052_13161
# 1                                       Data Scientist
# 2    Sr. Manager, Data Scientist - Personalization ...
# 3                                       Data Scientist
# 4                                       Data Scientist
# 5                                       Data Scientist
# 6                                       Data Scientist
# 7                                       Data Scientist
# 8                                      Data Scientists
# 9                                       Data Scientist
# 10                                      Data Scientist
# 11   AEM Consultant--- Blue Prism Architect---Data ...
# 12       Data Scientist/Sr. Data Analyst (Tableau/SQL)
# 13        Information security analyst /Data Scientist
# 14                                 Data Scientist - GA
# 15                           Data Engineer (Developer)
# 16                          Data Analyst-Data Movement
# 17                           Data Analyst-DBA and DBSA
# 18   Workday HCM Data Conversion- Solution Engineer...
# 19            Data Conversion- Solution Manager - USDC
# 20                            Sr. Data Center Engineer
# 21     Senior .NET Technical Lead/Manager - Data Focus
# 22                               Sr Big Data Architect
# 23                          Big Data Platform Engineer
# 24                                         Data Mapper
# 25                                   Big Data Engineer
# 26        Oracle eBusiness Suite Product Data Hub Lead
# 27          Data Architect      Atlanta, GA    Maddy J
# 28                             Data Quality Specialist
# 29                                        Data Analyst
# ..                                                 ...
# 720                               Senior iOS Developer
# 721                                 Java Web Developer
# 722                               Automation Test Lead
# 723                   Senior Salesforce Technical Lead
# 724              Sr. Corporate Quality Systems Manager
# 725                  Oracle Fusion Reporting Developer
# 726          Project Lead Kofax, Imaging/ Global scape
# 727   Java Developer w/ MVC & PL/SQL - BHJOB2052_13137
# 728            Cloud Software Engineer (JAVA - Hadoop)
# 729                      Software Programmer  III-.Net
# 730                                     .NET Developer
# 731        Manager, Pricing Strategy - BHJOB2052_12896
# 732                      Senior Manager of SAP Finance
# 733                        Vmware System Engineer (05)
# 734                                   Project Engineer
# 735                                     Java Developer
# 736                                   Project Engineer
# 737             ServiceNow Developer - BHJOB2052_12920
# 738            Windows Desktop/Server Support Engineer
# 739                                    Program Manager
# 740  Technical Product Owner / Manager - BHJOB2052_...
# 741                             Ruby on Rails Engineer
# 742                          UI Developer / Angular.JS
# 743                          System Programmer Analyst
# 744                                   Salesforce Admin
# 745        IT Security Audit Manager - BHJOB2052_13125
# 746                       Lead Cloud Software Engineer
# 747                       Software Engineer I, II, III
# 748                  Development Manager - Engineering
# 749                                    ERP HCM Analyst
#
#                                              skill_set  \
# 0    statistics, data models, data mining, data ana...
# 1    Analysis, Analytical, API, Data Mining, Java, ...
# 2    statistics, data models, data mining, data ana...
# 3         Python, Time Series, Cloud, Data Modeling, R
# 4                                       Data Scientist
# 5            Data Scientist,Python,Cloud,Data Modeling
# 6                                        data engineer
# 7    Hive, Pig, MySQL, Postgres, Hadoop, MapReduce,...
# 8    ninja ,Machine Intelligence,Trader surveillanc...
# 9                                         Python,ARIMA
# 10                                    Python, Cloud...
# 11   AEM Consultant--- Blue Prism Architect---Data ...
# 12   Analyst, Database, Developer, Management, Metr...
# 13   Must have Hadoop and cloud security expertise ...
# 14        Data Science, Marketing Analytics, Hadoop, R
# 15                                                Java
# 16   Agile, Analysis, Analyst, Architecture, Databa...
# 17   Agile, Analysis, Analyst, Database, Database A...
# 18   Analysis, Consulting, Development, ERP, Excel,...
# 19   Analysis, Consulting, Development, Excel, HTTP...
# 20   EMC, data storage, NetApp, VMware, professiona...
# 21   .Net, Agile, Ajax, ASP, ASP.NET, Automated, C+...
# 22                                  Big Data Architect
# 23   Agile, Analysis, Architecture, Business Requir...
# 24   Analytical Skills, Business Requirements, CGI,...
# 25   Agile, Architecture, Database, Developer, Deve...
# 26                       Oracle EBS, MDM, Data Quality
# 27           Data Architect,visualizations,Tableau,SQL
# 28               Data Quality, Infosphere, Informatica
# 29                    Data Analyst, SQL, Data Modeling
# ..                                                 ...
# 720                                          IOS COCOA
# 721  JAVA, J2EE, EJB, JavaBeans, JavaScript ES6, se...
# 722                  Drupal 8/7, Selenium, Behat, Test
# 723  Agile, Analytical Skills, Architecture, Develo...
# 724  Change Management, Configuration Management, C...
# 725  Oracle Fusion Applications (Fin GRC/Fusion Acc...
# 726                       Kofax, Imaging/ Global scape
# 727                  degree, java, pl/sql, mvc, spring
# 728               Hadoop, Heroku, Azure, or Amazon AWS
# 729  AngularJS, .NET, Spring Programming  Languages...
# 730  .NET, MVC, C#, VB.Net, asp.net 4.5, SQL server...
# 731        pricing strategy, excel, powerpoint, degree
# 732  General Ledger (new G/L a plus), AP, AR, Credi...
# 733  Vmware, virtualization, Cisco ASA, VPN, Linux,...
# 734         electrical engineer, Redhat, Linux, SCADA,
# 735   MVC frameworks, JSP, servlets, SQL, HTML and CSS
# 736                                   Bachelors Degree
# 737                             servicenow, javascript
# 738  Patch Management for Servers, Desktops & Netwo...
# 739  Consulting, Development, Excel, Manager, Manag...
# 740                     product manager, product owner
# 741  ruby, rails, clojure, sinatra, capistrano, bac...
# 742                Angular.JS, Javascript, css3, html5
# 743                                         SQL, RDBMS
# 744  Salesforce Admin Exp  Salesforce Admin Certi o...
# 745  managing IT and security audit programs, devel...
# 746                        JVM, RESTful APIs, TDD, BDD
# 747  Software development, DOM, AJAX, HTML, trouble...
# 748  Software development experience, development m...
# 749                                    ERP HCM Analyst
#
#                                        employment_type
# 0                                            Full Time
# 1                                            Full Time
# 2                                            Full Time
# 3                                            Full Time
# 4    Contract Corp-To-Corp, Contract Independent, C...
# 5    Contract Corp-To-Corp, Contract Independent, C...
# 6    Full Time, Contract Corp-To-Corp, Contract Ind...
# 7    Full Time, Contract Corp-To-Corp, Contract Ind...
# 8                                          Contract W2
# 9    Contract Corp-To-Corp, Contract Independent, C...
# 10                                         Contract W2
# 11   Full Time, Contract Corp-To-Corp, Contract Ind...
# 12   Contract Independent, Contract W2, C2H Indepen...
# 13                                         Contract W2
# 14                                         Contract W2
# 15   Full Time, Contract Corp-To-Corp, Contract Ind...
# 16                                           Full Time
# 17                                           Full Time
# 18                                           Full Time
# 19                                           Full Time
# 20                                           Full Time
# 21                                           Full Time
# 22                                           Full Time
# 23                                           Full Time
# 24                                           Full Time
# 25                                           Full Time
# 26   Contract Corp-To-Corp, C2H Corp-To-Corp, Contr...
# 27                               Contract Corp-To-Corp
# 28                                           Full Time
# 29                                           Full Time
# ..                                                 ...
# 720  Full Time, Contract Corp-To-Corp, Contract Ind...
# 721  Full Time, Contract Corp-To-Corp, Contract Ind...
# 722  Contract Corp-To-Corp, Contract Independent, C...
# 723  Contract Corp-To-Corp, Contract Independent, C...
# 724  Contract Corp-To-Corp, Contract Independent, C...
# 725  Contract Corp-To-Corp, Contract Independent, C...
# 726                              Contract Corp-To-Corp
# 727                                          Full Time
# 728                                          Full Time
# 729                                          Full Time
# 730                                          Full Time
# 731                                          Full Time
# 732                                          Full Time
# 733                                          Full Time
# 734                                          Full Time
# 735                                          Full Time
# 736                                          Full Time
# 737                                          Full Time
# 738                                          Full Time
# 739                                          Full Time
# 740                                          Full Time
# 741                                          Full Time
# 742                                          Full Time
# 743                                          Full Time
# 744                                          Full Time
# 745                                          Full Time
# 746                                          Full Time
# 747                                          Full Time
# 748                                          Full Time
# 749                                          Full Time
#
# [750 rows x 3 columns]

# %%
# Looks like a lot of postings has nothing to do with Data Science 
# Lets check the ones that are
ds_keywds = ['data','hadoop','tableau','python','spark','predictive','model','analytic','analyst',
                 'statistic','scientist','intelligence','sas','research','information','machine learning']
def find_ds_keywds(title):
    # checking the presence of some ds buzzwords in the job title..ofcourse anything with'data', we are interested 
    # courtesy : 'http://www.datasciencecentral.com/profiles/blogs/job-titles-for-data-scientists'
    return any(x in title.lower() for x in ds_keywds) 
    
job_info_ds = job_info[job_info['job_title'].apply(find_ds_keywds)]
job_info_ds
# Out:
#                                              job_title  \
# 0        Sr. Manager, Data Scientist - BHJOB2052_13161
# 1                                       Data Scientist
# 2    Sr. Manager, Data Scientist - Personalization ...
# 3                                       Data Scientist
# 4                                       Data Scientist
# 5                                       Data Scientist
# 6                                       Data Scientist
# 7                                       Data Scientist
# 8                                      Data Scientists
# 9                                       Data Scientist
# 10                                      Data Scientist
# 11   AEM Consultant--- Blue Prism Architect---Data ...
# 12       Data Scientist/Sr. Data Analyst (Tableau/SQL)
# 13        Information security analyst /Data Scientist
# 14                                 Data Scientist - GA
# 15                           Data Engineer (Developer)
# 16                          Data Analyst-Data Movement
# 17                           Data Analyst-DBA and DBSA
# 18   Workday HCM Data Conversion- Solution Engineer...
# 19            Data Conversion- Solution Manager - USDC
# 20                            Sr. Data Center Engineer
# 21     Senior .NET Technical Lead/Manager - Data Focus
# 22                               Sr Big Data Architect
# 23                          Big Data Platform Engineer
# 24                                         Data Mapper
# 25                                   Big Data Engineer
# 26        Oracle eBusiness Suite Product Data Hub Lead
# 27          Data Architect      Atlanta, GA    Maddy J
# 28                             Data Quality Specialist
# 29                                        Data Analyst
# ..                                                 ...
# 554              Senior HR Reporting Solutions Analyst
# 555                        Operations Research Analyst
# 556                       JD Edwards Developer Analyst
# 558                                         QA Analyst
# 559        Sr. Information Security Compliance Analyst
# 563                       Information Security Analyst
# 570                       Information Security Analyst
# 574                     Hadoop Developer/Administrator
# 579                           Tableau Server Architect
# 582                          Sr Agile Business Analyst
# 585                               DLP Security Analyst
# 587                       Information Security Analyst
# 592                                   Python Developer
# 597                  Systems Analyst - with SQL skills
# 601                       Senior Information Architect
# 613            IT Database Administrator - Atlanta, GA
# 622                   Business Analyst/Project Manager
# 652                                  SAS Administrator
# 667            Business Systems Analyst I-Applications
# 669                  Director - Information Technology
# 677                               ePMO Project Analyst
# 689  Loss Mitigation and Workout Analyst, Merchant ...
# 692                 SOC Security Analyst - SecureWorks
# 694    Tier II Technical Support Analyst (MAC support)
# 696             Lead Tier II Technical Support Analyst
# 697                  Tier II Technical Support Analyst
# 712                WMS Analyst (Professional Services)
# 728            Cloud Software Engineer (JAVA - Hadoop)
# 743                          System Programmer Analyst
# 749                                    ERP HCM Analyst
#
#                                              skill_set  \
# 0    statistics, data models, data mining, data ana...
# 1    Analysis, Analytical, API, Data Mining, Java, ...
# 2    statistics, data models, data mining, data ana...
# 3         Python, Time Series, Cloud, Data Modeling, R
# 4                                       Data Scientist
# 5            Data Scientist,Python,Cloud,Data Modeling
# 6                                        data engineer
# 7    Hive, Pig, MySQL, Postgres, Hadoop, MapReduce,...
# 8    ninja ,Machine Intelligence,Trader surveillanc...
# 9                                         Python,ARIMA
# 10                                    Python, Cloud...
# 11   AEM Consultant--- Blue Prism Architect---Data ...
# 12   Analyst, Database, Developer, Management, Metr...
# 13   Must have Hadoop and cloud security expertise ...
# 14        Data Science, Marketing Analytics, Hadoop, R
# 15                                                Java
# 16   Agile, Analysis, Analyst, Architecture, Databa...
# 17   Agile, Analysis, Analyst, Database, Database A...
# 18   Analysis, Consulting, Development, ERP, Excel,...
# 19   Analysis, Consulting, Development, Excel, HTTP...
# 20   EMC, data storage, NetApp, VMware, professiona...
# 21   .Net, Agile, Ajax, ASP, ASP.NET, Automated, C+...
# 22                                  Big Data Architect
# 23   Agile, Analysis, Architecture, Business Requir...
# 24   Analytical Skills, Business Requirements, CGI,...
# 25   Agile, Architecture, Database, Developer, Deve...
# 26                       Oracle EBS, MDM, Data Quality
# 27           Data Architect,visualizations,Tableau,SQL
# 28               Data Quality, Infosphere, Informatica
# 29                    Data Analyst, SQL, Data Modeling
# ..                                                 ...
# 554                    financial, QlikView, dashboards
# 555  cplex, c++, operations research, industrial en...
# 556  5+ years of JDE Development, JDE World 7.3, Or...
# 558  Telecommunications Experience, Quality Center,...
# 559                               Security, Compliance
# 563                  Information Security, CISSP, CISA
# 570                       Information Security Analyst
# 574  adoop Cluster Administration 3. Hadoop Securit...
# 579          Tableau Server, Tableau Enterprise Server
# 582                                              Agile
# 585                           Refer to Job Description
# 587                               Information Security
# 592  Python,testing frameworks,MS SQL Query,C#,Java...
# 597  Analyst, Architecture, Database, Developer, De...
# 601  Architect, Artificial Intelligence, Developmen...
# 613                          Database, SQL, SQL Server
# 622  Experience or strong knowledge in one or more ...
# 652                                  See job overview.
# 667  understanding of business processes and use of...
# 669  Salesforce, LAMP technologies (Linux-Apache-My...
# 677  ePMO Project Analyst, payment technology, PMO ...
# 689  Accounting, Analysis, Analyst, Excel, Hub, Man...
# 692  Analysis, Analyst, Civil, Database, Firewall, ...
# 694  Analysis, Analyst, DNS, Hardware, Help Desk, M...
# 696  Analysis, Analyst, DNS, Hardware, Help Desk, M...
# 697  Analysis, Analyst, DNS, Hardware, Help Desk, M...
# 712  WMS, Logistics, Supply Chain, analysis, implem...
# 728               Hadoop, Heroku, Azure, or Amazon AWS
# 743                                         SQL, RDBMS
# 749                                    ERP HCM Analyst
#
#                                        employment_type
# 0                                            Full Time
# 1                                            Full Time
# 2                                            Full Time
# 3                                            Full Time
# 4    Contract Corp-To-Corp, Contract Independent, C...
# 5    Contract Corp-To-Corp, Contract Independent, C...
# 6    Full Time, Contract Corp-To-Corp, Contract Ind...
# 7    Full Time, Contract Corp-To-Corp, Contract Ind...
# 8                                          Contract W2
# 9    Contract Corp-To-Corp, Contract Independent, C...
# 10                                         Contract W2
# 11   Full Time, Contract Corp-To-Corp, Contract Ind...
# 12   Contract Independent, Contract W2, C2H Indepen...
# 13                                         Contract W2
# 14                                         Contract W2
# 15   Full Time, Contract Corp-To-Corp, Contract Ind...
# 16                                           Full Time
# 17                                           Full Time
# 18                                           Full Time
# 19                                           Full Time
# 20                                           Full Time
# 21                                           Full Time
# 22                                           Full Time
# 23                                           Full Time
# 24                                           Full Time
# 25                                           Full Time
# 26   Contract Corp-To-Corp, C2H Corp-To-Corp, Contr...
# 27                               Contract Corp-To-Corp
# 28                                           Full Time
# 29                                           Full Time
# ..                                                 ...
# 554                                        Contract W2
# 555                             Full Time, Contract W2
# 556  Contract Corp-To-Corp, Contract Independent, C...
# 558                                        Contract W2
# 559                                        Contract W2
# 563  Contract Corp-To-Corp, Contract Independent, C...
# 570                                        Contract W2
# 574                 Contract Corp-To-Corp, Contract W2
# 579                                             C2H W2
# 582                                        Contract W2
# 585  Contract Corp-To-Corp, Contract Independent, C...
# 587  Contract Corp-To-Corp, Contract Independent, C...
# 592  Contract Corp-To-Corp, Contract Independent, C...
# 597  Contract Independent, Contract W2, C2H Indepen...
# 601  Contract Corp-To-Corp, Contract Independent, C...
# 613                                          Full Time
# 622                                        Contract W2
# 652                                          Full Time
# 667                                          Full Time
# 669                                          Full Time
# 677                                          Full Time
# 689                                          Full Time
# 692                                          Full Time
# 694                                          Full Time
# 696                                          Full Time
# 697                                          Full Time
# 712                                          Full Time
# 728                                          Full Time
# 743                                          Full Time
# 749                                          Full Time
#
# [267 rows x 3 columns]

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(min_df=2, stop_words='english')
# sparse representation of the counts using scipy.sparse.coo_matrix.
cvmatrix = cv.fit_transform(job_info_ds['skill_set'])
cv.vocabulary_
# Out:
# {'access': 0,
#  'accounting': 1,
#  'administration': 2,
#  'adobe': 3,
#  'aem': 4,
#  'agile': 5,
#  'ajax': 6,
#  'ambari': 7,
#  'analysis': 8,
#  'analyst': 9,
#  'analytical': 10,
#  'analytics': 11,
#  'apache': 12,
#  'api': 13,
#  'application': 14,
#  'applications': 15,
#  'arcgis': 16,
#  'architect': 17,
#  'architecture': 18,
#  'architectures': 19,
#  'arcsde': 20,
#  'arima': 21,
#  'asa': 22,
#  'asp': 23,
#  'automated': 24,
#  'aws': 25,
#  'azure': 26,
#  'banking': 27,
#  'based': 28,
#  'bi': 29,
#  'big': 30,
#  'bigsql': 31,
#  'blue': 32,
#  'bteq': 33,
#  'build': 34,
#  'builder': 35,
#  'building': 36,
#  'business': 37,
#  'capacity': 38,
#  'case': 39,
#  'cassandra': 40,
#  'ccna': 41,
#  'ceh': 42,
#  'center': 43,
#  'centric': 44,
#  'cgi': 45,
#  'change': 46,
#  'cisco': 47,
#  'cissp': 48,
#  'civil': 49,
#  'client': 50,
#  'cloud': 51,
#  'cms': 52,
#  'code': 53,
#  'collection': 54,
#  'communication': 55,
#  'compliance': 56,
#  'computer': 57,
#  'consultant': 58,
#  'consulting': 59,
#  'control': 60,
#  'controls': 61,
#  'crm': 62,
#  'crystal': 63,
#  'css': 64,
#  'customer': 65,
#  'cyber': 66,
#  'dashboards': 67,
#  'data': 68,
#  'database': 69,
#  'db2': 70,
#  'dba': 71,
#  'degree': 72,
#  'description': 73,
#  'design': 74,
#  'desk': 75,
#  'developer': 76,
#  'development': 77,
#  'director': 78,
#  'dns': 79,
#  'drools': 80,
#  'ebs': 81,
#  'ecommerce': 82,
#  'edi': 83,
#  'emc': 84,
#  'encryption': 85,
#  'engineer': 86,
#  'engineering': 87,
#  'enterprise': 88,
#  'environments': 89,
#  'erp': 90,
#  'esri': 91,
#  'etl': 92,
#  'excel': 93,
#  'excellence': 94,
#  'experience': 95,
#  'expertise': 96,
#  'facing': 97,
#  'financial': 98,
#  'firewall': 99,
#  'flow': 100,
#  'flume': 101,
#  'framework': 102,
#  'ga': 103,
#  'gathering': 104,
#  'geodatabase': 105,
#  'giac': 106,
#  'git': 107,
#  'google': 108,
#  'hadoop': 109,
#  'hardware': 110,
#  'hbase': 111,
#  'hcatalog': 112,
#  'hdfs': 113,
#  'help': 114,
#  'hive': 115,
#  'hortonworks': 116,
#  'hp': 117,
#  'hr': 118,
#  'http': 119,
#  'hub': 120,
#  'ibm': 121,
#  'impala': 122,
#  'implementation': 123,
#  'implementations': 124,
#  'industrial': 125,
#  'informatica': 126,
#  'information': 127,
#  'infosphere': 128,
#  'infrastructure': 129,
#  'intelligence': 130,
#  'ip': 131,
#  'iterative': 132,
#  'iv': 133,
#  'j2ee': 134,
#  'java': 135,
#  'javascript': 136,
#  'jee': 137,
#  'job': 138,
#  'jquery': 139,
#  'kafka': 140,
#  'knowledge': 141,
#  'knox': 142,
#  'lan': 143,
#  'lawson': 144,
#  'lead': 145,
#  'learning': 146,
#  'libraries': 147,
#  'library': 148,
#  'lifecycle': 149,
#  'linux': 150,
#  'logging': 151,
#  'machine': 152,
#  'management': 153,
#  'manager': 154,
#  'manufacturing': 155,
#  'mapping': 156,
#  'mapreduce': 157,
#  'marketing': 158,
#  'materials': 159,
#  'matlab': 160,
#  'mdm': 161,
#  'mentor': 162,
#  'metrics': 163,
#  'micro': 164,
#  'microsoft': 165,
#  'middleware': 166,
#  'migration': 167,
#  'mining': 168,
#  'model': 169,
#  'modeling': 170,
#  'models': 171,
#  'mongodb': 172,
#  'monitoring': 173,
#  'mr2': 174,
#  'ms': 175,
#  'multi': 176,
#  'mysql': 177,
#  'net': 178,
#  'netapp': 179,
#  'network': 180,
#  'networking': 181,
#  'networks': 182,
#  'nexus': 183,
#  'ninja': 184,
#  'nosql': 185,
#  'obiee': 186,
#  'objects': 187,
#  'office': 188,
#  'olap': 189,
#  'oozie': 190,
#  'open': 191,
#  'operations': 192,
#  'oracle': 193,
#  'outlook': 194,
#  'pc': 195,
#  'pentaho': 196,
#  'peoplesoft': 197,
#  'performance': 198,
#  'phoenix': 199,
#  'php': 200,
#  'pig': 201,
#  'pl': 202,
#  'planning': 203,
#  'platform': 204,
#  'point': 205,
#  'post': 206,
#  'postgres': 207,
#  'postgresql': 208,
#  'power': 209,
#  'powerpoint': 210,
#  'pre': 211,
#  'prism': 212,
#  'process': 213,
#  'production': 214,
#  'professional': 215,
#  'programmer': 216,
#  'programming': 217,
#  'project': 218,
#  'protocol': 219,
#  'publisher': 220,
#  'python': 221,
#  'qa': 222,
#  'quality': 223,
#  'queries': 224,
#  'query': 225,
#  'ranger': 226,
#  'rdbms': 227,
#  'refer': 228,
#  'release': 229,
#  'reporting': 230,
#  'reports': 231,
#  'requirements': 232,
#  'research': 233,
#  'risk': 234,
#  'route': 235,
#  'routing': 236,
#  'rpa': 237,
#  'sales': 238,
#  'salesforce': 239,
#  'sap': 240,
#  'sas': 241,
#  'scala': 242,
#  'science': 243,
#  'scientist': 244,
#  'scripting': 245,
#  'scripts': 246,
#  'scrum': 247,
#  'sdlc': 248,
#  'security': 249,
#  'senior': 250,
#  'series': 251,
#  'server': 252,
#  'service': 253,
#  'services': 254,
#  'sfdc': 255,
#  'shell': 256,
#  'skills': 257,
#  'software': 258,
#  'solr': 259,
#  'solutions': 260,
#  'source': 261,
#  'spark': 262,
#  'spotfire': 263,
#  'spring': 264,
#  'spss': 265,
#  'sql': 266,
#  'sqoop': 267,
#  'ssas': 268,
#  'ssis': 269,
#  'ssl': 270,
#  'ssrs': 271,
#  'stack': 272,
#  'statistical': 273,
#  'statistics': 274,
#  'storage': 275,
#  'strong': 276,
#  'strorage': 277,
#  'subversion': 278,
#  'supervision': 279,
#  'support': 280,
#  'surveillance': 281,
#  'switch': 282,
#  'systems': 283,
#  'tableau': 284,
#  'tcp': 285,
#  'technical': 286,
#  'technologies': 287,
#  'technology': 288,
#  'telecom': 289,
#  'telecommunications': 290,
#  'teradata': 291,
#  'testing': 292,
#  'threat': 293,
#  'tibco': 294,
#  'time': 295,
#  'tokenization': 296,
#  'tools': 297,
#  'trader': 298,
#  'uat': 299,
#  'ucs': 300,
#  'understanding': 301,
#  'unix': 302,
#  'ups': 303,
#  'usage': 304,
#  'use': 305,
#  'validation': 306,
#  'version': 307,
#  'video': 308,
#  'visual': 309,
#  'visualization': 310,
#  'visualizations': 311,
#  'vmware': 312,
#  'vpn': 313,
#  'vxlan': 314,
#  'wan': 315,
#  'warehouse': 316,
#  'warehousing': 317,
#  'web': 318,
#  'windows': 319,
#  'wireless': 320,
#  'written': 321,
#  'xml': 322,
#  'years': 323}

# %%
# 323 unique words are found , a matrix is created with one row each for 267 entries in job_info_ds (with 323 columns)
# every entry representing the frequency (of the word corresponding to that column) in the 
cvmatrix.todense().shape
# Out:
# (267, 324)

# %%
# adding up all the values in a given column will give the total number of times a word appears in the narrowed-down 323 joblistings  
dist = np.sum(cvmatrix.toarray(), axis=0)
word_count = {}
for tag, count in zip(cv.get_feature_names(), dist):
      word_count[tag] = count
sorted_cnts = pd.DataFrame(list(word_count.items()),columns=['Word','Count'])
sorted_cnts.sort_values(by=['Count'], ascending=False,inplace=True)
sorted_cnts.reset_index(drop=True)
# Out:
#               Word  Count
# 0             data    150
# 1              sql     87
# 2         analysis     80
# 3          analyst     68
# 4       management     63
# 5          project     60
# 6         business     58
# 7           hadoop     51
# 8      development     43
# 9         security     37
# 10        database     32
# 11            java     32
# 12           excel     31
# 13          python     31
# 14             big     30
# 15         manager     29
# 16    architecture     29
# 17          oracle     28
# 18        modeling     28
# 19       architect     24
# 20         testing     23
# 21           linux     22
# 22           cloud     22
# 23           agile     21
# 24       developer     17
# 25    intelligence     17
# 26        research     16
# 27              bi     16
# 28          server     16
# 29           spark     15
# ..             ...    ...
# 294           ccna      2
# 295            ssl      2
# 296          point      2
# 297       firewall      2
# 298            pre      2
# 299          refer      2
# 300     programmer      2
# 301       spotfire      2
# 302            asa      2
# 303      mapreduce      2
# 304           ssas      2
# 305       planning      2
# 306         jquery      2
# 307      publisher      2
# 308         google      2
# 309           flow      2
# 310         vmware      2
# 311           knox      2
# 312           blue      2
# 313             hr      2
# 314           olap      2
# 315            ups      2
# 316  manufacturing      2
# 317            emc      2
# 318       protocol      2
# 319         threat      2
# 320            aem      2
# 321     production      2
# 322         client      2
# 323    statistical      2
#
# [324 rows x 2 columns]

# %%
sorted_cnts[:50]
# Out:
#              Word  Count
# 209          data    150
# 214           sql     87
# 169      analysis     80
# 171       analyst     68
# 105    management     63
# 104       project     60
# 193      business     58
# 300        hadoop     51
# 22    development     43
# 65       security     37
# 123      database     32
# 21           java     32
# 68          excel     31
# 2          python     31
# 265           big     30
# 160       manager     29
# 215  architecture     29
# 275        oracle     28
# 260      modeling     28
# 101     architect     24
# 127       testing     23
# 239         linux     22
# 167         cloud     22
# 66          agile     21
# 115     developer     17
# 233  intelligence     17
# 183      research     16
# 97             bi     16
# 31         server     16
# 7           spark     15
# 306  requirements     15
# 280    analytical     14
# 8           mysql     13
# 76        tableau     13
# 184          hive     13
# 266     lifecycle     13
# 319    powerpoint     13
# 208    consulting     12
# 288       windows     12
# 162    experience     12
# 33            etl     12
# 230          unix     11
# 270        skills     11
# 222     microsoft     11
# 164         hbase     11
# 136            ms     11
# 181        mining     10
# 264       metrics      9
# 124        degree      9
# 43         access      9

# %%
# whoa! 'R' a no-show! how come ? also d3.js  ..trying min_df = 1
cv1 = CountVectorizer(min_df=1, stop_words='english')
# sparse representation of the counts using scipy.sparse.coo_matrix.
cvmatrix1 = cv1.fit_transform(job_info_ds['skill_set'])
cv1.vocabulary_
# Out:
# {'10': 0,
#  '11g': 1,
#  '12c': 2,
#  '256': 3,
#  '365': 4,
#  '3yrs': 5,
#  '837': 6,
#  'ab': 7,
#  'abinitio': 8,
#  'access': 9,
#  'accounting': 10,
#  'ace': 11,
#  'aci': 12,
#  'activities': 13,
#  'administration': 14,
#  'administrator': 15,
#  'adobe': 16,
#  'adoop': 17,
#  'aem': 18,
#  'agile': 19,
#  'ai': 20,
#  'airline': 21,
#  'aix': 22,
#  'ajax': 23,
#  'alpharetta': 24,
#  'alteryx': 25,
#  'alto': 26,
#  'amazon': 27,
#  'ambari': 28,
#  'aml': 29,
#  'analysis': 30,
#  'analyst': 31,
#  'analytical': 32,
#  'analytics': 33,
#  'apache': 34,
#  'apex': 35,
#  'api': 36,
#  'app': 37,
#  'application': 38,
#  'applications': 39,
#  'appropriate': 40,
#  'arcgis': 41,
#  'architect': 42,
#  'architecture': 43,
#  'architectures': 44,
#  'arcsde': 45,
#  'arcsight': 46,
#  'arima': 47,
#  'artificial': 48,
#  'asa': 49,
#  'asp': 50,
#  'atscale': 51,
#  'automated': 52,
#  'automation': 53,
#  'aws': 54,
#  'azure': 55,
#  'ba': 56,
#  'banking': 57,
#  'based': 58,
#  'bash': 59,
#  'basic': 60,
#  'bi': 61,
#  'big': 62,
#  'biginsights': 63,
#  'bigsql': 64,
#  'blue': 65,
#  'bo': 66,
#  'br': 67,
#  'brio': 68,
#  'broad': 69,
#  'bsm': 70,
#  'bteq': 71,
#  'build': 72,
#  'builder': 73,
#  'building': 74,
#  'business': 75,
#  'capacity': 76,
#  'case': 77,
#  'cash': 78,
#  'cassandra': 79,
#  'catalyst': 80,
#  'ccie': 81,
#  'ccna': 82,
#  'ccnp': 83,
#  'ceh': 84,
#  'center': 85,
#  'centre': 86,
#  'centric': 87,
#  'cgi': 88,
#  'chain': 89,
#  'change': 90,
#  'changepoint': 91,
#  'charting': 92,
#  'checkpoint': 93,
#  'cisa': 94,
#  'cisco': 95,
#  'cissp': 96,
#  'civil': 97,
#  'claims': 98,
#  'clerk': 99,
#  'client': 100,
#  'cloud': 101,
#  'cloudera': 102,
#  'cluster': 103,
#  'clustering': 104,
#  'clusters': 105,
#  'cms': 106,
#  'code': 107,
#  'codeigniter': 108,
#  'collaboration': 109,
#  'collection': 110,
#  'com': 111,
#  'combined': 112,
#  'commerce': 113,
#  'communication': 114,
#  'compliance': 115,
#  'computer': 116,
#  'computing': 117,
#  'consultant': 118,
#  'consulting': 119,
#  'containers': 120,
#  'contract': 121,
#  'control': 122,
#  'controls': 123,
#  'coordination': 124,
#  'cplex': 125,
#  'craft': 126,
#  'crm': 127,
#  'crystal': 128,
#  'css': 129,
#  'cto': 130,
#  'cubes': 131,
#  'custom': 132,
#  'customer': 133,
#  'cyber': 134,
#  'dashboards': 135,
#  'data': 136,
#  'database': 137,
#  'databases': 138,
#  'datapower': 139,
#  'db': 140,
#  'db2': 141,
#  'dba': 142,
#  'dc': 143,
#  'degree': 144,
#  'delivery': 145,
#  'dependency': 146,
#  'description': 147,
#  'design': 148,
#  'desk': 149,
#  'desktop': 150,
#  'developer': 151,
#  'developing': 152,
#  'development': 153,
#  'devops': 154,
#  'diagnostic': 155,
#  'dialysis': 156,
#  'dining': 157,
#  'director': 158,
#  'disaster': 159,
#  'django': 160,
#  'dns': 161,
#  'docker': 162,
#  'documentation': 163,
#  'driven': 164,
#  'drools': 165,
#  'dynamics': 166,
#  'ebs': 167,
#  'ecommerce': 168,
#  'ecosystem': 169,
#  'edi': 170,
#  'editing': 171,
#  'elastic': 172,
#  'emc': 173,
#  'emerging': 174,
#  'encase': 175,
#  'encounter': 176,
#  'encryption': 177,
#  'engineer': 178,
#  'engineering': 179,
#  'ensure': 180,
#  'enterprise': 181,
#  'entry': 182,
#  'environments': 183,
#  'epmo': 184,
#  'erp': 185,
#  'errors': 186,
#  'erwin': 187,
#  'esri': 188,
#  'etl': 189,
#  'excel': 190,
#  'excellence': 191,
#  'excellent': 192,
#  'exchange': 193,
#  'exp': 194,
#  'experience': 195,
#  'expertise': 196,
#  'exposure': 197,
#  'expressionengine': 198,
#  'extensive': 199,
#  'eye': 200,
#  'f5': 201,
#  'facing': 202,
#  'factory': 203,
#  'farming': 204,
#  'fastexport': 205,
#  'fastload': 206,
#  'financial': 207,
#  'financials': 208,
#  'firewall': 209,
#  'firewalls': 210,
#  'fixing': 211,
#  'flow': 212,
#  'flowchart': 213,
#  'flume': 214,
#  'force': 215,
#  'formats': 216,
#  'foundation': 217,
#  'framework': 218,
#  'frameworks': 219,
#  'fraud': 220,
#  'functional': 221,
#  'ga': 222,
#  'gartner': 223,
#  'gathering': 224,
#  'gen': 225,
#  'generic': 226,
#  'genetic': 227,
#  'geodatabase': 228,
#  'giac': 229,
#  'gis': 230,
#  'gisp': 231,
#  'git': 232,
#  'github': 233,
#  'good': 234,
#  'google': 235,
#  'graphs': 236,
#  'grid': 237,
#  'gui': 238,
#  'hadoop': 239,
#  'hana': 240,
#  'hardware': 241,
#  'hbase': 242,
#  'hcatalog': 243,
#  'hcm': 244,
#  'hdfs': 245,
#  'help': 246,
#  'heroku': 247,
#  'hibernate': 248,
#  'highways': 249,
#  'hire': 250,
#  'hive': 251,
#  'horton': 252,
#  'hortonworks': 253,
#  'host': 254,
#  'hp': 255,
#  'hql': 256,
#  'hr': 257,
#  'http': 258,
#  'hub': 259,
#  'hyptertext': 260,
#  'ibm': 261,
#  'iii': 262,
#  'image': 263,
#  'impala': 264,
#  'implementation': 265,
#  'implementations': 266,
#  'implementing': 267,
#  'industrial': 268,
#  'informatica': 269,
#  'information': 270,
#  'infosphere': 271,
#  'infrastructure': 272,
#  'initio': 273,
#  'insight': 274,
#  'inte': 275,
#  'integration': 276,
#  'intelligence': 277,
#  'interface': 278,
#  'internals': 279,
#  'ip': 280,
#  'iterative': 281,
#  'iv': 282,
#  'j2ee': 283,
#  'jad': 284,
#  'java': 285,
#  'javascript': 286,
#  'jde': 287,
#  'jee': 288,
#  'jenkins': 289,
#  'job': 290,
#  'jquery': 291,
#  'json': 292,
#  'juniper': 293,
#  'kafka': 294,
#  'kennesaw': 295,
#  'kerebos': 296,
#  'knowledge': 297,
#  'knox': 298,
#  'korn': 299,
#  'kount': 300,
#  'kpi': 301,
#  'kubernetes': 302,
#  'kylin': 303,
#  'kyvos': 304,
#  'lamp': 305,
#  'lan': 306,
#  'lancope': 307,
#  'lawson': 308,
#  'lead': 309,
#  'learning': 310,
#  'libraries': 311,
#  'library': 312,
#  'lifecycle': 313,
#  'like': 314,
#  'linux': 315,
#  'logging': 316,
#  'logistics': 317,
#  'looking': 318,
#  'lpt': 319,
#  'machine': 320,
#  'manag': 321,
#  'manage': 322,
#  'management': 323,
#  'manager': 324,
#  'managing': 325,
#  'manipulation': 326,
#  'manual': 327,
#  'manufacturing': 328,
#  'mapping': 329,
#  'mapreduce': 330,
#  'marketing': 331,
#  'master': 332,
#  'materials': 333,
#  'matlab': 334,
#  'mcp': 335,
#  'md5': 336,
#  'mdm': 337,
#  'medicaid': 338,
#  'medicare': 339,
#  'mentor': 340,
#  'metrics': 341,
#  'micro': 342,
#  'microsoft': 343,
#  'microstrategy': 344,
#  'middleware': 345,
#  'migration': 346,
#  'mining': 347,
#  'mitigation': 348,
#  'mload': 349,
#  'model': 350,
#  'modeling': 351,
#  'models': 352,
#  'moderately': 353,
#  'mongo': 354,
#  'mongodb': 355,
#  'monitoring': 356,
#  'month': 357,
#  'moveit': 358,
#  'mps': 359,
#  'mr2': 360,
#  'ms': 361,
#  'mssql': 362,
#  'mulesoft': 363,
#  'multi': 364,
#  'mysql': 365,
#  'net': 366,
#  'netapp': 367,
#  'netezza': 368,
#  'network': 369,
#  'networking': 370,
#  'networks': 371,
#  'nexus': 372,
#  'nfs': 373,
#  'ninja': 374,
#  'nosql': 375,
#  'obiee': 376,
#  'objects': 377,
#  'office': 378,
#  'olap': 379,
#  'omniture': 380,
#  'onboarding': 381,
#  'oozie': 382,
#  'open': 383,
#  'operate': 384,
#  'operational': 385,
#  'operations': 386,
#  'operator': 387,
#  'optimizing': 388,
#  'oracle': 389,
#  'oral': 390,
#  'order': 391,
#  'oscp': 392,
#  'outlook': 393,
#  'overview': 394,
#  'packages': 395,
#  'packaging': 396,
#  'palo': 397,
#  'paloalto': 398,
#  'pay': 399,
#  'payment': 400,
#  'pc': 401,
#  'penetration': 402,
#  'pentaho': 403,
#  'pentester': 404,
#  'peoplesoft': 405,
#  'performance': 406,
#  'perl': 407,
#  'permit': 408,
#  'phoenix': 409,
#  'php': 410,
#  'pig': 411,
#  'pl': 412,
#  'planning': 413,
#  'plans': 414,
#  'platform': 415,
#  'plsql': 416,
#  'pmo': 417,
#  'pmp': 418,
#  'point': 419,
#  'points': 420,
#  'portals': 421,
#  'portfolio': 422,
#  'post': 423,
#  'postgres': 424,
#  'postgresql': 425,
#  'power': 426,
#  'powerbi': 427,
#  'powerpoint': 428,
#  'powershell': 429,
#  'ppm': 430,
#  'pre': 431,
#  'presales': 432,
#  'pricing': 433,
#  'prism': 434,
#  'procedures': 435,
#  'process': 436,
#  'processes': 437,
#  'processing': 438,
#  'procure': 439,
#  'production': 440,
#  'professional': 441,
#  'programmer': 442,
#  'programming': 443,
#  'project': 444,
#  'protocol': 445,
#  'protocols': 446,
#  'publish': 447,
#  'publisher': 448,
#  'python': 449,
#  'qa': 450,
#  'qc': 451,
#  'qlik': 452,
#  'qlikview': 453,
#  'quality': 454,
#  'queries': 455,
#  'query': 456,
#  'rac': 457,
#  'rackspace': 458,
#  'ranger': 459,
#  'rating': 460,
#  'rational': 461,
#  'rdbms': 462,
#  'readiness': 463,
#  'recovery': 464,
#  'recruiter': 465,
#  'redhat': 466,
#  'refer': 467,
#  'relational': 468,
#  'release': 469,
#  'replication': 470,
#  'reporting': 471,
#  'reports': 472,
#  'requirement': 473,
#  'requirements': 474,
#  'research': 475,
#  'resource': 476,
#  'responsibilities': 477,
#  'respositories': 478,
#  'retail': 479,
#  'risk': 480,
#  'rman': 481,
#  'roads': 482,
#  'route': 483,
#  'routing': 484,
#  'rpa': 485,
#  'saas': 486,
#  'sale': 487,
#  'sales': 488,
#  'salesforce': 489,
#  'sap': 490,
#  'sas': 491,
#  'scala': 492,
#  'scheduler': 493,
#  'scheduling': 494,
#  'schema': 495,
#  'science': 496,
#  'scientist': 497,
#  'scrapinghub': 498,
#  'scripting': 499,
#  'scripts': 500,
#  'scrum': 501,
#  'sde': 502,
#  'sdlc': 503,
#  'search': 504,
#  'security': 505,
#  'senior': 506,
#  'series': 507,
#  'server': 508,
#  'service': 509,
#  'services': 510,
#  'sf': 511,
#  'sfdc': 512,
#  'sha': 513,
#  'sharepoint': 514,
#  'shell': 515,
#  'simulation': 516,
#  'skills': 517,
#  'sna': 518,
#  'snowflake': 519,
#  'soa': 520,
#  'soap': 521,
#  'soc': 522,
#  'software': 523,
#  'solr': 524,
#  'solution': 525,
#  'solutions': 526,
#  'source': 527,
#  'sources': 528,
#  'spark': 529,
#  'spera': 530,
#  'splunk': 531,
#  'spotfire': 532,
#  'spring': 533,
#  'spss': 534,
#  'sql': 535,
#  'sqlite': 536,
#  'sqoop': 537,
#  'ssas': 538,
#  'ssh': 539,
#  'ssis': 540,
#  'ssl': 541,
#  'ssrs': 542,
#  'stack': 543,
#  'star': 544,
#  'statistical': 545,
#  'statistics': 546,
#  'stealth': 547,
#  'storage': 548,
#  'store': 549,
#  'stored': 550,
#  'storm': 551,
#  'strong': 552,
#  'strorage': 553,
#  'structures': 554,
#  'struts': 555,
#  'studio': 556,
#  'submission': 557,
#  'subscribe': 558,
#  'subversion': 559,
#  'sun': 560,
#  'supervision': 561,
#  'supervisor': 562,
#  'supply': 563,
#  'support': 564,
#  'supporting': 565,
#  'surveillance': 566,
#  'switch': 567,
#  'switching': 568,
#  'synthetic': 569,
#  'syspro': 570,
#  'systems': 571,
#  'tableau': 572,
#  'tanium': 573,
#  'tcp': 574,
#  'tdch': 575,
#  'tdm': 576,
#  'team': 577,
#  'technical': 578,
#  'technician': 579,
#  'technologies': 580,
#  'technology': 581,
#  'techologies': 582,
#  'telecom': 583,
#  'telecommunications': 584,
#  'teradata': 585,
#  'test': 586,
#  'testing': 587,
#  'tfs': 588,
#  'threading': 589,
#  'threat': 590,
#  'tibco': 591,
#  'time': 592,
#  'tipping': 593,
#  'tls': 594,
#  'toad': 595,
#  'togaf': 596,
#  'tokenization': 597,
#  'tomcat': 598,
#  'tool': 599,
#  'tools': 600,
#  'tpt': 601,
#  'trader': 602,
#  'transport': 603,
#  'tuning': 604,
#  'typical': 605,
#  'uat': 606,
#  'ucs': 607,
#  'ui': 608,
#  'understanding': 609,
#  'unix': 610,
#  'unstructured': 611,
#  'ups': 612,
#  'usage': 613,
#  'use': 614,
#  'user': 615,
#  'using': 616,
#  'ux': 617,
#  'validation': 618,
#  'vb': 619,
#  'vbscript': 620,
#  'verbal': 621,
#  'version': 622,
#  'vertica': 623,
#  'video': 624,
#  'visual': 625,
#  'visualization': 626,
#  'visualizations': 627,
#  'vmware': 628,
#  'vpn': 629,
#  'vss': 630,
#  'vulnerability': 631,
#  'vxlan': 632,
#  'wan': 633,
#  'warehouse': 634,
#  'warehousing': 635,
#  'watch': 636,
#  'wave': 637,
#  'web': 638,
#  'weblogs': 639,
#  'windows': 640,
#  'wireless': 641,
#  'wms': 642,
#  'word': 643,
#  'work': 644,
#  'workflow': 645,
#  'works': 646,
#  'world': 647,
#  'writing': 648,
#  'written': 649,
#  'xml': 650,
#  'xp': 651,
#  'xslt': 652,
#  'years': 653,
#  'zachman': 654,
#  'zookeeper': 655}

# %%
job_info_ds[job_info_ds['skill_set'].apply(lambda skill : 'd3' in skill)]
# Out:
# Empty DataFrame
# Columns: [job_title, skill_set, employment_type]
# Index: []

# %%
job_info_ds[job_info_ds['skill_set'].apply(lambda skill : ' R' in skill or 'R 'in skill)]
# Out:
#                                              job_title  \
# 3                                       Data Scientist
# 14                                 Data Scientist - GA
# 17                           Data Analyst-DBA and DBSA
# 23                          Big Data Platform Engineer
# 24                                         Data Mapper
# 33                                      Data Scientist
# 44                                 Data Scientist - GA
# 47                           Data Analyst-DBA and DBSA
# 53                          Big Data Platform Engineer
# 54                                         Data Mapper
# 66                       Solution Architect (Big Data)
# 67                           Enterprise Data Architect
# 71                                  Big Data Architect
# 72                       Data Center Network Architect
# 74                                      Data Architect
# 81            Linux System Data Center Design Engineer
# 91                                Revenue Data Analyst
# 96                                  Big Data Architect
# 102                             Data Reporting Analyst
# 105      Data Analyst Lead - Monitoring Tools Resource
# 116                      Data Center Network Architect
# 117                      Data Center Network Architect
# 123                Data Analyst/Reports Developer (05)
# 126  Financial Data Reporting Analyst // 6 Month Co...
# 131        Computer Operator (Data Center) - 3rd Shift
# 132                       Data Center Architect for GA
# 135                               Senior UX Researcher
# 138                   Senior Project/Marketing Analyst
# 139                                       Statistician
# 141                         Security Analytics Manager
# ..                                                 ...
# 152    Business Analyst - Software - Actimize division
# 156                                   Business Analyst
# 160                             BI Analytics Developer
# 163                          Digital Analytics Manager
# 166                                    Hadoop Engineer
# 167                                   Business Analyst
# 205                          Advanced Business Analyst
# 213                         Technical Business Analyst
# 225                       Information Security Analyst
# 250                                L3 Business Analyst
# 261              Esri ArcSDE Geodatabase Administrator
# 269  Application Developer./Business Intelligence D...
# 292                      Information Security Engineer
# 298              Technical Application Support Analyst
# 300                        Tableau, BO, HANA Reporting
# 334                                   Hadoop Architect
# 342                      Business Analyst - Salesforce
# 348                    Business Intelligence Developer
# 371                  Senior Technical Business Analyst
# 424                 Senior Salesforce Business Analyst
# 425                 Senior Salesforce Business Analyst
# 463              Operational Policy Research Associate
# 470                              Lead Business Analyst
# 508                         Security Analyst (MID SOC)
# 512                         Technical Business Analyst
# 517                         Business / Reports Analyst
# 574                     Hadoop Developer/Administrator
# 669                  Director - Information Technology
# 689  Loss Mitigation and Workout Analyst, Merchant ...
# 743                          System Programmer Analyst
#
#                                              skill_set  \
# 3         Python, Time Series, Cloud, Data Modeling, R
# 14        Data Science, Marketing Analytics, Hadoop, R
# 17   Agile, Analysis, Analyst, Database, Database A...
# 23   Agile, Analysis, Architecture, Business Requir...
# 24   Analytical Skills, Business Requirements, CGI,...
# 33        Python, Time Series, Cloud, Data Modeling, R
# 44        Data Science, Marketing Analytics, Hadoop, R
# 47   Agile, Analysis, Analyst, Database, Database A...
# 53   Agile, Analysis, Architecture, Business Requir...
# 54   Analytical Skills, Business Requirements, CGI,...
# 66   Solution Architecture, Big Data, RDBMS (Data W...
# 67   Azure, SSAS, SSIS, PowerShell, Automation, R-S...
# 71   Big Data, Hadoop, Oracle, SQL, MySQL, Pentaho,...
# 72   Data Center, Network, Route, Switch, Nexus, UC...
# 74   Architecture, Business Requirements, CTO, Deve...
# 81                     Linux and Shell OR bash OR korn
# 91   Accounting, Analysis, Analyst, Brio, Database,...
# 96   Big Data/Hadoop Architecture, IBM BigInsights ...
# 102  MS Excel, Power Query, Charting Tools, SharePo...
# 105  Data Analyst, Monitoring Tools Resource, Synth...
# 116  NEXUS, ROUTE, SWITCH, APPLICATION CENTRIC INFR...
# 117  NEXUS, ROUTE, SWITCH, APPLICATION CENTRIC INFR...
# 123          Data Analyst, SQL, Access, Excel, Reports
# 126  Financial Data Reporting Analyst // 6 Month Co...
# 131  AIX, Automated, Call Center, Change Management...
# 132     DC Architecture, Nexus, R&S and WAN networking
# 135  Agile, Analysis, Data Collection, Development,...
# 138  Analysis, Analyst, Data Analysis, Excel, Manag...
# 139  Analysis, Analytical Skills, Capacity Planning...
# 141  Analysis, Business Intelligence, Civil, Data M...
# ..                                                 ...
# 152  Analysis, Analyst, Business Analyst, Business ...
# 156  Agile, Analysis, Analyst, Analytical Skills, B...
# 160  BI  ETL  SQL  MicroSoft SSIS Big Data MicroSof...
# 163  Adobe, Analysis, Data Analysis, Director, Exce...
# 166  Java, J2EE \tHadoop, HCatalog, HDFS,Hive, Pig,...
# 167  Business Analyst, Business Process, Requiremen...
# 205  Agile, Analysis, Analyst, Business Analyst, Cu...
# 213  Agile, Analysis, Analyst, Business Analyst, Da...
# 225  hadoop, Big Data, AWS, Cloud, Security, Java, ...
# 250  Analysis, Analyst, Architecture, Business Anal...
# 261  ArcGIS with geodatabase development, editing, ...
# 269  Excellent Verbal,Written Communication skills....
# 292                               (SECURITY ENGINEER )
# 298  Analysis, Analyst, Cisco, CMS, Consulting, Cus...
# 300                        Tableau, BO, Hana Reporting
# 334  Architecture, Business Requirements, Developme...
# 342  SFDC, Salesforce, Force.com, SF.com, Salesforc...
# 348               OBIEE ,PL/SQL , BI Publisher Reports
# 371  Analyst, Business Analyst, Business Requiremen...
# 424  SalesForce, SFDC, Business Analysis, Client Fa...
# 425  SalesForce, SFDC, Business Analysis, Client Fa...
# 463  Analysis, Development, Director, Hub, Manager,...
# 470  Agile, Analysis, Analyst, Analytical Skills, A...
# 508  Lancope (Stealth Watch), PaloAlto Next Gen Fir...
# 512              SQL, Requirements gathering, Analysis
# 517  Crystal Reports, Requirements Gathering, Manuf...
# 574  adoop Cluster Administration 3. Hadoop Securit...
# 669  Salesforce, LAMP technologies (Linux-Apache-My...
# 689  Accounting, Analysis, Analyst, Excel, Hub, Man...
# 743                                         SQL, RDBMS
#
#                                        employment_type
# 3                                            Full Time
# 14                                         Contract W2
# 17                                           Full Time
# 23                                           Full Time
# 24                                           Full Time
# 33                                           Full Time
# 44                                         Contract W2
# 47                                           Full Time
# 53                                           Full Time
# 54                                           Full Time
# 66                                           Full Time
# 67                                           Full Time
# 71                                           Full Time
# 72                                           Full Time
# 74                                           Full Time
# 81                                           Full Time
# 91   Contract Corp-To-Corp, Contract Independent, C...
# 96                               Contract Corp-To-Corp
# 102  Contract Corp-To-Corp, Contract Independent, C...
# 105  Full Time, Contract Corp-To-Corp, Contract Ind...
# 116                              Contract Corp-To-Corp
# 117                                        Contract W2
# 123                                        Contract W2
# 126                            C2H Independent, C2H W2
# 131  Contract Independent, Contract W2, C2H Indepen...
# 132                                        Contract W2
# 135                                          Full Time
# 138                                          Full Time
# 139                                          Full Time
# 141                                          Full Time
# ..                                                 ...
# 152                                          Full Time
# 156                                          Full Time
# 160                                          Full Time
# 163                                          Full Time
# 166                                          Full Time
# 167                                          Full Time
# 205  Contract Corp-To-Corp, Contract Independent, C...
# 213  Contract Independent, Contract W2, C2H Indepen...
# 225                                        Contract W2
# 250                                          Full Time
# 261  Contract Corp-To-Corp, Contract Independent, C...
# 269  Contract Corp-To-Corp, Contract Independent, C...
# 292          C2H Corp-To-Corp, C2H Independent, C2H W2
# 298                                          Full Time
# 300                 Contract Corp-To-Corp, Contract W2
# 334                                          Full Time
# 342                                        Contract W2
# 348                                        Contract W2
# 371                                          Full Time
# 424                                             C2H W2
# 425  Contract Corp-To-Corp, Contract Independent, C...
# 463                                          Full Time
# 470                                          Full Time
# 508                                          Full Time
# 512                                          Full Time
# 517                                          Full Time
# 574                 Contract Corp-To-Corp, Contract W2
# 669                                          Full Time
# 689                                          Full Time
# 743                                          Full Time
#
# [61 rows x 3 columns]

# %%
print(cv)
# Out:
# CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=2,
#         ngram_range=(1, 1), preprocessor=None, stop_words='english',
#         strip_accents=None, token_pattern='(?u)\\b\\w\\w+\\b',
#         tokenizer=None, vocabulary=None)

# %%
# note that CountVectorizer discards "words" that contain only one character, such as "R"
# CountVectorizer also transforms all words into lowercase
cv1 = CountVectorizer(min_df=2, stop_words='english')
tokenize = cv1.build_tokenizer()
tokenize("Python, Time Series, Cloud, Data Modeling, R")
# Out:
# ['Python', 'Time', 'Series', 'Cloud', 'Data', 'Modeling']

# %%
# many programming languages are just one character long , 'R' , 'C' 
# tweaking the 'token_pattern' parameter to include 'R' or 'C'
# Testing the new pattern
cv1 = CountVectorizer(min_df=1, stop_words='english', token_pattern=r'(?u)\b\w\w+\b|r|c' ,tokenizer=None)
tokenize = cv1.build_tokenizer()
tokenize("Python, Time Series, Cloud, R ,Data Modeling")
# Out:
# ['Python', 'Time', 'Series', 'Cloud', 'Data', 'Modeling']

# %%
#cvmatrix1 = cv1.fit_transform(job_info_ds['skill_set'])
cvmatrix1 = cv1.fit_transform(["Python, Time Series, Cloud, Data Modeling, R"])
cv1.vocabulary_
# Out:
# {'cloud': 0,
#  'data': 1,
#  'modeling': 2,
#  'python': 3,
#  'r': 4,
#  'series': 5,
#  'time': 6}

# %%
R_job_ds = job_info_ds[job_info_ds['skill_set'].apply(lambda skill : ' R' in skill or 'R 'in skill)]

# %%
# correcting the token_pattern 
#cv1 = CountVectorizer(min_df=2, stop_words='english', token_pattern=r'(?u)\b\w\w+\b|r|c' ,tokenizer=None)
cv1 = CountVectorizer(min_df=1, stop_words='english', token_pattern=r'(?u)\b\w\w+\b|[r]$' ,tokenizer=None)
#cvmatrix1 = cv1.fit_transform(job_info_ds['skill_set'])
#cvmatrix1 = cv1.fit_transform(["Python, Time Series, Cloud, Data Modeling, R","OBIEE ,PL/SQL , BI Publisher Reports","DC Architecture, Nexus, R&S and WAN networking"])
cvmatrix1 = cv1.fit_transform(R_job_ds['skill_set'])
dist = np.sum(cvmatrix1.toarray(), axis=0)
word_count = {}
for tag, count in zip(cv1.get_feature_names(), dist):
      word_count[tag] = count
sorted_cnts1 = pd.DataFrame(list(word_count.items()),columns=['Word','Count'])
sorted_cnts1.sort_values(by=['Count'], ascending=False,inplace=True)
sorted_cnts1.reset_index(drop=True)
sorted_cnts1[sorted_cnts1['Word'] == 'r']
# Out:
#    Word  Count
# 99    r      4

# %%
job_info_ds[job_info_ds['skill_set'].apply(lambda skill : ' R' in skill or 'R 'in skill)]
# Out:
#                                              job_title  \
# 3                                       Data Scientist
# 14                                 Data Scientist - GA
# 17                           Data Analyst-DBA and DBSA
# 23                          Big Data Platform Engineer
# 24                                         Data Mapper
# 33                                      Data Scientist
# 44                                 Data Scientist - GA
# 47                           Data Analyst-DBA and DBSA
# 53                          Big Data Platform Engineer
# 54                                         Data Mapper
# 66                       Solution Architect (Big Data)
# 67                           Enterprise Data Architect
# 71                                  Big Data Architect
# 72                       Data Center Network Architect
# 74                                      Data Architect
# 81            Linux System Data Center Design Engineer
# 91                                Revenue Data Analyst
# 96                                  Big Data Architect
# 102                             Data Reporting Analyst
# 105      Data Analyst Lead - Monitoring Tools Resource
# 116                      Data Center Network Architect
# 117                      Data Center Network Architect
# 123                Data Analyst/Reports Developer (05)
# 126  Financial Data Reporting Analyst // 6 Month Co...
# 131        Computer Operator (Data Center) - 3rd Shift
# 132                       Data Center Architect for GA
# 135                               Senior UX Researcher
# 138                   Senior Project/Marketing Analyst
# 139                                       Statistician
# 141                         Security Analytics Manager
# ..                                                 ...
# 152    Business Analyst - Software - Actimize division
# 156                                   Business Analyst
# 160                             BI Analytics Developer
# 163                          Digital Analytics Manager
# 166                                    Hadoop Engineer
# 167                                   Business Analyst
# 205                          Advanced Business Analyst
# 213                         Technical Business Analyst
# 225                       Information Security Analyst
# 250                                L3 Business Analyst
# 261              Esri ArcSDE Geodatabase Administrator
# 269  Application Developer./Business Intelligence D...
# 292                      Information Security Engineer
# 298              Technical Application Support Analyst
# 300                        Tableau, BO, HANA Reporting
# 334                                   Hadoop Architect
# 342                      Business Analyst - Salesforce
# 348                    Business Intelligence Developer
# 371                  Senior Technical Business Analyst
# 424                 Senior Salesforce Business Analyst
# 425                 Senior Salesforce Business Analyst
# 463              Operational Policy Research Associate
# 470                              Lead Business Analyst
# 508                         Security Analyst (MID SOC)
# 512                         Technical Business Analyst
# 517                         Business / Reports Analyst
# 574                     Hadoop Developer/Administrator
# 669                  Director - Information Technology
# 689  Loss Mitigation and Workout Analyst, Merchant ...
# 743                          System Programmer Analyst
#
#                                              skill_set  \
# 3         Python, Time Series, Cloud, Data Modeling, R
# 14        Data Science, Marketing Analytics, Hadoop, R
# 17   Agile, Analysis, Analyst, Database, Database A...
# 23   Agile, Analysis, Architecture, Business Requir...
# 24   Analytical Skills, Business Requirements, CGI,...
# 33        Python, Time Series, Cloud, Data Modeling, R
# 44        Data Science, Marketing Analytics, Hadoop, R
# 47   Agile, Analysis, Analyst, Database, Database A...
# 53   Agile, Analysis, Architecture, Business Requir...
# 54   Analytical Skills, Business Requirements, CGI,...
# 66   Solution Architecture, Big Data, RDBMS (Data W...
# 67   Azure, SSAS, SSIS, PowerShell, Automation, R-S...
# 71   Big Data, Hadoop, Oracle, SQL, MySQL, Pentaho,...
# 72   Data Center, Network, Route, Switch, Nexus, UC...
# 74   Architecture, Business Requirements, CTO, Deve...
# 81                     Linux and Shell OR bash OR korn
# 91   Accounting, Analysis, Analyst, Brio, Database,...
# 96   Big Data/Hadoop Architecture, IBM BigInsights ...
# 102  MS Excel, Power Query, Charting Tools, SharePo...
# 105  Data Analyst, Monitoring Tools Resource, Synth...
# 116  NEXUS, ROUTE, SWITCH, APPLICATION CENTRIC INFR...
# 117  NEXUS, ROUTE, SWITCH, APPLICATION CENTRIC INFR...
# 123          Data Analyst, SQL, Access, Excel, Reports
# 126  Financial Data Reporting Analyst // 6 Month Co...
# 131  AIX, Automated, Call Center, Change Management...
# 132     DC Architecture, Nexus, R&S and WAN networking
# 135  Agile, Analysis, Data Collection, Development,...
# 138  Analysis, Analyst, Data Analysis, Excel, Manag...
# 139  Analysis, Analytical Skills, Capacity Planning...
# 141  Analysis, Business Intelligence, Civil, Data M...
# ..                                                 ...
# 152  Analysis, Analyst, Business Analyst, Business ...
# 156  Agile, Analysis, Analyst, Analytical Skills, B...
# 160  BI  ETL  SQL  MicroSoft SSIS Big Data MicroSof...
# 163  Adobe, Analysis, Data Analysis, Director, Exce...
# 166  Java, J2EE \tHadoop, HCatalog, HDFS,Hive, Pig,...
# 167  Business Analyst, Business Process, Requiremen...
# 205  Agile, Analysis, Analyst, Business Analyst, Cu...
# 213  Agile, Analysis, Analyst, Business Analyst, Da...
# 225  hadoop, Big Data, AWS, Cloud, Security, Java, ...
# 250  Analysis, Analyst, Architecture, Business Anal...
# 261  ArcGIS with geodatabase development, editing, ...
# 269  Excellent Verbal,Written Communication skills....
# 292                               (SECURITY ENGINEER )
# 298  Analysis, Analyst, Cisco, CMS, Consulting, Cus...
# 300                        Tableau, BO, Hana Reporting
# 334  Architecture, Business Requirements, Developme...
# 342  SFDC, Salesforce, Force.com, SF.com, Salesforc...
# 348               OBIEE ,PL/SQL , BI Publisher Reports
# 371  Analyst, Business Analyst, Business Requiremen...
# 424  SalesForce, SFDC, Business Analysis, Client Fa...
# 425  SalesForce, SFDC, Business Analysis, Client Fa...
# 463  Analysis, Development, Director, Hub, Manager,...
# 470  Agile, Analysis, Analyst, Analytical Skills, A...
# 508  Lancope (Stealth Watch), PaloAlto Next Gen Fir...
# 512              SQL, Requirements gathering, Analysis
# 517  Crystal Reports, Requirements Gathering, Manuf...
# 574  adoop Cluster Administration 3. Hadoop Securit...
# 669  Salesforce, LAMP technologies (Linux-Apache-My...
# 689  Accounting, Analysis, Analyst, Excel, Hub, Man...
# 743                                         SQL, RDBMS
#
#                                        employment_type
# 3                                            Full Time
# 14                                         Contract W2
# 17                                           Full Time
# 23                                           Full Time
# 24                                           Full Time
# 33                                           Full Time
# 44                                         Contract W2
# 47                                           Full Time
# 53                                           Full Time
# 54                                           Full Time
# 66                                           Full Time
# 67                                           Full Time
# 71                                           Full Time
# 72                                           Full Time
# 74                                           Full Time
# 81                                           Full Time
# 91   Contract Corp-To-Corp, Contract Independent, C...
# 96                               Contract Corp-To-Corp
# 102  Contract Corp-To-Corp, Contract Independent, C...
# 105  Full Time, Contract Corp-To-Corp, Contract Ind...
# 116                              Contract Corp-To-Corp
# 117                                        Contract W2
# 123                                        Contract W2
# 126                            C2H Independent, C2H W2
# 131  Contract Independent, Contract W2, C2H Indepen...
# 132                                        Contract W2
# 135                                          Full Time
# 138                                          Full Time
# 139                                          Full Time
# 141                                          Full Time
# ..                                                 ...
# 152                                          Full Time
# 156                                          Full Time
# 160                                          Full Time
# 163                                          Full Time
# 166                                          Full Time
# 167                                          Full Time
# 205  Contract Corp-To-Corp, Contract Independent, C...
# 213  Contract Independent, Contract W2, C2H Indepen...
# 225                                        Contract W2
# 250                                          Full Time
# 261  Contract Corp-To-Corp, Contract Independent, C...
# 269  Contract Corp-To-Corp, Contract Independent, C...
# 292          C2H Corp-To-Corp, C2H Independent, C2H W2
# 298                                          Full Time
# 300                 Contract Corp-To-Corp, Contract W2
# 334                                          Full Time
# 342                                        Contract W2
# 348                                        Contract W2
# 371                                          Full Time
# 424                                             C2H W2
# 425  Contract Corp-To-Corp, Contract Independent, C...
# 463                                          Full Time
# 470                                          Full Time
# 508                                          Full Time
# 512                                          Full Time
# 517                                          Full Time
# 574                 Contract Corp-To-Corp, Contract W2
# 669                                          Full Time
# 689                                          Full Time
# 743                                          Full Time
#
# [61 rows x 3 columns]

# %% [markdown]
# That looks about right!

# %%
# looks like we need to capture 2-word phrases like big data , time series etc , hence setting ngram_range = (1,2) 
cv1 = CountVectorizer(min_df=2, stop_words='english', token_pattern=r'(?u)\b\w\w+\b|[r]$' ,tokenizer=None, ngram_range=(1, 2))
cvmatrix1 = cv1.fit_transform(job_info_ds['skill_set'])
dist = np.sum(cvmatrix1.toarray(), axis=0)
word_count = {}
for tag, count in zip(cv1.get_feature_names(), dist):
      word_count[tag] = count
sorted_cnts1 = pd.DataFrame(list(word_count.items()),columns=['Word','Count'])
sorted_cnts1.sort_values(by=['Count'], ascending=False,inplace=True)
sorted_cnts1.head(50)
# Out:
#                       Word  Count
# 283                   data    150
# 500                    sql     87
# 98                analysis     80
# 99                 analyst     68
# 232             management     63
# 487                project     60
# 277               business     58
# 167                 hadoop     51
# 194            development     43
# 211               security     37
# 236               database     32
# 193                   java     32
# 185                 python     31
# 212                  excel     31
# 228                    big     30
# 10            architecture     29
# 445                manager     29
# 163               big data     29
# 436                 oracle     28
# 151       analysis analyst     28
# 398               modeling     28
# 231              architect     24
# 71                 testing     23
# 136                  linux     22
# 450                  cloud     22
# 379                  agile     21
# 560        project project     18
# 356          data analysis     18
# 413              developer     17
# 679           intelligence     17
# 169     project management     16
# 322                     bi     16
# 495                 server     16
# 676       business analyst     16
# 636               research     16
# 687     manager management     15
# 171           requirements     15
# 187                  spark     15
# 287          data modeling     14
# 596             analytical     14
# 407  business intelligence     14
# 590         agile analysis     14
# 220                tableau     13
# 595              lifecycle     13
# 420                  mysql     13
# 106                   hive     13
# 180             powerpoint     13
# 364                    etl     12
# 447             experience     12
# 637       analyst business     12

# %%
#Excluding some words/phrases from the first 50 entries to narrow the list further down to the names of technologies/tools
my_additional_stop_words = ['analysis', 'analyst', 'management', 'project', 'development', 
                'database', 'manager', 'analysis analyst', 'testing', 'project project', 
                'data analysis', 'developer', 'intelligence', 'project management', 'server', 'manager management', 
                 'requirements', 'analytical', 'experience', 'analyst business', 'security', 
                 'research', 'lifecycle', 'windows', 'consulting', 'skills',
                'programming', 'supervision', 'degree', 'center', 'sql sql', 'engineer', 'analytics',
                'access', 'process', 'office', 'validation', 'information', 'tools', 'quality', 'administration',
                 'application', 'infrastructure', 'application', 'scripts', 'http', 'video', 'enterprise', 
                'net', 'design', 'networks', 'hardware', 'ms', 'sql sql']
from sklearn.feature_extraction import text 
cv1 = CountVectorizer(min_df=2, stop_words = text.ENGLISH_STOP_WORDS.union(my_additional_stop_words), token_pattern=r'(?u)\b\w\w+\b|[r]$' ,
                      tokenizer=None, ngram_range=(1, 2))
cvmatrix1 = cv1.fit_transform(job_info_ds['skill_set'])
dist = np.sum(cvmatrix1.toarray(), axis=0)
word_count = {}
for tag, count in zip(cv1.get_feature_names(), dist):
      word_count[tag] = count
sorted_cnts1 = pd.DataFrame(list(word_count.items()),columns=['Word','Count'])
sorted_cnts1.sort_values(by=['Count'], ascending=False,inplace=True)
# exclude these words unless they occur along with other words
drop_list = ['data', 'big', 'architect', 'microsoft', 'mining', 'metrics', 'business', 'modeling', 'sales', 'operations']
sorted_cnts1 = sorted_cnts1[sorted_cnts1['Word'].apply(lambda word : False if (any(x in word for x in drop_list) & len(word.split()) == 1) else True)]
sorted_cnts1[sorted_cnts1["Word"] != 'sql sql']
# Out:
#                       Word  Count
# 500                    sql     87
# 260                 hadoop     51
# 299                   java     32
# 342                  excel     31
# 284                 python     31
# 257               big data     29
# 125                 oracle     28
# 212                  linux     22
# 137                  cloud     22
# 58                   agile     21
# 81                      bi     16
# 287                  spark     15
# 458          data modeling     14
# 156                   hive     13
# 106                  mysql     13
# 277             powerpoint     13
# 354                tableau     13
# 28                     etl     12
# 165         data architect     12
# 135                  hbase     11
# 95                    unix     11
# 436            data mining     10
# 222                    aws      9
# 225                    sas      8
# 428                    sap      8
# 460     agile architecture      8
# 490                  cisco      8
# 441              scripting      8
# 302  architecture business      8
# 264                  kafka      8
# ..                     ...    ...
# 185         sql subversion      2
# 183             scrum sdlc      2
# 178       programmer scrum      2
# 175          usage logging      2
# 174        salesforce sfdc      2
# 216              cissp ceh      2
# 217        facing business      2
# 218        hadoop hcatalog      2
# 243     logging monitoring      2
# 259                 impala      2
# 258         visualizations      2
# 256   teradata informatica      2
# 254              data java      2
# 251              marketing      2
# 249           sql teradata      2
# 247      javascript jquery      2
# 245              pig oozie      2
# 244                    emc      2
# 242            sql telecom      2
# 220           python arima      2
# 240       architecture edi      2
# 239             python use      2
# 234               planning      2
# 231        centric network      2
# 230       architecture big      2
# 229                 spring      2
# 227             subversion      2
# 224           learning rpa      2
# 221        mapreduce spark      2
# 546                    ceh      2
#
# [530 rows x 2 columns]

# %%
job_info_ds[job_info_ds['skill_set'].apply(str.lower).apply(lambda skill : 'bi' in skill)]
# Out:
#                                              job_title                                          skill_set                                    employment_type
# 11   AEM Consultant--- Blue Prism Architect---Data ...  AEM Consultant--- Blue Prism Architect---Data ...  Full Time, Contract Corp-To-Corp, Contract Ind...
# 22                               Sr Big Data Architect                                 Big Data Architect                                          Full Time
# 41   AEM Consultant--- Blue Prism Architect---Data ...  AEM Consultant--- Blue Prism Architect---Data ...  Full Time, Contract Corp-To-Corp, Contract Ind...
# 52                               Sr Big Data Architect                                 Big Data Architect                                          Full Time
# 61                             Data Solutions Engineer  Analytics, Data Solutions, MuleSoft, AWS, Wave...                                          Full Time
# 66                       Solution Architect (Big Data)  Solution Architecture, Big Data, RDBMS (Data W...                                          Full Time
# 68                    Senior Enterprise Data Architect  Senior Enterprise Data Architect, Data, ETL, B...                                          Full Time
# 69                  Cloud/Big Data Technical Architect                            Big Data, Cloud, Google                                          Full Time
# 70           Google Cloud/Big Data Technical Architect                 BI/Big Data, Google Cloud Platform                                          Full Time
# 71                                  Big Data Architect  Big Data, Hadoop, Oracle, SQL, MySQL, Pentaho,...                                          Full Time
# 86                              Data Security Engineer  data etl big data bi php python sql shell tani...                                             C2H W2
# 90                      Big Data Application Architect  Big Data,spera, PowerBI, Tableau, SPSS, Spotfi...                 Contract Corp-To-Corp, Contract W2
# 92                  Machine Learning / Big Data Expert  Machine Learning, Big Data, Java, Scala, Pytho...  Full Time, Contract Corp-To-Corp, Contract Ind...
# 93                                      Data Architect               BIG DATA, ETL, ORACLE, LINUX, HADOOP                                                NaN
# 94                                  Big Data Architect  Big Data Architecture, Big Data Implementation...                 Full Time, C2H Independent, C2H W2
# 96                                  Big Data Architect  Big Data/Hadoop Architecture, IBM BigInsights ...                              Contract Corp-To-Corp
# 97                                  Big Data Architect                                 Big Data Architect  Full Time, Contract Corp-To-Corp, Contract Ind...
# 99                                  Big Data Architect  Big Data/Hadoop Architecture, HDFS, MR2, Hive,...  Full Time, Contract Corp-To-Corp, Contract Ind...
# 100                    Big Data/Java Product Architect  Java, Spring, Cloud, AWS, Big Data, MongoDB, N...                     Full Time, Contract W2, C2H W2
# 110                                 Big Data Architect                            HADOOP, BI ARCHITECTURE                                        Contract W2
# 113                     Data Specialist(ETL.Ab Initio)  AbInitio development experience,generic graphs...  Contract Corp-To-Corp, Contract Independent, C...
# 114                                 Big Data Architect  HDFS, MR2, Hive, HBase, Sqoop, Oozie, BigSQL, ...  Full Time, Contract Corp-To-Corp, Contract W2,...
# 124                  Big Data Architect/Developer role  Big Data Architect Developer Spark Kafka Cassa...  Contract Corp-To-Corp, Contract Independent, C...
# 127            Big Data Developer- Immediate Interview  Big Data Developer, Spark, Kafka, data sources...  Full Time, Contract Corp-To-Corp, Contract Ind...
# 128                  Application Support/ Data Analyst  Analyst, BI Tools, Change Management, Developm...  Contract Independent, Contract W2, C2H Indepen...
# 160                             BI Analytics Developer  BI  ETL  SQL  MicroSoft SSIS Big Data MicroSof...                                          Full Time
# 201                          Hadoop Solution Architect                    big data, hadoop, ETL framework                 Contract Corp-To-Corp, Contract W2
# 206                                    Hadoop Engineer  Software design & development with Java, J2EE,...  Contract Corp-To-Corp, Contract Independent, C...
# 207              Senior Information Security Architect  Information Security, Security Architect, IBM ...                                        Contract W2
# 208                                  BigData Architect  Big Data/Hadoop Architecture, HDFS, MR2, Hive,...  Full Time, Contract Corp-To-Corp, Contract Ind...
# 225                       Information Security Analyst  hadoop, Big Data, AWS, Cloud, Security, Java, ...                                        Contract W2
# 235                Sr. Hadoop Developer/Architect (05)  Hadoop, Big Data, Java, Business Intelligence,...                                          Full Time
# 236       BI Analyst w/ Fortune 500 Company in Atlanta  Analysis, Analyst, Architecture, BI Tools, Bus...                                          Full Time
# 238                         Hadoop Developer Architect  Build Big Data solutions using Hadoop and or N...                              Contract Corp-To-Corp
# 240  Systems Security Administrator - Sr/ Sr. Infor...  Looking for   8-10 years of combined IT and Se...                                        Contract W2
# 263             Senior Business Intelligence Developer  SSIS, SSRS, SSAS, SQL, Power BI, MS SQL, Micro...                                          Full Time
# 269  Application Developer./Business Intelligence D...  Excellent Verbal,Written Communication skills....  Contract Corp-To-Corp, Contract Independent, C...
# 317                    Business Intelligence Developer                        BI, OLAP, SQL, Oracle, Qlik                                        Contract W2
# 348                    Business Intelligence Developer               OBIEE ,PL/SQL , BI Publisher Reports                                        Contract W2
# 353       Senior Business Intelligence Cloud Developer                                  DevOps, Cloud, BI                                        Contract W2
# 394                          Reports Analyst/Developer  SSRS, Crystal reports, manufacturing, industri...                                          Full Time
# 422        Senior Business Intelligence (BI) Architect  Architect, BI Tools, Business Intelligence, IT...  Contract Corp-To-Corp, Contract Independent, C...
# 491  Senior Information Security Risk Analyst - BHJ...  information security risk analysis and managem...                                          Full Time
# 574                     Hadoop Developer/Administrator  adoop Cluster Administration 3. Hadoop Securit...                 Contract Corp-To-Corp, Contract W2

# %%
job_info_ds[job_info_ds['skill_set'].apply(str.lower).apply(lambda skill : 'oracle' in skill)]
# Out:
#                                              job_title                                          skill_set                                    employment_type
# 18   Workday HCM Data Conversion- Solution Engineer...  Analysis, Consulting, Development, ERP, Excel,...                                          Full Time
# 19            Data Conversion- Solution Manager - USDC  Analysis, Consulting, Development, Excel, HTTP...                                          Full Time
# 26        Oracle eBusiness Suite Product Data Hub Lead                      Oracle EBS, MDM, Data Quality  Contract Corp-To-Corp, C2H Corp-To-Corp, Contr...
# 48   Workday HCM Data Conversion- Solution Engineer...  Analysis, Consulting, Development, ERP, Excel,...                                          Full Time
# 49            Data Conversion- Solution Manager - USDC  Analysis, Consulting, Development, Excel, HTTP...                                          Full Time
# 56        Oracle eBusiness Suite Product Data Hub Lead                      Oracle EBS, MDM, Data Quality  Contract Corp-To-Corp, C2H Corp-To-Corp, Contr...
# 60                                      Data Architect  Architect, Architecture, Business Intelligence...                                          Full Time
# 71                                  Big Data Architect  Big Data, Hadoop, Oracle, SQL, MySQL, Pentaho,...                                          Full Time
# 74                                      Data Architect  Architecture, Business Requirements, CTO, Deve...                                          Full Time
# 88                                      Data Architect  Architecture, Business Intelligence, Business ...  Full Time, Contract Corp-To-Corp, Contract Ind...
# 93                                      Data Architect               BIG DATA, ETL, ORACLE, LINUX, HADOOP                                                NaN
# 102                             Data Reporting Analyst  MS Excel, Power Query, Charting Tools, SharePo...  Contract Corp-To-Corp, Contract Independent, C...
# 111                                       Data Analyst  Analyst, Database, ERP, Excel, Oracle, SQL, SQ...                                        Contract W2
# 122  Oracle DBA w/ Data Migration and Systems Exper...  Oracle DBA w/ Data Migration and Systems Exper...                                          Full Time
# 134  Data Architect / ETL Architect / Teradata Arch...  Data Architect, Data Modeling, Teradata, Infor...                                        Contract W2
# 139                                       Statistician  Analysis, Analytical Skills, Capacity Planning...                                          Full Time
# 142                             Database Administrator  Oracle Database 11g / 12c system internals, un...                                          Full Time
# 149                                 Operations Analyst  Analysis, Analyst, Analytical Skills, Apache, ...                                          Full Time
# 203                    Business Intelligence Developer  Data warehousing / Business Intelligence exper...  Full Time, Contract Corp-To-Corp, Contract Ind...
# 235                Sr. Hadoop Developer/Architect (05)  Hadoop, Big Data, Java, Business Intelligence,...                                          Full Time
# 236       BI Analyst w/ Fortune 500 Company in Atlanta  Analysis, Analyst, Architecture, BI Tools, Bus...                                          Full Time
# 250                                L3 Business Analyst  Analysis, Analyst, Architecture, Business Anal...                                          Full Time
# 298              Technical Application Support Analyst  Analysis, Analyst, Cisco, CMS, Consulting, Cus...                                          Full Time
# 317                    Business Intelligence Developer                        BI, OLAP, SQL, Oracle, Qlik                                        Contract W2
# 334                                   Hadoop Architect  Architecture, Business Requirements, Developme...                                          Full Time
# 406  ETL Developer - Oracle - Learn DataStage - BHJ...                           oracle, sql, etl, degree                                             C2H W2
# 475                            Senior Business Analyst  Agile, Analysis, Analyst, Architecture, Busine...                                          Full Time
# 500  Business Intelligence / Bigdata Solutions Arch...  ETL, Business Intelligence, Java, Scala, Pytho...                                          Full Time

# %% [markdown]
# <a id='#Checking-the-data'></a>

# %% [markdown]
# # Checking the data
#
# [[ go back to the top ]](#Table-of-contents)
# The next step is to look at the data we're working with. Even curated data sets from the government can have errors in them, and it's vital that we spot these errors before investing too much time in our analysis.<br>
# Generally, we're looking to answer the following questions:<br>
# Is there anything wrong with the data?<br>
# Are there any quirks with the data?<br>
# Do I need to fix or remove any of the data?<br>
# <br>
# For small datasets visualize using a pairplot to check for weirdness in the data , get the overall picture check if the data is linearly separable.<br>
# example : sb.pairplot(iris_data.dropna(), hue='class')<br>
# For larger datasets with lots of dimensions use Dimentionality Reduction techniques to visualize after variable conversion<br>
# <b>PCA</b><br>
# <b>t-SNE</b>

# %% [markdown]
# <a id='#Peek'></a>

# %% [markdown]
# ### Step 1 : Peek at your data
#
# [[ go back to the top ]](#Table-of-contents)
# Use head()

# %% [markdown]
# <a id='#Dimensions'></a>

# %% [markdown]
# ### Step 2 : Dimensions
#
# [[ go back to the top ]](#Table-of-contents)
# Use df.shape

# %% [markdown]
# <a id='#Datatype'></a>

# %% [markdown]
# ### Step 3 : Datatype of each feature
#
# [[ go back to the top ]](#Table-of-contents)
# Use info()

# %% [markdown]
# <a id='#Descriptive-stats'></a>

# %% [markdown]
# ### Step 4 : Descriptive Statistics
#
# [[ go back to the top ]](#Table-of-contents)
# Use describe() & describe(include=[‘O’])

# %% [markdown]
# <a id='#Class-dist'></a>

# %% [markdown]
# ### Step 5 : Class Distribution
#
# [[ go back to the top ]](#Table-of-contents)
# class_counts = df.groupby('class').size() <br>
# Classification problems with imbalance classes require special treatment<br>

# %% [markdown]
# <a id='#Correlation'></a>

# %% [markdown]
# ### Step 6 : Correlation
#
# [[ go back to the top ]](#Table-of-contents)
# correlations = df.corr(method='pearson')<br>
# If you have ordinal data, you will want to use Spearman's rank-order correlation or a Kendall's Tau Correlation instead of the Pearson product-moment correlation.

# %% [markdown]
# <a id='#Skew'></a>

# %% [markdown]
# ### Step 7 : Skew
#
# [[ go back to the top ]](#Table-of-contents)
# skew = df.skew()

# %% [markdown]
# <a id='#Takeaway1'></a>

# %% [markdown]
# ### Takeaway from "Checking the data"
# What did I learn? <br>
# [[ go back to the top ]](#Table-of-contents)
# ##### What is the distribution of numerical feature values across the samples?
# ##### What is the distribution of categorical feature values across the samples?
# ##### Which features are missing data?
# ##### Can anomalies/outliers/anything weird be spotted?
# ### Assumtions based on data analysis
# We arrive at following assumptions based on data analysis done so far. We may validate these assumptions further before taking appropriate actions.
# ###### Correlating.
# We want to know how well does each feature correlate with Survival. We want to do this early in our project and match these quick correlations with modelled correlations later in the project.
# ###### Completing.
# We may want to complete Age feature as it is definitely correlated to survival.<br>
# We may want to complete the Embarked feature as it may also correlate with survival or another important feature.
# ###### Correcting.
# Ticket feature may be dropped from our analysis as it contains high ratio of duplicates (22%) and there may not be a correlation between Ticket and survival.<br>
# Cabin feature may be dropped as it is highly incomplete or contains many null values both in training and test dataset.<br>
# PassengerId may be dropped from training dataset as it does not contribute to survival.<br>
# Name feature is relatively non-standard, may not contribute directly to survival, so maybe dropped.<br>
# ###### Creating.
# We may want to create a new feature called Family based on Parch and SibSp to get total count of family members on board.<br>
# We may want to engineer the Name feature to extract Title as a new feature.<br>
# We may want to create new feature for Age bands. This turns a continous numerical feature into an ordinal categorical feature.<br>
# We may also want to create a Fare range feature if it helps our analysis.<br>
# ###### Classifying.
# We may also add to our assumptions based on the problem description noted earlier.<br>
# Women (Sex=female) were more likely to have survived.<br>
# Children (Age<?) were more likely to have survived.<br>
# The upper-class passengers (Pclass=1) were more likely to have survived.<br>

# %% [markdown]
# <a id='#Missing-data'></a>

# %% [markdown]
# # Missing data
#
# [[ go back to the top ]](#Table-of-contents)<br>
# Some predictive models inherently are able to deal with missing data (neural networks come to mind) and others require that the missing values be dealt with separately.<br>
# ### Identifying Missing data
# We can use seaborn to create a simple heatmap to see where we are missing data!<br>
# sns.heatmap(train.isnull(),yticklabels=False,cbar=False,cmap='viridis')<br>

# %% [markdown]
# ### Taking Care with Missing values
# 1) Throw out any data with missing values<br>
# If you’ve got a lot of data that isn’t missing any values it is certainly the quickest and easiest way to handle it.
# <br>
# train.drop('Cabin',axis=1,inplace=True)<br>
# 2) Assign a value that indicates a missing value<br>
# This is particularly appropriate for categorical variables (more on this in the next post). I really like using this approach when possible because the fact that the value is missing can be useful information in and of itself. Perhaps when a value is missing for a particular variable, that has some underlying cause that makes it correlate more highly with another value.One interesting trick is that you can do this with binary variables by setting the false value as -1, the true value as 1, and missing values as 0.<br>
# df['Cabin'][df.Cabin.isnull()] = 'U0'<br>
# 3) Assign the average value<br>
# This is a very common approach because it is simple, and for variables that aren’t extremely important it very well may be good enough. You can also incorporate other variables to create subsets and assign the average within the group. In cases of categorical variables, the most common value can be applied rather than the statistical mean.<br>
# df['Fare'][ np.isnan(df['Fare']) ] = df['Fare'].median()<br>
# df.Embarked[ df.Embarked.isnull() ] = df.Embarked.dropna().mode().values <br>
# 4) Use a regression or another simple model to predict the values of missing variables <br>
# Useful code :<br>
# from sklearn.ensemble import RandomForestRegressor (Can be LinearRegression as well) <br>
#
# def setMissingAges(df):
#
#     # Grab all the features that can be included in a Random Forest Regressor
#     age_df = df[['Age','Embarked','Fare', 'Parch', 'SibSp', 'Title_id','Pclass','Names','CabinLetter']]
#
#     # Split into sets with known and unknown Age values
#     knownAge = age_df.loc[ (df.Age.notnull()) ]
#     unknownAge = age_df.loc[ (df.Age.isnull()) ]
#
#     # All age values are stored in a target array
#     y = knownAge.values[:, 0]
#
#     # All the other values are stored in the feature array
#     X = knownAge.values[:, 1::]
#
#     # Create and fit a model
#     rtr = RandomForestRegressor(n_estimators=2000, n_jobs=-1)
#     rtr.fit(X, y)
#
#     # Use the fitted model to predict the missing values
#     predictedAges = rtr.predict(unknownAge.values[:, 1::])
#
#     # Assign those predictions to the full data set
#     df.loc[ (df.Age.isnull()), 'Age' ] = predictedAges
#
#     return df
# <br>
# def impute_age(cols):
#     Age = cols[0]
#     Pclass = cols[1]
#
#     if pd.isnull(Age):
#
#         if Pclass == 1:
#             return 37
#
#         elif Pclass == 2:
#             return 29
#
#         else:
#             return 24
#
#     else:
#         return Age
# train['Age'] = train[['Age','Pclass']].apply(impute_age,axis=1)
#
# 5)Impute missing data using a reliable method, such as k-nearest neighbors.<br>
# <br>
# from sklearn.preprocessing import Imputer <br>
# imp = Imputer(missing_values='NaN', strategy='mean', axis=0)<br>
# X = imp.fit_transform(X)<br>
# <br>
# The Imputer class provides basic strategies for imputing missing values, either using the mean, the median or the most frequent value of the row or column in which the missing values are located. This class also allows for different missing values encodings.

# %% [markdown]
# ### Recheck if Missing data is dealt with
# We can use seaborn to create the heatmap again to see whether we are still missing data.<br>
# sns.heatmap(train.isnull(),yticklabels=False,cbar=False,cmap='viridis')<br>

# %% [markdown]
# <a id='#EDA'></a>

# %% [markdown]
# # Exploratory Data Analysis
#
# [[ go back to the top ]](#Table-of-contents)<br>
# This is best done by Visualizations<br>
# ### Univariate Analysis
# ##### What is the plan ? Based on what happened so far?
# <br>
# #### Visualizations
# ##### Histograms <br>
# A fast way to get an idea of the distribution of each attribute is to look at histograms. Histograms group data into bins and provide you a count of the number of observations in each bin. From the shape of the bins you can quickly get a feeling for whether an attribute is Gaussian’, skewed or even has an exponential distribution. It can also help you see possible outliers.<br>
# Bins should be all the same size. For example, groups of ten or a hundred.<br>
# Bins should include all of the data, even outliers. If your outliers fall way outside of your other data, consider lumping them in with your first or last bin. This creates a rough histogram — make sure you note where outliers are being included.<br>
# Boundaries for bins should land at whole numbers whenever possible (this makes the chart easier to read).<br>
# Choose between 5 and 20 bins. The larger the data set, the more likely you’ll want a large number of bins. For example, a set of 12 data pieces might warrant 5 bins but a set of 1000 numbers will probably be more useful with 20 bins. The exact number of bins is usually a judgment call.<br>
# If at all possible, try to make your data set evenly divisible by the number of bins. For example, if you have 10 pieces of data, work with 5 bins instead of 6 or 7.<br>
# One goal would be to minimize the integrated mean square error.  When the distribution is normal, this can be done with the Freedman–Diaconis rule of course, one might listent to William S. Cleveland (perhaps the world's leading expert on statistical graphics) and not use histograms at all.
# Useful code : <br>
# sns.set_style('whitegrid')<br>
# sns.countplot(x='Survived',data=train,palette='RdBu_r')<br>
# train['Age'].hist(bins=30,color='darkred',alpha=0.7)<br>
# sns.distplot(train['Age'].dropna(),kde=False,color='darkred',bins=30)<br>
# train['Fare'].hist(color='green',bins=40,figsize=(8,4))
# ##### Density Plots
# Density plots are another way of getting a quick idea of the distribution of each attribute. The plots look like an abstracted histogram with a smooth curve drawn through the top of each bin, much like your eye tried to do with the histograms.<br>
# sns.distplot(train['Age'].dropna(),kde=True,color='darkred',bins=30)<br>
# ##### Box and Whisker Plots
# Another useful way to review the distribution of each attribute is to use Box and Whisker Plots or boxplots for short.
# Boxplots summarize the distribution of each attribute, drawing a line for the median (middle value) and a box around the 25th and 75th percentiles (the middle 50% of the data). The whiskers give an idea of the spread of the data and dots outside of the whiskers show candidate outlier values (values that are 1.5 times greater than the size of spread of the middle 50% of the data).<br>
# plt.figure(figsize=(12, 7))<br>
# sns.boxplot(x='Pclass',y='Age',data=train,palette='winter')

# %% [markdown]
# <a id='#Takeaway2'></a>

# %% [markdown]
# ### Takeaway from "Univariate Analysis"
# What did I learn? <br>
# [[ go back to the top ]](#Table-of-contents)
# ##### What is the distribution of numerical feature values across the samples?
# This helps us determine, among other early insights, how representative is the training dataset of the actual problem domain.<br>
# Total samples are 891 or 40% of the actual number of passengers on board the Titanic (2,224).<br>
# Survived is a categorical feature with 0 or 1 values.<br>
# Around 38% samples survived representative of the actual survival rate at 32%.<br>
# Most passengers (> 75%) did not travel with parents or children.<br>
# Nearly 30% of the passengers had siblings and/or spouse aboard.<br>
# Fares varied significantly with few passengers ( < 1 percent) paying as high as 512.<br>
# Few elderly passengers ( < 1 percent) within age range 65-80. <br>
# ##### What is the distribution of categorical feature values across the samples?
# Names are unique across the dataset (count=unique=891)<br>
# Sex variable as two possible values with 65% male (top=male, freq=577/count=891).<br>
# Cabin values have several dupicates across samples. Alternatively several passengers shared a cabin.<br>
# Embarked takes three possible values. S port used by most passengers (top=S)<br>
# Ticket feature has high ratio (22%) of duplicate values (unique=681).<br>
# ##### Can anomalies/outliers/anything weird be spotted?
#
# ##### If yes(for the previous question) ,what is the plan to handle anomalies/outliers/anything weird that has be spotted?
#
# ### Assumtions based on data analysis
# We arrive at following assumptions based on data analysis done so far. We may validate these assumptions further before taking appropriate actions.
# ###### Correlating.
# We want to know how well does each feature correlate with Survival. We want to do this early in our project and match these quick correlations with modelled correlations later in the project.
# ###### Completing.
# We may want to complete Age feature as it is definitely correlated to survival.<br>
# We may want to complete the Embarked feature as it may also correlate with survival or another important feature.
# ###### Correcting.
# Ticket feature may be dropped from our analysis as it contains high ratio of duplicates (22%) and there may not be a correlation between Ticket and survival.<br>
# Cabin feature may be dropped as it is highly incomplete or contains many null values both in training and test dataset.<br>
# PassengerId may be dropped from training dataset as it does not contribute to survival.<br>
# Name feature is relatively non-standard, may not contribute directly to survival, so maybe dropped.<br>
# ###### Creating.
# We may want to create a new feature called Family based on Parch and SibSp to get total count of family members on board.<br>
# We may want to engineer the Name feature to extract Title as a new feature.<br>
# We may want to create new feature for Age bands. This turns a continous numerical feature into an ordinal categorical feature.<br>
# We may also want to create a Fare range feature if it helps our analysis.<br>
# ###### Classifying.
# We may also add to our assumptions based on the problem description noted earlier.<br>
# Women (Sex=female) were more likely to have survived.<br>
# Children (Age<?) were more likely to have survived.<br>
# The upper-class passengers (Pclass=1) were more likely to have survived.<br>

# %% [markdown]
# <a id='#Multivariate'></a>

# %% [markdown]
# ### Multivariate Analysis
# [[ go back to the top ]](#Table-of-contents)<br>
# ##### What is the plan ? Based on what happened so far?
# <br>
# This is best done by Visualizations and by feature correlations by pivoting features against each other<br>
# ##### Analyze by pivoting features
# To confirm some of our observations and assumptions, we can quickly analyze our feature correlations by pivoting features against each other.<br>
# It also makes sense doing so only for features which are categorical (Sex), ordinal (Pclass) or discrete (SibSp, Parch) type.<br>
# Pclass We observe significant correlation (>0.5) among Pclass=1 and Survived (classifying # 3). We decide to include this feature in our model.<br>
# Sex We confirm the observation during problem definition that Sex=female had very high survival rate at 74% (classifying # 1).<br>
# SibSp and Parch These features have zero correlation for certain values. It may be best to derive a feature or a set of features from these individual features (creating # 1).<br>
# Sample code :<br>
# train_df[['Pclass', 'Survived']].groupby(['Pclass'], as_index=False).mean().sort_values(by='Survived', ascending=False)
# ##### Visualizations
# For<b> Large Datasets use Dimentionality Reduction Techniques </b> like PCA and t-SNE to viaualize data
# <br>
# ###### PCA
# from sklearn.preprocessing import StandardScaler<br>
# scaler = StandardScaler()<br>
# scaler.fit(df)<br>
# scaled_data = scaler.transform(df)<br>
# from sklearn.decomposition import PCA<br>
# pca = PCA(n_components=2)<br>
# pca.fit(scaled_data)<br>
# x_pca = pca.transform(scaled_data)<br>
# scaled_data.shape<br>
# x_pca.shape<br>
# plt.figure(figsize=(8,6))<br>
# plt.scatter(x_pca[:,0],x_pca[:,1],c=cancer['target'],cmap='plasma')<br>
# plt.xlabel('First principal component')<br>
# plt.ylabel('Second Principal Component')<br>
# #The components correspond to combinations of the original features, the components themselves are stored as an attribute of the fitted PCA object:<br>
# pca.components_ <br>
# df_comp = pd.DataFrame(pca.components_,columns=cancer['feature_names'])<br>
# plt.figure(figsize=(12,6))<br>
# sns.heatmap(df_comp,cmap='plasma',)<br>
# This heatmap and the color bar basically represent the correlation between the various feature and the principal component itself.<br>
# ###### t-SNE
# When PCA doesnt work ..when we need a non-linear dimentionality reduction.It is highly recommended to use another dimensionality reduction method (e.g. PCA for dense data or TruncatedSVD for sparse data) to reduce the number of dimensions to a reasonable amount (e.g. 50) if the number of features is very high. This will suppress some noise and speed up the computation of pairwise distances between samples.<br>
# from sklearn.manifold import TSNE<br>
# X_tsne = TSNE(learning_rate=100).fit_transform(iris.data)<br>
# X_pca = PCA().fit_transform(iris.data)<br>
# figure(figsize=(10, 5))<br>
# subplot(121)<br>
# scatter(X_tsne[:, 0], X_tsne[:, 1], c=iris.target)<br>
# subplot(122)<br>
# scatter(X_pca[:, 0], X_pca[:, 1], c=iris.target)<br>
# (Vary the colour of the points with different features...Color-coherent clusters shows that for T-SNE, nothing is closer to a given observation than an observation with that the similar feature . This is also a consequence of the T-SNE algorithm itself, that focuses on preserving very small pairwise distances between points, contrary to PCA.To spot abnormal points : those with color that do not correspond to their cluster. They are anomalies.<br>
# ###### Pairplots (for small datasets)
# sns.pairplot(df,hue='Kyphosis',palette='Set1')<br>
# sns.pairplot(iris,hue='species',palette='Dark2')<br>
# sb.pairplot(iris_data.dropna(), hue='class')
# <br>
# scatter_matrix(dataset)<br>
# plt.show()<br>
# ###### Countplots with hue
# sns.set_style('whitegrid')<br>
# sns.countplot(x='Survived',hue='Sex',data=train,palette='RdBu_r')<br>
# ns.set_style('whitegrid')
# sns.countplot(x='Survived',hue='Pclass',data=train,palette='rainbow')<br>
# ###### Jointplot (scatterplot)
# sns.jointplot(x='fico',y='int.rate',data=loans,color='purple')<br>
# sns.jointplot(x='Time on Website',y='Yearly Amount Spent',data=customers)<br>
# sns.jointplot(x='Time on App',y='Length of Membership',kind='hex',data=customers)<br>
# <br>
# plt.scatter(data[0][:,0],data[0][:,1],c=data[1],cmap='rainbow')<br>
# <br>
# f, (ax1, ax2) = plt.subplots(1, 2, sharey=True,figsize=(10,6))<br>
# ax1.set_title('K Means')<br>
# ax1.scatter(data[0][:,0],data[0][:,1],c=kmeans.labels_,cmap='rainbow')<br>
# ax2.set_title("Original")<br>
# ax2.scatter(data[0][:,0],data[0][:,1],c=data[1],cmap='rainbow')<br>
# ###### lmplots
# plt.figure(figsize=(11,7))<br>
# sns.lmplot(y='int.rate',x='fico',data=loans,hue='credit.policy',col='not.fully.paid',palette='Set1')<br>
# <br>
# sns.set_style('whitegrid')<br>
# sns.lmplot('Room.Board','Grad.Rate',data=df, hue='Private',<br>
#            palette='coolwarm',size=6,aspect=1,fit_reg=False)<br>
# <br>
# ###### Overlapping histograms
# ns.set_style('darkgrid')<br>
# g = sns.FacetGrid(df,hue="Private",palette='coolwarm',size=6,aspect=2)<br>
# g = g.map(plt.hist,'Outstate',bins=20,alpha=0.7)<br>
# <br>
# ###### Heatmaps
# sns.heatmap(USAhousing.corr())<br>
# <br>
# plt.figure(figsize=(12,6))<br>
# sns.heatmap(df_comp,cmap='plasma',)
# <br>
# ###### kdeplot
# sns.kdeplot( setosa['sepal_width'], setosa['sepal_length'],<br>
#                  cmap="plasma", shade=True, shade_lowest=False)
# <br>
# ###### violinplot
# plt.figure(figsize=(10, 10))<br>
#
# for column_index, column in enumerate(iris_data_clean.columns):<br>
#     if column == 'class': <br>
#         continue <br>
#     plt.subplot(2, 2, column_index + 1) <br>
#     sb.violinplot(x='class', y=column, data=iris_data_clean) <br>

# %% [markdown]
# <a id='#Takeaway3'></a>

# %% [markdown]
# ### Takeaway from "Multivariate Analysis"
# What did I learn? <br>
# [[ go back to the top ]](#Table-of-contents)
# ##### What is the distribution of numerical feature values across the samples?
# This helps us determine, among other early insights, how representative is the training dataset of the actual problem domain.<br>
# Total samples are 891 or 40% of the actual number of passengers on board the Titanic (2,224).<br>
# Survived is a categorical feature with 0 or 1 values.<br>
# Around 38% samples survived representative of the actual survival rate at 32%.<br>
# Most passengers (> 75%) did not travel with parents or children.<br>
# Nearly 30% of the passengers had siblings and/or spouse aboard.<br>
# Fares varied significantly with few passengers ( < 1 percent) paying as high as 512.<br>
# Few elderly passengers ( < 1 percent) within age range 65-80. <br>
# ##### What is the distribution of categorical feature values across the samples?
# Names are unique across the dataset (count=unique=891)<br>
# Sex variable as two possible values with 65% male (top=male, freq=577/count=891).<br>
# Cabin values have several dupicates across samples. Alternatively several passengers shared a cabin.<br>
# Embarked takes three possible values. S port used by most passengers (top=S)<br>
# Ticket feature has high ratio (22%) of duplicate values (unique=681).<br>
# ##### Can anomalies/outliers/anything weird be spotted?
#
# ##### If yes(for the previous question) ,what is the plan to handle anomalies/outliers/anything weird that has be spotted?
# ### Assumtions based on data analysis
# We arrive at following assumptions based on data analysis done so far. We may validate these assumptions further before taking appropriate actions.
# ###### Correlating.
# We want to know how well does each feature correlate with Survival. We want to do this early in our project and match these quick correlations with modelled correlations later in the project.
# ###### Completing.
# We may want to complete Age feature as it is definitely correlated to survival.<br>
# We may want to complete the Embarked feature as it may also correlate with survival or another important feature.
# ###### Correcting.
# Ticket feature may be dropped from our analysis as it contains high ratio of duplicates (22%) and there may not be a correlation between Ticket and survival.<br>
# Cabin feature may be dropped as it is highly incomplete or contains many null values both in training and test dataset.<br>
# PassengerId may be dropped from training dataset as it does not contribute to survival.<br>
# Name feature is relatively non-standard, may not contribute directly to survival, so maybe dropped.<br>
# ###### Creating.
# We may want to create a new feature called Family based on Parch and SibSp to get total count of family members on board.<br>
# We may want to engineer the Name feature to extract Title as a new feature.<br>
# We may want to create new feature for Age bands. This turns a continous numerical feature into an ordinal categorical feature.<br>
# We may also want to create a Fare range feature if it helps our analysis.<br>
# ###### Classifying.
# We may also add to our assumptions based on the problem description noted earlier.<br>
# Women (Sex=female) were more likely to have survived.<br>
# Children (Age<?) were more likely to have survived.<br>
# The upper-class passengers (Pclass=1) were more likely to have survived.<br>

# %% [markdown]
# <a id='#Outliers'></a>

# %% [markdown]
# ### Outliers
# [[ go back to the top ]](#Table-of-contents)<br>
# #### Here are some changes you can make to your model:
#
# <b>Use a model that's resistant to outliers.</b><br>
# Tree-based models are generally not as affected by outliers, while regression-based models are. If you're performing a statistical test, try a non-parametric test instead of a parametric one.
# <br>
# <b>Use a more robust error metric.</b><br>
# Switching from mean squared error to mean absolute difference (or something like Huber Loss) reduces the influence of outliers. Why is the median a measure of central tendency?
# <br>
# <b>Here are some changes you can make to your data:</b><br>
# <br>
# Winsorize your data. Artificially cap your data at some threshold. <br>
# Transform your data. If your data has a very pronounced right tail, try a log transformation.<br>
# Remove the outliers. This works if there are very few of them and you're fairly certain they're anomalies and not worth predicting.<br>

# %% [markdown]
# <a id='#Feature'></a>

# %% [markdown]
# # Feature Engineering
#
# [[ go back to the top ]](#Table-of-contents)

# %% [markdown]
# ### Feature Engineering : Add new features
#
# [[ go back to the top ]](#Table-of-contents)
# ##### Derived Features
# Very basic examples of a useful derived variable might be pulling the country code and/or area code out of telephone numbers, or extracting country/state/city from GPS coordinates. Any time a qualitative variable represents an object in the world that we know something about, there is an opportunity to derive variables from it. Also, if a data set represents a timeseries or other historical behavioral information that can also provide a great opportunity for uncovering derived variables.<br>
# ##### Decomposition
# There may be features that represent a complex concept that may be more useful to a machine learning method when split into the constituent parts. An example is a date that may have day and time components that in turn could be split out further. Perhaps only the hour of day is relevant to the problem being solved. consider what feature decompositions you can perform.
# ##### Aggregation
# There may be features that can be aggregated into a single feature that would be more meaningful to the problem you are trying to solve. For example, there may be a data instances for each time a customer logged into a system that could be aggregated into a count for the number of logins allowing the additional instances to be discarded. Consider what type of feature aggregations could perform.
# <br> Examples -
# ###### 1. Create variables for difference in date, time and addresses<br>
# While you might be using date and time values on their own, you can create new variables by considering differences in dates and time. Here is an example hypothesis: An applicant who takes days to fill in an application form is likely to be less interested / motivated in the product compared to some one who fills in the same application with in 30 minutes. Similarly, for a bank, time elapsed between dispatch of login details for Online portal and customer logging in might show customers’ willingness to use Online portal.<br>
# <br>
# Another example is that a customer living closer to a bank branch is more likely to have a higher engagement than a customer living far off.<br>
# <br>
# ###### 2. Create new ratios and proportions<br>
# Instead of just keeping past inputs and outputs in your dataset, creating ratios out of them might add a lot of value. Some of the ratios, I have used in past are: Input / Output (past performance), productivity, efficiency and percentages. For example, in order to predict future performance of credit card sales of a branch, ratios like credit card sales / Sales person or Credit card Sales / Marketing spend would be more powerful than just using absolute number of card sold in the branch<br>
# ###### 3. Include effect of influencer<br>
# Influencer can impact on the behaviour of your study significantly. Influencer could be of various form and sizes. It could be an employee of your Organization, agent of your Organization or a customer of your Organization. Bringing the impact of these related entities can improve the models significantly. For example, a loan initiated by a sub-set of brokers (and not all brokers) might be more likely to be transferred to a different entity after the lock-in period. Similarly, there might be a sub set of Sales personnel involved who do a higher cross-sell to their customers.<br>
# <br>
# ###### 4. Check variables for seasonality and create the model for right period<br>
# A lot of businesses face some kind of seasonality. It could be driven by tax benefits, festive season or weather. If this is the case, you need to make sure that the data and variables are chosen for the right period.<br>

# %% [markdown]
# <a id='#Feature1'></a>

# %% [markdown]
# ### Feature Engineering : Remove Features
#
# [[ go back to the top ]](#Table-of-contents)
# <b>Useless Attributes</b>
# <b>Correlated Attributes:</b> Some algorithms degrade in importance with the existence of highly correlated attributes. Pairwise attributes with high correlation can be identified and the most correlated attributes can be removed from the data.<br>

# %% [markdown]
# <a id='#Feature12'></a>

# %% [markdown]
# ### Feature Engineering : Apply Transformations
#
# [[ go back to the top ]](#Table-of-contents)
# When we can transform complex non-linear relationships into linear relationships. Existence of a linear relationship between variables is easier to comprehend compared to a non-linear or curved relation. Transformation helps us to convert a non-linear relation into linear relation. Scatter plot can be used to find the relationship between two continuous variables. These transformations also improve the prediction. Log transformation is one of the commonly used transformation technique used in these situations.<br>
# Symmetric distribution is preferred over skewed distribution as it is easier to interpret and generate inferences. Some modeling techniques requires normal distribution of variables. So, whenever we have a skewed distribution, we can use transformations which reduce skewness. For right skewed distribution, we take square / cube root or logarithm of variable and for left skewed, we take square / cube or exponential of variables.<br>
# Variable Transformation is also done from an implementation point of view (Human involvement). Let’s understand it more clearly. In one of my project on employee performance, I found that age has direct correlation with performance of the employee i.e. higher the age, better the performance. From an implementation stand point, launching age based progamme might present implementation challenge. However, categorizing the sales agents in three age group buckets of < 30 years, 30-45 years and >45  and then formulating three different strategies for each group is a judicious approach. This categorization technique is known as Binning of Variables.<br>
# There are various methods used to transform variables. As discussed, some of them include square root, cube root, logarithmic, binning, reciprocal and many others. Let’s look at these methods in detail by highlighting the pros and cons of these transformation methods.<br>
# <b>Logarithm: </b>Log of a variable is a common transformation method used to change the shape of distribution of the variable on a distribution plot. It is generally used for reducing right skewness of variables. Though, It can’t be applied to zero or negative values as well.Log(Marketing spend) might have a more representable relationship with Sales as compared to absolute Marketing spend.<br>
# <b>Square / Cube root: </b>The square and cube root of a variable has a sound effect on variable distribution. However, it is not as significant as logarithmic transformation. Cube root has its own advantage. It can be applied to negative <b>Binning: </b>It is used to categorize variables. It is performed on original values, percentile or frequency. Decision of categorization technique is based on business understanding. For example, we can categorize income in three categories, namely: High, Average and Low. We can also perform co-variate binning which depends on the value of more than one variables.<br>

# %% [markdown]
# <a id='#Feature2'></a>

# %% [markdown]
# ### Feature Engineering : Convert Categorical Variables
#
# [[ go back to the top ]](#Table-of-contents)
#
# Logistic regression, distance based methods such as kNN, support vector machines, tree based methods etc. in sklearn needs numeric arrays. Features having string values cannot be handled by these learners.<br>
# Sklearn provides a very efficient tools for encoding the levels of a categorical features into numeric values.<br>
# ##### LabelEncoder
# LabelEncoder encode labels with value between 0 and n_classes-1.<br>
# Lets encode all the categorical features.<br>
#
# from sklearn.preprocessing import LabelEncoder<br>
# le=LabelEncoder()<br>
# for col in X_test.columns.values:<br>
#        # Encoding only categorical variables
#        if X_test[col].dtypes=='object':
#        #Using whole data to form an exhaustive list of levels
#        data=X_train[col].append(X_test[col])
#        le.fit(data.values)
#        X_train[col]=le.transform(X_train[col])
#        X_test[col]=le.transform(X_test[col])
# <br>
# ###### One-hot-encoding
#        from sklearn.preprocessing import OneHotEncoder<br>
#        enc=OneHotEncoder(sparse=False)
#        X_train_1=X_train
#        X_test_1=X_test
#        columns=['Gender', 'Married', 'Dependents', 'Education','Self_Employed',
#           'Credit_History', 'Property_Area']
#        for col in columns:
#        # creating an exhaustive list of all possible categorical values
#        data=X_train[[col]].append(X_test[[col]])
#        enc.fit(data)
#        # Fitting One Hot Encoding on train data
#        temp = enc.transform(X_train[[col]])
#        # Changing the encoded features into a data frame with new column names
#        temp=pd.DataFrame(temp,columns=[(col+"_"+str(i)) for i in data[col]
#             .value_counts().index])
#        # In side by side concatenation index values should be same
#        # Setting the index values similar to the X_train data frame
#        temp=temp.set_index(X_train.index.values)
#        # adding the new One Hot Encoded varibales to the train data frame
#        X_train_1=pd.concat([X_train_1,temp],axis=1)
#        # fitting One Hot Encoding on test data
#        temp = enc.transform(X_test[[col]])
#        # changing it into data frame and adding column names
#        temp=pd.DataFrame(temp,columns=[(col+"_"+str(i)) for i in data[col]
#             .value_counts().index])
#        # Setting the index for proper concatenation
#        temp=temp.set_index(X_test.index.values)
#        # adding the new One Hot Encoded varibales to test data frame
#        X_test_1=pd.concat([X_test_1,temp],axis=1)
#
# There are some cases where LabelEncoder or DictVectorizor are useful, but these are quite limited in my opinion due to ordinality.
# LabelEncoder can turn [dog,cat,dog,mouse,cat] into [1,2,1,3,2], but then the imposed ordinality means that the average of dog and mouse is cat. Still there are algorithms like decision trees and random forests that can work with categorical variables just fine and LabelEncoder can be used to store values using less disk space.
# One-Hot-Encoding has a the advantage that the result is binary rather than ordinal and that everything sits in an orthogonal vector space. The disadvantage is that for high cardinality, the feature space can really blow up quickly and you start fighting with the curse of dimensionality. In these cases, I typically employ one-hot-encoding followed by PCA for dimensionality reduction. I find that the judicious combination of one-hot plus PCA can seldom be beat by other encoding schemes. PCA finds the linear overlap, so will naturally tend to group similar features into the same feature.

# %% [markdown]
# <a id='#Feature3'></a>

# %% [markdown]
# ### Feature Engineering : Standardize
#
# [[ go back to the top ]](#Table-of-contents)
# Standardization is a useful technique to transform attributes with a Gaussian distribution and differing means and standard deviations to a standard Gaussian distribution with a mean of 0 and a standard deviation of 1.
# It is most suitable for techniques that assume a Gaussian distribution in the input variables and work better with rescaled data, such as linear regression, logistic regression and linear discriminate analysis.Elements such as l1 ,l2 regularizer in linear models (logistic comes under this category) and RBF kernel in SVM in objective function of learners assumes that all the features are centered around zero and have variance in the same order.<br>
# <br>
# #Standardize data (0 mean, 1 stdev)<br>
# from sklearn.preprocessing import StandardScaler<br>
# scaler = StandardScaler().fit(X)<br>
# rescaledX = scaler.transform(X)<br>
# #summarize transformed data<br>
# numpy.set_printoptions(precision=3)<br>
# print(rescaledX[0:5,:])<br>
# Standardizing the data when using a estimator having l1 or l2 regularization helps us to increase the accuracy of the prediction model. Other learners like kNN with euclidean distance measure, k-means, SVM, perceptron, neural networks, linear discriminant analysis, principal component analysis may perform better with standardized data.<br>

# %% [markdown]
# <a id='#Feature4'></a>

# %% [markdown]
# ### Feature Engineering : Normalize
#
# [[ go back to the top ]](#Table-of-contents)
# Normalizing in scikit-learn refers to rescaling each observation (row) to have a length of 1 (called a unit norm in linear algebra).
# This preprocessing can be useful for sparse datasets (lots of zeros) with attributes of varying scales when using algorithms that weight input values such as neural networks and algorithms that use distance measures such as K-Nearest Neighbors.<br>
# #Normalize data (length of 1<br>
# from sklearn.preprocessing import Normalizer<br>
# scaler = Normalizer().fit(X)<br>
# normalizedX = scaler.transform(X)<br>
# #summarize transformed data<br>
# numpy.set_printoptions(precision=3)<br>
# print(normalizedX[0:5,:])<br>

# %% [markdown]
# <a id='#Feature5'></a>

# %% [markdown]
# ### Feature Engineering : Make Binary
#
# [[ go back to the top ]](#Table-of-contents)
# You can transform your data using a binary threshold. All values above the threshold are marked 1 and all equal to or below are marked as 0. This is called binarizing your data or threshold your data. It can be useful when you have probabilities that you want to make crisp values. It is also useful when feature engineering and you want to add new features that indicate something meaningful. <br>
# <br>
# from sklearn.preprocessing import Binarizer<br>
# binarizer = Binarizer(threshold=0.0).fit(X)<br>
# binaryX = binarizer.transform(X)<br>
# #summarize transformed data<br>
# numpy.set_printoptions(precision=3)<br>
# print(binaryX[0:5,:])<br>

# %% [markdown]
# <a id='#Feature6'></a>

# %% [markdown]
# ### Feature Engineering : Scale
#
# [[ go back to the top ]](#Table-of-contents)
# When your data is comprised of attributes with varying scales, many machine learning algorithms can benefit from rescaling the attributes to all have the same scale.
# Often this is referred to as normalization and attributes are often rescaled into the range between 0 and 1. This is useful for optimization algorithms in used in the core of machine learning algorithms like gradient descent. It is also useful for algorithms that weight inputs like regression and neural networks and algorithms that use distance measures like K-Nearest Neighbors.<br>
# <br>
# #Rescale data (between 0 and 1)<br>
# from sklearn.preprocessing import MinMaxScaler<br>
# array = data.values<br>
# #separate array into input and output components<br>
# X = array[:,0:8]<br>
# Y = array[:,8]<br>
# scaler = MinMaxScaler(feature_range=(0, 1))<br>
# rescaledX = scaler.fit_transform(X)<br>
# #summarize transformed data<br>
# numpy.set_printoptions(precision=3)<br>
# print(rescaledX[0:5,:])<br>

# %% [markdown]
# <a id='#Feature7'></a>

# %% [markdown]
# ### Feature Engineering : Bin
#
# [[ go back to the top ]](#Table-of-contents)
# Binning is a term used to indicate creating quantiles. This allows you to create an ordered, categorical variable out of a range of values. In algorithms that respond effectively use categorical information this can be useful (probably not so great for linear regression).<br>
# <br>
# #Divide all fares into quartiles<br>
# df['Fare_bin'] = pd.qcut(df['Fare'], 4)<br>
# #qcut() creates a new variable that identifies the quartile range, but we can't use the string so either<br>
# #factorize or create dummies from the result<br>
# df['Fare_bin_id'] = pd.factorize(df['Fare_bin']) <br>
# df = pd.concat([df, pd.get_dummies(df['Fare_bin']).rename(columns=lambda x: 'Fare_' + str(x))], axis=1)<br>

# %% [markdown]
# <a id='#Feature8'></a>

# %% [markdown]
# ### Feature Engineering : Correlation and Interaction variables
#
# [[ go back to the top ]](#Table-of-contents)
# Interaction variables capture effects of the relationship between variables. They are constructed by performing mathematical operations on sets of features. The simple approach that we use in this example is to perform basic operators (add, subtract, multiply, divide) on each pair of numerical features. We could also get much more involved and include more than 2 features in each calculation, and/or use other operators (sqrt, ln, trig functions, etc).<br>
# This process of automated feature generation can quickly produce a LOT of new variables. In our case, we use 9 features to generate 176 new interaction features. In a larger data set with dozens or hundreds of numeric features, this process can generate an overwhelming number of new interactions. Some types of models are really good at handling a very large number of features (I’ve heard of thousands to millions), which would be necessary in such a case.
# It’s very likely that some of the new interaction variables are going to be highly correlated with one of their original variables, or with other interactions, which can be a problem especially for linear models. Highly correlated variables can cause an issue called “multicollinearity”. There is a lot of information out there about how to identify, deal with, and safely ignore multicollinearity in a data set so I’ll avoid an explanation here, but I’ve included some great links at the bottom of this post if you’re interested.<br>

# %% [markdown]
# <a id='#Feature9'></a>

# %% [markdown]
# ### Feature Engineering : Testing
#
# [[ go back to the top ]](#Table-of-contents)
# we can similarly set up unit tests to verify our expectations about a data set.
# We can quickly test our data using assert statements: We assert that something must be true, and if it is, then nothing happens and the notebook continues running. However, if our assertion is wrong, then the notebook stops running and brings it to our attention. For example:.<br>
# #We know that we should only have three classes
# assert len(iris_data_clean['class'].unique()) == 3
# #We know that sepal lengths for 'Iris-versicolor' should never be below 2.5 cm
# assert iris_data_clean.loc[iris_data_clean['class'] == 'Iris-versicolor', 'sepal_length_cm'].min() >= 2.5
# #We know that our data set should have no missing measurements
# assert len(iris_data_clean.loc[(iris_data_clean['sepal_length_cm'].isnull()) |
#                                (iris_data_clean['sepal_width_cm'].isnull()) |
#                                (iris_data_clean['petal_length_cm'].isnull()) |
#                                (iris_data_clean['petal_width_cm'].isnull())]) == 0

# %% [markdown]
# <a id='#Feature10'></a>

# %% [markdown]
# ### Feature Engineering : Repeat EDA
#
# [[ go back to the top ]](#Table-of-contents)

# %% [markdown]
# <a id='#Feature11'></a>

# %% [markdown]
# ### Feature Engineering : Takeaway
#
# [[ go back to the top ]](#Table-of-contents)

# %% [markdown]
# <a id='#Feature-Selection'></a>

# %% [markdown]
# # Feature Selection
#
# [[ go back to the top ]](#Table-of-contents)
#
# The data features that you use to train your machine learning models have a huge influence on the performance you can achieve.<br>
# Irrelevant or partially relevant features can negatively impact model performance.<br>
# There are automatic feature selection techniques that you can use to prepare your machine learning data in python with scikit-learn.<br>
# Feature selection is a process where you automatically select those features in your data that contribute most to the prediction variable or output in which you are interested. Having irrelevant features in your data can decrease the accuracy of many models, especially linear algorithms like linear and logistic regression.<br>
# Three benefits of performing feature selection before modeling your data are:<br>
# Reduces Overfitting: Less redundant data means less opportunity to make decisions based on noise.<br>
# Improves Accuracy: Less misleading data means modeling accuracy improves.<br>
# Reduces Training Time: Less data means that algorithms train faster.<br>
# <br>
# ##### 1. Univariate Selection<br>
# Statistical tests can be used to select those features that have the strongest relationship with the output variable.
# The scikit-learn library provides the SelectKBest class that can be used with a suite of different statistical tests to select a specific number of features.<br>
# The example below uses the chi squared (chi^2) statistical test for non-negative features to select 4 of the best features from the Pima Indians onset of diabetes dataset.<br>
# <br>
# #Feature Extraction with Univariate Statistical Tests (Chi-squared for classification)<br>
# from sklearn.feature_selection import SelectKBest<br>
# from sklearn.feature_selection import chi2<br>
# array = data.values<br>
# X = array[:,0:8]<br>
# Y = array[:,8]<br>
# #feature extraction<br>
# test = SelectKBest(score_func=chi2, k=4)<br>
# fit = test.fit(X, Y)<br>
# #summarize scores<br>
# numpy.set_printoptions(precision=3)<br>
# print(fit.scores_)<br>
# features = fit.transform(X)<br>
# #summarize selected features<br>
# print(features[0:5,:])<br>
# <br>
# [  111.52   1411.887    17.605    53.108  2175.565   127.669     5.393<br>
#    181.304]<br>
# [[ 148.     0.    33.6   50. ]<br>
#  [  85.     0.    26.6   31. ]<br>
#  [ 183.     0.    23.3   32. ]<br>
#  [  89.    94.    28.1   21. ]<br>
#  [ 137.   168.    43.1   33. ]]<br>
# <br>
# You can see the scores for each attribute and the 4 attributes chosen (those with the highest scores): plas, test, mass and age.
# <br>
# ##### 2. Recursive Feature Elimination
# The Recursive Feature Elimination (or RFE) works by recursively removing attributes and building a model on those attributes that remain.<br>
# It uses the model accuracy to identify which attributes (and combination of attributes) contribute the most to predicting the target attribute.<br>
# You can learn more about the RFE class in the scikit-learn documentation.<br>
# The example below uses RFE with the logistic regression algorithm to select the top 3 features. The choice of algorithm does not matter too much as long as it is skillful and consistent.<br>
# <br>
# from sklearn.feature_selection import RFE<br>
# from sklearn.linear_model import LogisticRegression<br>
# array = data.values<br>
# X = array[:,0:8]<br>
# Y = array[:,8]<br>
# model = LogisticRegression()<br>
# rfe = RFE(model, 3)<br>
# fit = rfe.fit(X, Y)<br>
# print("Num Features: ",fit.n_features_) <br>
# print("Selected Features: ",fit.support_)<br>
# print("Feature Ranking: ",fit.ranking_)<br>
# <br>
# Num Features:  3 <br>
# Selected Features:  [ True False False False False  True  True False]<br>
# Feature Ranking:  [1 2 3 5 6 1 1 4]<br>
# <br>
# You can see that RFE chose the the top 3 features as preg, mass and pedi.<br>
# These are marked True in the support array and marked with a choice “1” in the ranking array.<br>
# <br>
# ##### 3. Principal Component Analysis
# Principal Component Analysis (or PCA) uses linear algebra to transform the dataset into a compressed form.<br>
# Generally this is called a data reduction technique. A property of PCA is that you can choose the number of dimensions or principal component in the transformed result.<br>
# In the example below, we use PCA and select 3 principal components.
# <br>
# from sklearn.decomposition import PCA<br>
# X = array[:,0:8]<br>
# Y = array[:,8]<br>
# #feature extraction<br>
# pca = PCA(n_components=3)<br>
# fit = pca.fit(X)<br>
# #summarize components<br>
# print("Explained Variance: ",fit.explained_variance_ratio_)<br>
# print(fit.components_)<br>
# <br>
# Explained Variance:  [ 0.889  0.062  0.026]<br>
# [[ -2.022e-03   9.781e-02   1.609e-02   6.076e-02   9.931e-01   1.401e-02<br>
#     5.372e-04  -3.565e-03] <br>
#  [  2.265e-02   9.722e-01   1.419e-01  -5.786e-02  -9.463e-02   4.697e-02<br>
#     8.168e-04   1.402e-01]<br>
#  [ -2.246e-02   1.434e-01  -9.225e-01  -3.070e-01   2.098e-02  -1.324e-01<br>
#    -6.400e-04  -1.255e-01]]<br>
# <br>
# You can see that the transformed dataset (3 principal components) bare little resemblance to the source data.<br>
# <br>
# #### 4. Feature Importance
# Bagged decision trees like Random Forest and Extra Trees can be used to estimate the importance of features.<br>
# <br>
# from sklearn.ensemble import ExtraTreesClassifier<br>
# #feature extraction<br>
# model = ExtraTreesClassifier()<br>
# model.fit(X, Y)<br>
# print(model.feature_importances_)<br>
# <br>
# [ 0.119  0.226  0.093  0.081  0.073  0.143  0.119  0.146]<br>
# <br>
# You can see that we are given an importance score for each attribute where the larger score the more important the attribute. The scores suggest at the importance of plas, age and mass.-+ <br>
# USEFUL CODE :
# <br>
# features_list = input_df.columns.values[1::]<br>
# X = input_df.values[:, 1::]<br>
# y = input_df.values[:, 0]<br>
#  <br>
# #Fit a random forest with (mostly) default parameters to determine feature importance<br>
# forest = RandomForestClassifier(oob_score=True, n_estimators=10000)<br>
# forest.fit(X, y)<br>
# feature_importance = forest.feature_importances_ <br>
#  <br>
# #make importances relative to max importance<br>
# feature_importance = 100.0 * (feature_importance / feature_importance.max())<br>
#  <br>
# #A threshold below which to drop features from the final data set. Specifically, this number represents<br>
# #the percentage of the most important feature's importance value<br>
# fi_threshold = 15<br>
#  <br>
# #Get the indexes of all features over the importance threshold<br>
# important_idx = np.where(feature_importance > fi_threshold)[0]<br>
#  <br>
# #Create a list of all the feature names above the importance threshold<br>
# important_features = features_list[important_idx]<br>
# print "n", important_features.shape[0], "Important features(>", fi_threshold, "% of max importance):n",<br>
#         important_features<br>
# <br>
# #Get the sorted indexes of important features<br>
# sorted_idx = np.argsort(feature_importance[important_idx])[::-1]<br>
# print "nFeatures sorted by importance (DESC):n", important_features[sorted_idx]<br>
#  <br>
# #Adapted from http://scikit-learn.org/stable/auto_examples/ensemble/plot_gradient_boosting_regression.html <br>
# pos = np.arange(sorted_idx.shape[0]) + .5 <br>
# plt.subplot(1, 2, 2) <br>
# plt.barh(pos, feature_importance[important_idx][sorted_idx[::-1]], align='center') <br>
# plt.yticks(pos, important_features[sorted_idx[::-1]]) <br>
# plt.xlabel('Relative Importance') <br>
# plt.title('Variable Importance') <br>
# plt.draw()<br>
# plt.show()<br>
#  <br>
# #Remove non-important features from the feature set, and reorder those remaining<br>
# X = X[:, important_idx][:, sorted_idx]<br>

# %% [markdown]
# <a id='#Resampling'></a>

# %% [markdown]
# # Algorithm Evaluation With Resampling Methods
#
# [[ go back to the top ]](#Table-of-contents)
# ### Split into Train and Test Sets
# The simplest method that we can use to evaluate the performance of a machine learning algorithm is to use different training and testing datasets.<br>
# We can take our original dataset, split it into two parts. Train the algorithm on the first part, make predictions on the second part and evaluate the predictions against the expected results.<br>
# The size of the split can depend on the size and specifics of your dataset, although it is common to use 67% of the data for training and the remaining 33% for testing.<br>
# This algorithm evaluation technique is very fast. It is ideal for large datasets (millions of records) where there is strong evidence that both splits of the data are representative of the underlying problem. Because of the speed, it is useful to use this approach when the algorithm you are investigating is slow to train.<br>
# A downside of this technique is that it can have a high variance. This means that differences in the training and test dataset can result in meaningful differences in the estimate of accuracy.<br>
# In the example below we split the data Pima Indians dataset into 67%/33% split for training and test and evaluate the accuracy of a Logistic Regression model.<br>
# <br>
# #Evaluate using a train and a test set<br>
# import sklearn <br>
# from sklearn import cross_validation <br>
# from sklearn.linear_model import LogisticRegression <br>
# test_size = 0.33<br>
# seed = 7<br>
# X_train, X_test, Y_train, Y_test = cross_validation.train_test_split(X, Y, test_size=test_size, random_state=seed)<br>
# model = LogisticRegression()<br>
# model.fit(X_train, Y_train)<br>
# result = model.score(X_test, Y_test)<br>
# print("Accuracy: {}".format(result*100.0))<br>
# We can see that the estimated accuracy for the model was approximately 75%. Note that in addition to specifying the size of the split, we also specify the random seed. Because the split of the data is random, we want to ensure that the results are reproducible. By specifying the random seed we ensure that we get the same random numbers each time we run the code.<br>
# This is important if we want to compare this result to the estimated accuracy of another machine learning algorithm or the same algorithm with a different configuration. To ensure the comparison was apples-for-apples, we must ensure that they are trained and tested on the same data.<br>
# ### K-fold Cross Validation
# Cross validation is an approach that you can use to estimate the performance of a machine learning algorithm with less variance than a single train-test set split.<br>
# It works by splitting the dataset into k-parts (e.g. k=5 or k=10). Each split of the data is called a fold. The algorithm is trained on k-1 folds with one held back and tested on the held back fold. This is repeated so that each fold of the dataset is given a chance to be the held back test set.<br>
# After running cross validation you end up with k different performance scores that you can summarize using a mean and a standard deviation.<br>
# The result is a more reliable estimate of the performance of the algorithm on new data given your test data. It is more accurate because the algorithm is trained and evaluated multiple times on different data.<br>
# The choice of k must allow the size of each test partition to be large enough to be a reasonable sample of the problem, whilst allowing enough repetitions of the train-test evaluation of the algorithm to provide a fair estimate of the algorithms performance on unseen data. For modest sized datasets in the thousands or tens of thousands of records, k values of 3, 5 and 10 are common.<br>
# 10-fold cross validation.<br>
# num_instances = len(X)<br>
# seed = 7v
# kfold = cross_validation.KFold(n=num_instances, n_folds=10, random_state=seed)<br>
# model = LogisticRegression()<br>
# results = cross_validation.cross_val_score(model, X, Y, cv=kfold)<br>
# print("Accuracy: ",results.mean()*100.0, results.std()*100.0)<br>
# <br>
# You can see that we report both the mean and the standard deviation of the performance measure. When summarizing performance measures, it is a good practice to summarize the distribution of the measures, in this case assuming a Gaussian distribution of performance (a very reasonable assumption) and recording the mean and standard deviation.<br>
# ### Leave One Out Cross Validation
# You can configure cross validation so that the size of the fold is 1 (k is set to the number of observations in your dataset). This variation of cross validation is called leave-one-out cross validation.
# The result is a large number of performance measures that can be summarized in an effort to give a more reasonable estimate of the accuracy of your model on unseen data. A downside is that it can be a computationally more expensive procedure than k-fold cross validation.<br>
# num_folds = 10<br>
# num_instances = len(X)<br>
# loocv = cross_validation.LeaveOneOut(num_instances)<br>
# model = LogisticRegression()<br>
# results = cross_validation.cross_val_score(model, X, Y, cv=loocv)<br>
# print("Accuracy: ",results.mean()*100.0, results.std()*100.0)<br>
# You can see in the standard deviation that the score has more variance than the k-fold cross validation results described above.<br>
# ### Repeated Random Test-Train Splits
# Another variation on k-fold cross validation is to create a random split of the data like the train/test split described above, but repeat the process of splitting and evaluation of the algorithm multiple times, like cross validation.<br>
# This has the speed of using a train/test split and the reduction in variance in the estimated performance of k-fold cross validation. You can also repeat the process many more times as need. A down side is that repetitions may include much of the same data in the train or the test split from run to run, introducing redundancy into the evaluation.<br>
# The example below splits the data into a 67%/33% train/test split and repeats the process 10 times.<br>
# kfold = cross_validation.ShuffleSplit(num_instances, test_size=test_size, random_state=seed)<br>
# model = LogisticRegression()<br>
# results = cross_validation.cross_val_score(model, X, Y, cv=kfold)<br>
# print("Accuracy: ",results.mean()*100.0, results.std()*100.0)<br>
# We can see that the distribution of the performance measure is on par with k-fold cross validation above.<br>
# ### Stratified k-fold cross-validation
# Stratified *k*-fold keeps the class proportions the same across all of the folds, which is vital for maintaining a representative subset of our data set. (e.g., so we don't have 100% `Iris setosa` entries in one of the folds.<br>
# <br>
# import numpy as np<br>
# from sklearn.cross_validation import StratifiedKFold<br>
#
# def plot_cv(cv, n_samples):<br>
#     masks = []<br>
#     for train, test in cv: <br>
#         mask = np.zeros(n_samples, dtype=bool)<br>
#         mask[test] = 1<br>
#         masks.append(mask)<br>
#     <br>
#     plt.figure(figsize=(15, 15))
#     plt.imshow(masks, interpolation='none')
#     plt.ylabel('Fold')
#     plt.xlabel('Row #')
#
# plot_cv(StratifiedKFold(all_classes, n_folds=10), len(all_classes))<br>
# <br>
# ##### What Techniques to Use When
# Generally k-fold cross validation is the gold-standard for evaluating the performance of a machine learning algorithm on unseen data with k set to 3, 5, or 10.<br>
# Using a train/test split is good for speed when using a slow algorithm and produces performance estimates with lower bias when using large datasets.<br>
# Techniques like leave-one-out cross validation and repeated random splits can be useful intermediates when trying to balance variance in the estimated performance, model training speed and dataset size.<br>
# The best advice is to experiment and find a technique for your problem that is fast and produces reasonable estimates of performance that you can use to make decisions. If in doubt, use 10-fold cross validation.<br>

# %% [markdown]
# <a id='#metrics'></a>

# %% [markdown]
# # Performance metrics
#
# [[ go back to the top ]](#Table-of-contents)
# ### Classification Metrics
# Classification problems are perhaps the most common type of machine learning problem and as such there are a myriad of metrics that can be used to evaluate predictions for these problems.
# In this section we will review how to use the following metrics:
# ###### Classification Accuracy.
# ###### Logarithmic Loss.
# ###### Area Under ROC Curve.
# ###### Confusion Matrix.
# ###### Classification Report.
# #### 1. Classification Accuracy
# Classification accuracy is the number of correct predictions made as a ratio of all predictions made.<br>
# This is the most common evaluation metric for classification problems, it is also the most misused. It is really only suitable when there are an equal number of observations in each class (which is rarely the case) and that all predictions and prediction errors are equally important, which is often not the case.<br>
# scoring = 'accuracy'
# kfold = cross_validation.KFold(n=num_instances, n_folds=10, random_state=seed)
# model = LogisticRegression()
# results = cross_validation.cross_val_score(model, X, Y, cv=kfold,scoring=scoring)
# print("Accuracy: ",results.mean()*100.0, results.std()*100.0)
#
# #### 2. Logarithmic Loss
# Logarithmic loss (or logloss) is a performance metric for evaluating the predictions of probabilities of membership to a given class.<br>
# The scalar probability between 0 and 1 can be seen as a measure of confidence for a prediction by an algorithm. Predictions that are correct or incorrect are rewarded or punished proportionally to the confidence of the prediction.<br>
# scoring = 'log_loss'
# results = cross_validation.cross_val_score(model, X, Y, cv=kfold,scoring=scoring)
# print("Accuracy: ",results.mean(), results.std())
#
# Smaller logloss is better with 0 representing a perfect logloss. As mentioned above, the measure is inverted to be ascending when using the cross_val_score() function.
#
# ##### 3. Area Under ROC Curve
# Area under ROC Curve (or AUC for short) is a performance metric for binary classification problems.
# The AUC represents a model’s ability to discriminate between positive and negative classes. An area of 1.0 represents a model that made all predictions perfectly. An area of 0.5 represents a model as good as random.<br>
# ROC can be broken down into sensitivity and specificity. A binary classification problem is really a trade-off between sensitivity and specificity.<br>
# Sensitivity is the true positive rate also called the recall. It is the number instances from the positive (first) class that actually predicted correctly.<br>
# Specificity is also called the true negative rate. Is the number of instances from the negative class (second) class that were actually predicted correctly.<br>
# An ROC curve is the most commonly used way to visualize the performance of a binary classifier, and AUC is (arguably) the best way to summarize its performance in a single number.<br>
# scoring = 'roc_auc'
# results = cross_validation.cross_val_score(model, X, Y, cv=kfold,scoring=scoring)
# print("Accuracy: ",results.mean(), results.std())
# If the AUC is relatively close to 1 and greater than 0.5, suggesting some skill in the predictions
#
# #### 4. Confusion Matrix
# The confusion matrix is a handy presentation of the accuracy of a model with two or more classes.
# The table presents predictions on the x-axis and accuracy outcomes on the y-axis. The cells of the table are the number of predictions made by a machine learning algorithm.<br>
# For example, a machine learning algorithm can predict 0 or 1 and each prediction may actually have been a 0 or 1. Predictions for 0 that were actually 0 appear in the cell for prediction=0 and actual=0, whereas predictions for 0 that were actually 1 appear in the cell for prediction = 0 and actual=1. And so on.<br>
# from sklearn.metrics import confusion_matrix
# test_size = 0.33
# seed = 7
# X_train, X_test, Y_train, Y_test = cross_validation.train_test_split(X, Y, test_size=test_size, random_state=seed)
# model = LogisticRegression()
# model.fit(X_train, Y_train)
# predicted = model.predict(X_test)
# matrix = confusion_matrix(Y_test, predicted)
# print(matrix)
#
# #### 5. Classification Report
# Scikit-learn does provide a convenience report when working on classification problems to give you a quick idea of the accuracy of a model using a number of measures.<br>
# The classification_report() function displays the precision, recall, f1-score and support for each class.
# from sklearn.metrics import classification_report
# 0report = classification_report(Y_test, predicted)
# print(report)
# <b>Mean F Score</b><br>
# The F1 score, commonly used in information retrieval, measures accuracy using the statistics precision p and recall r. Precision is the ratio of true positives (tp) to all predicted positives (tp + fp). Recall is the ratio of true positives to all actual positives (tp + fn). The F1 score is given by <br>
# F1= 2*(pr)/(p+r) <br>
#   where  p= (tp)/(tp + fp) , r= (tp)/(tp + fn)<br>
# <br>
# The F1 metric weights recall and precision equally, and a good retrieval algorithm will maximize both precision and recall simultaneously. Thus moderately good performance on both will be favored over extremely good performance on one and poor performance on the other.
# For MeanF1Score calculate F1 metrics for each label, and find their average, weighted by support (the number of true instances for each label).

# %% [markdown]
# <a id='#Spot-check'></a>

# %% [markdown]
# # Spot-check Algorithms
#
# [[ go back to the top ]](#Table-of-contents)
# Spot-checking is a way of discovering which algorithms perform well on your machine learning problem.<br>
# You cannot know which algorithms are best suited to your problem before hand. You must trial a number of methods and focus attention on those that prove themselves the most promising.<br>
# You can guess at what algorithms might do well on your dataset, and this can be a good starting point.<br>
#
# Try a mixture of algorithm representations (e.g. instances and trees).<br>
# Try a mixture of learning algorithms (e.g. different algorithms for learning the same type of representation).<br>
# Try a mixture of modeling types (e.g. linear and nonlinear functions or parametric and nonparametric).<br>
# Let’s get specific. <br>
# Algorithms Overview<br>
# We are going to take a look at 6 classification algorithms to spot check on your dataset.<br>
# ##### 2 Linear Machine Learning Algorithms:
# Logistic Regression <br>
# Linear Discriminant Analysis <br>
# ###### 4 Nonlinear Machine Learning Algorithms:
# K-Nearest Neighbors<br>
# Naive Bayes<br>
# Classification and Regression Trees<br>
# Support Vector Machines<br>
# <br>
# kfold = cross_validation.KFold(n=num_instances, n_folds=10, random_state=seed)<br>
# model = LogisticRegression()<br>
# results = cross_validation.cross_val_score(model, X, Y, cv=kfold)<br>
# print("Accuracy: ",results.mean()*100.0, results.std()*100.0)<br>

# %% [markdown]
# <a id='#Spot-check'></a>

# %% [markdown]
# # Model Comparison and Selection
#
# [[ go back to the top ]](#Table-of-contents)
# <br>
# #prepare models<br>
# models = []<br>
# models.append(('LR', LogisticRegression()))<br>
# models.append(('LDA', LinearDiscriminantAnalysis()))<br>
# models.append(('KNN', KNeighborsClassifier()))<br>
# models.append(('CART', DecisionTreeClassifier()))<br>
# models.append(('NB', GaussianNB()))<br>
# models.append(('SVM', SVC()))<br>
# #evaluate each model in turn<br>
# results = []<br>
# names = []<br>
# scoring = 'accuracy' <br>
# for name, model in models:<br>
#     kfold = cross_validation.KFold(n=num_instances, n_folds=10, random_state=seed)<br>
#     cv_results = cross_validation.cross_val_score(model, X, Y, cv=kfold, scoring=scoring)<br>
#     results.append(cv_results)<br>
#     names.append(name)<br>
#     print("{} : {} , {}".format(name, cv_results.mean(), cv_results.std()))<br>
# #boxplot algorithm comparison<br>
# fig = plt.figure()<br>
# fig.suptitle('Algorithm Comparison')<br>
# ax = fig.add_subplot(111)<br>
# plt.boxplot(results)<br>
# ax.set_xticklabels(names)<br>
# plt.show()<br>
#
# """
#
# ========================
#
# Plotting Learning Curves
#
# ========================
#
#
#
# On the left side the learning curve of a naive Bayes classifier is shown for
#
# the digits dataset. Note that the training score and the cross-validation score
#
# are both not very good at the end. However, the shape of the curve can be found
#
# in more complex datasets very often: the training score is very high at the
#
# beginning and decreases and the cross-validation score is very low at the
#
# beginning and increases. On the right side we see the learning curve of an SVM
#
# with RBF kernel. We can see clearly that the training score is still around
#
# the maximum and the validation score could be increased with more training
#
# samples.
#
# """
#
# print(__doc__)
#
#
#
# import numpy as np
#
# import matplotlib.pyplot as plt
#
# from sklearn.naive_bayes import GaussianNB
#
# from sklearn.svm import SVC
#
# from sklearn.datasets import load_digits
#
# from sklearn.model_selection import learning_curve
#
# from sklearn.model_selection import ShuffleSplit
#
#
#
#
#
# def plot_learning_curve(estimator, title, X, y, ylim=None, cv=None,
#
#                         n_jobs=1, train_sizes=np.linspace(.1, 1.0, 5)):
#
#     """
#
#     Generate a simple plot of the test and training learning curve.
#
#
#
#     Parameters
#
#     ----------
#
#     estimator : object type that implements the "fit" and "predict" methods
#
#         An object of that type which is cloned for each validation.
#
#
#
#     title : string
#
#         Title for the chart.
#
#
#
#     X : array-like, shape (n_samples, n_features)
#
#         Training vector, where n_samples is the number of samples and
#
#         n_features is the number of features.
#
#
#
#     y : array-like, shape (n_samples) or (n_samples, n_features), optional
#
#         Target relative to X for classification or regression;
#
#         None for unsupervised learning.
#
#
#
#     ylim : tuple, shape (ymin, ymax), optional
#
#         Defines minimum and maximum yvalues plotted.
#
#
#
#     cv : int, cross-validation generator or an iterable, optional
#
#         Determines the cross-validation splitting strategy.
#
#         Possible inputs for cv are:
#
#           - None, to use the default 3-fold cross-validation,
#
#           - integer, to specify the number of folds.
#
#           - An object to be used as a cross-validation generator.
#
#           - An iterable yielding train/test splits.
#
#
#
#         For integer/None inputs, if ``y`` is binary or multiclass,
#
#         :class:`StratifiedKFold` used. If the estimator is not a classifier
#
#         or if ``y`` is neither binary nor multiclass, :class:`KFold` is used.
#
#
#
#         Refer :ref:`User Guide <cross_validation>` for the various
#
#         cross-validators that can be used here.
#
#
#
#     n_jobs : integer, optional
#
#         Number of jobs to run in parallel (default 1).
#
#     """
#
#     plt.figure()
#
#     plt.title(title)
#
#     if ylim is not None:
#
#         plt.ylim(*ylim)
#
#     plt.xlabel("Training examples")
#
#     plt.ylabel("Score")
#
#     train_sizes, train_scores, test_scores = learning_curve(
#
#         estimator, X, y, cv=cv, n_jobs=n_jobs, train_sizes=train_sizes)
#
#     train_scores_mean = np.mean(train_scores, axis=1)
#
#     train_scores_std = np.std(train_scores, axis=1)
#
#     test_scores_mean = np.mean(test_scores, axis=1)
#
#     test_scores_std = np.std(test_scores, axis=1)
#
#     plt.grid()
#
#
#
#     plt.fill_between(train_sizes, train_scores_mean - train_scores_std,
#
#                      train_scores_mean + train_scores_std, alpha=0.1,
#
#                      color="r")
#
#     plt.fill_between(train_sizes, test_scores_mean - test_scores_std,
#
#                      test_scores_mean + test_scores_std, alpha=0.1, color="g")
#
#     plt.plot(train_sizes, train_scores_mean, 'o-', color="r",
#
#              label="Training score")
#
#     plt.plot(train_sizes, test_scores_mean, 'o-', color="g",
#
#              label="Cross-validation score")
#
#
#
#     plt.legend(loc="best")
#
#     return plt
#
#
#
#
#
# digits = load_digits()
#
# X, y = digits.data, digits.target
#
#
#
#
#
# title = "Learning Curves (Naive Bayes)"
#
# #Cross validation with 100 iterations to get smoother mean test and train
#
# #score curves, each time with 20% data randomly selected as a validation set.
#
# cv = ShuffleSplit(n_splits=100, test_size=0.2, random_state=0)
#
#
#
# estimator = GaussianNB()
#
# plot_learning_curve(estimator, title, X, y, ylim=(0.7, 1.01), cv=cv, n_jobs=4)
#
#
#
# title = "Learning Curves (SVM, RBF kernel, $\gamma=0.001$)"
#
# #SVC is more expensive so we do a lower number of CV iterations:
#
# cv = ShuffleSplit(n_splits=10, test_size=0.2, random_state=0)
#
# estimator = SVC(gamma=0.001)
#
# plot_learning_curve(estimator, title, X, y, (0.7, 1.01), cv=cv, n_jobs=4)
#
#
#
# plt.show()

# %%
"""

========================

Plotting Learning Curves

========================



On the left side the learning curve of a naive Bayes classifier is shown for

the digits dataset. Note that the training score and the cross-validation score

are both not very good at the end. However, the shape of the curve can be found

in more complex datasets very often: the training score is very high at the

beginning and decreases and the cross-validation score is very low at the

beginning and increases. On the right side we see the learning curve of an SVM

with RBF kernel. We can see clearly that the training score is still around

the maximum and the validation score could be increased with more training

samples.

"""

print(__doc__)



import numpy as np

import matplotlib.pyplot as plt

from sklearn.naive_bayes import GaussianNB

from sklearn.svm import SVC

from sklearn.datasets import load_digits

from sklearn.model_selection import learning_curve

from sklearn.model_selection import ShuffleSplit





def plot_learning_curve(estimator, title, X, y, ylim=None, cv=None,

                        n_jobs=1, train_sizes=np.linspace(.1, 1.0, 5)):

    """

    Generate a simple plot of the test and training learning curve.



    Parameters

    ----------

    estimator : object type that implements the "fit" and "predict" methods

        An object of that type which is cloned for each validation.



    title : string

        Title for the chart.



    X : array-like, shape (n_samples, n_features)

        Training vector, where n_samples is the number of samples and

        n_features is the number of features.



    y : array-like, shape (n_samples) or (n_samples, n_features), optional

        Target relative to X for classification or regression;

        None for unsupervised learning.



    ylim : tuple, shape (ymin, ymax), optional

        Defines minimum and maximum yvalues plotted.



    cv : int, cross-validation generator or an iterable, optional

        Determines the cross-validation splitting strategy.

        Possible inputs for cv are:

          - None, to use the default 3-fold cross-validation,

          - integer, to specify the number of folds.

          - An object to be used as a cross-validation generator.

          - An iterable yielding train/test splits.



        For integer/None inputs, if ``y`` is binary or multiclass,

        :class:`StratifiedKFold` used. If the estimator is not a classifier

        or if ``y`` is neither binary nor multiclass, :class:`KFold` is used.



        Refer :ref:`User Guide <cross_validation>` for the various

        cross-validators that can be used here.



    n_jobs : integer, optional

        Number of jobs to run in parallel (default 1).

    """

    plt.figure()

    plt.title(title)

    if ylim is not None:

        plt.ylim(*ylim)

    plt.xlabel("Training examples")

    plt.ylabel("Score")

    train_sizes, train_scores, test_scores = learning_curve(

        estimator, X, y, cv=cv, n_jobs=n_jobs, train_sizes=train_sizes)

    train_scores_mean = np.mean(train_scores, axis=1)

    train_scores_std = np.std(train_scores, axis=1)

    test_scores_mean = np.mean(test_scores, axis=1)

    test_scores_std = np.std(test_scores, axis=1)

    plt.grid()



    plt.fill_between(train_sizes, train_scores_mean - train_scores_std,

                     train_scores_mean + train_scores_std, alpha=0.1,

                     color="r")

    plt.fill_between(train_sizes, test_scores_mean - test_scores_std,

                     test_scores_mean + test_scores_std, alpha=0.1, color="g")

    plt.plot(train_sizes, train_scores_mean, 'o-', color="r",

             label="Training score")

    plt.plot(train_sizes, test_scores_mean, 'o-', color="g",

             label="Cross-validation score")



    plt.legend(loc="best")

    return plt





digits = load_digits()

X, y = digits.data, digits.target





title = "Learning Curves (Naive Bayes)"

# Cross validation with 100 iterations to get smoother mean test and train

# score curves, each time with 20% data randomly selected as a validation set.

cv = ShuffleSplit(n_splits=100, test_size=0.2, random_state=0)



estimator = GaussianNB()

plot_learning_curve(estimator, title, X, y, ylim=(0.7, 1.01), cv=cv, n_jobs=4)



title = "Learning Curves (SVM, RBF kernel, $\gamma=0.001$)"

# SVC is more expensive so we do a lower number of CV iterations:

cv = ShuffleSplit(n_splits=10, test_size=0.2, random_state=0)

estimator = SVC(gamma=0.001)

plot_learning_curve(estimator, title, X, y, (0.7, 1.01), cv=cv, n_jobs=4)



plt.show()

# %%
## Adapted from http://scikit-learn.org/stable/auto_examples/plot_learning_curve.html
import matplotlib.pyplot as plt
from sklearn.learning_curve import learning_curve

# assume classifier and training data is prepared...

train_sizes, train_scores, test_scores = learning_curve(
        forest, X, y, cv=10, n_jobs=-1, train_sizes=np.linspace(.1, 1., 10), verbose=0)

train_scores_mean = np.mean(train_scores, axis=1)
train_scores_std = np.std(train_scores, axis=1)
test_scores_mean = np.mean(test_scores, axis=1)
test_scores_std = np.std(test_scores, axis=1)

plt.figure()
plt.title("RandomForestClassifier")
plt.legend(loc="best")
plt.xlabel("Training examples")
plt.ylabel("Score")
plt.ylim((0.6, 1.01))
plt.gca().invert_yaxis()
plt.grid()

# Plot the average training and test score lines at each training set size
plt.plot(train_sizes, train_scores_mean, 'o-', color="b", label="Training score")
plt.plot(train_sizes, test_scores_mean, 'o-', color="r", label="Test score")

# Plot the std deviation as a transparent range at each training set size
plt.fill_between(train_sizes, train_scores_mean - train_scores_std, train_scores_mean + train_scores_std, 
                 alpha=0.1, color="b")
plt.fill_between(train_sizes, test_scores_mean - test_scores_std, test_scores_mean + test_scores_std, 
                 alpha=0.1, color="r")

# Draw the plot and reset the y-axis
plt.draw()
plt.show()
plt.gca().invert_yaxis()

# %% [markdown]
# <a id='#Hyperparameters'></a>

# %% [markdown]
# # Hyper-parameter optimisation
#
# [[ go back to the top ]](#Table-of-contents)
# Phrased as a search problem, you can use different search strategies to find a good and robust parameter or set of parameters for an algorithm on a given problem.<br>
# Two simple and easy search strategies are grid search and random search. Scikit-learn provides these two methods for algorithm parameter tuning and examples of each are provided below.<br>
# #### Grid Search Parameter Tuning
# Grid search is an approach to parameter tuning that will methodically build and evaluate a model for each combination of algorithm parameters specified in a grid. This is a one-dimensional grid search.<br>
# <br>
# from sklearn.linear_model import Ridge<br>
# from sklearn.grid_search import GridSearchCV<br>
# #prepare a range of alpha values to test<br>
# alphas = numpy.array([1,0.1,0.01,0.001,0.0001,0])<br>
# #create and fit a ridge regression model, testing each alpha <br>
# model = Ridge()<br>
# grid = GridSearchCV(estimator=model, param_grid=dict(alpha=alphas))<br>
# grid.fit(X,Y)<br>
# print(grid)<br>
# #summarize the results of the grid search<br>
# print(grid.best_score_)<br>
# print(grid.best_estimator_.alpha)<br>
# ##### Random Search Parameter Tuning
# Random search is an approach to parameter tuning that will sample algorithm parameters from a random distribution (i.e. uniform) for a fixed number of iterations. A model is constructed and evaluated for each combination of parameters chosen.<br>
# <br>
# from scipy.stats import uniform as sp_rand<br>
# from sklearn.linear_model import Ridge<br>
# from sklearn.grid_search import RandomizedSearchCV<br>
# #prepare a uniform distribution to sample for the alpha parameter<br>
# param_grid = {'alpha': sp_rand()}<br>
# #create and fit a ridge regression model, testing random alpha values<br>
# model = Ridge()<br>
# rsearch = RandomizedSearchCV(estimator=model, param_distributions=param_grid, n_iter=100) <br>
# rsearch.fit(X,Y) <br>
# print(rsearch) <br>
# #summarize the results of the random parameter search <br>
# print(rsearch.best_score_) <br>
# print(rsearch.best_estimator_.alpha) <br>

# %%
from sklearn.grid_search import GridSearchCV

decision_tree_classifier = DecisionTreeClassifier()

parameter_grid = {'max_depth': [1, 2, 3, 4, 5],
                  'max_features': [1, 2, 3, 4]}

cross_validation = StratifiedKFold(all_classes, n_folds=10)

grid_search = GridSearchCV(decision_tree_classifier,
                           param_grid=parameter_grid,
                           cv=cross_validation)

grid_search.fit(all_inputs, all_classes)
print('Best score: {}'.format(grid_search.best_score_))
print('Best parameters: {}'.format(grid_search.best_params_))

# %%
grid_visualization = []

for grid_pair in grid_search.grid_scores_:
    grid_visualization.append(grid_pair.mean_validation_score)
    
grid_visualization = np.array(grid_visualization)
grid_visualization.shape = (5, 4)
sb.heatmap(grid_visualization, cmap='Blues')
plt.xticks(np.arange(4) + 0.5, grid_search.param_grid['max_features'])
plt.yticks(np.arange(5) + 0.5, grid_search.param_grid['max_depth'][::-1])
plt.xlabel('max_features')
plt.ylabel('max_depth')

# %%
# Utility function to report optimal parameters
# (adapted from http://scikit-learn.org/stable/auto_examples/randomized_search.html)
def report(grid_scores, n_top=5):
    params = None
    top_scores = sorted(grid_scores, key=itemgetter(1), reverse=True)[:n_top]
    for i, score in enumerate(top_scores):
        print("Parameters with rank: {0}".format(i + 1))
        print("Mean validation score: {0:.4f} (std: {1:.4f})".format(
              score.mean_validation_score, np.std(score.cv_validation_scores)))
        print("Parameters: {0}".format(score.parameters))
        print("")
        
        if params == None:
            params = score.parameters
    
    return params

# The most common value for the max number of features to look at in each split is sqrt(# of features)
sqrtfeat = np.sqrt(X.shape[1]) 

# Simple grid test (162 combinations)
grid_test1 = { "n_estimators"      : [1000, 2500, 5000],
               "criterion"         : ["gini", "entropy"],
               "max_features"      : [sqrtfeat-1, sqrtfeat, sqrtfeat+1],
               "max_depth"         : [5, 10, 25],
               "min_samples_split" : [2, 5, 10] }

# Large randomized test using max_depth to control tree size (5000 possible combinations)
random_test1 = { "n_estimators"      : np.rint(np.linspace(X.shape[0]*2, X.shape[0]*4, 5)).astype(int),
                 "criterion"         : ["gini", "entropy"],
                 "max_features"      : np.rint(np.linspace(sqrtfeat/2, sqrtfeat*2, 5)).astype(int),
                 "max_depth"         : np.rint(np.linspace(1, X.shape[1]/2, 10),
                 "min_samples_split" : np.rint(np.linspace(2, X.shape[0]/50, 10)).astype(int) }

# Large randomized test using min_samples_leaf and max_leaf_nodes to control tree size (50k combinations)
random_test2 = { "n_estimators"      : np.rint(np.linspace(X.shape[0]*2, X.shape[0]*4, 5)).astype(int),
                 "criterion"         : ["gini", "entropy"],
                 "max_features"      : np.rint(np.linspace(sqrtfeat/2, sqrtfeat*2, 5)).astype(int),
                 "min_samples_split" : np.rint(np.linspace(2, X.shape[0]/50, 10)).astype(int),
                 "min_samples_leaf"  : np.rint(np.linspace(1, X.shape[0]/200, 10)).astype(int), 
                 "max_leaf_nodes"    : np.rint(np.linspace(10, X.shape[0]/50, 10)).astype(int) }

forest = RandomForestClassifier(oob_score=True)

print "Hyperparameter optimization using GridSearchCV..."
grid_search = GridSearchCV(forest, grid_test1, n_jobs=-1, cv=10)
grid_search.fit(X, y)
best_params_from_grid_search = scorereport.report(grid_search.grid_scores_)

print "Hyperparameter optimization using RandomizedSearchCV with max_depth parameter..."
grid_search = RandomizedSearchCV(forest, random_test1, n_jobs=-1, cv=10, n_iter=100)
grid_search.fit(X, y)
best_params_from_rand_search1 = scorereport.report(grid_search.grid_scores_)

print "...and using RandomizedSearchCV with min_samples_leaf + max_leaf_nodes parameters..."
grid_search = RandomizedSearchCV(forest, random_test2, n_jobs=-1, cv=10, n_iter=500)
grid_search.fit(X, y)
best_params_from_rand_search2 = scorereport.report(grid_search.grid_scores_)

# %% [markdown]
# <a id='#Pipeline'></a>

# %% [markdown]
# # A single Pipeline
#
# [[ go back to the top ]](#Table-of-contents)

# %%
# %matplotlib inline
import pandas as pd
import seaborn as sb
from sklearn.ensemble import RandomForestClassifier
from sklearn.cross_validation import train_test_split
from sklearn.cross_validation import cross_val_score

# We can jump directly to working with the clean data because we saved our cleaned data set
iris_data_clean = pd.read_csv('iris-data-clean.csv')

# Testing our data: Our analysis will stop here if any of these assertions are wrong

# We know that we should only have three classes
assert len(iris_data_clean['class'].unique()) == 3

# We know that sepal lengths for 'Iris-versicolor' should never be below 2.5 cm
assert iris_data_clean.loc[iris_data_clean['class'] == 'Iris-versicolor', 'sepal_length_cm'].min() >= 2.5

# We know that our data set should have no missing measurements
assert len(iris_data_clean.loc[(iris_data_clean['sepal_length_cm'].isnull()) |
                               (iris_data_clean['sepal_width_cm'].isnull()) |
                               (iris_data_clean['petal_length_cm'].isnull()) |
                               (iris_data_clean['petal_width_cm'].isnull())]) == 0

all_inputs = iris_data_clean[['sepal_length_cm', 'sepal_width_cm',
                             'petal_length_cm', 'petal_width_cm']].values

all_classes = iris_data_clean['class'].values

# This is the classifier that came out of Grid Search
random_forest_classifier = RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
                                max_depth=None, max_features=3, max_leaf_nodes=None,
                                min_samples_leaf=1, min_samples_split=2,
                                min_weight_fraction_leaf=0.0, n_estimators=5, n_jobs=1,
                                oob_score=False, random_state=None, verbose=0, warm_start=True)

# All that's left to do now is plot the cross-validation scores
rf_classifier_scores = cross_val_score(random_forest_classifier, all_inputs, all_classes, cv=10)
sb.boxplot(rf_classifier_scores)
sb.stripplot(rf_classifier_scores, jitter=True, color='white')

# ...and show some of the predictions from the classifier
(training_inputs,
 testing_inputs,
 training_classes,
 testing_classes) = train_test_split(all_inputs, all_classes, train_size=0.75)

random_forest_classifier.fit(training_inputs, training_classes)

for input_features, prediction, actual in zip(testing_inputs[:10],
                                              random_forest_classifier.predict(testing_inputs[:10]),
                                              testing_classes[:10]):
    print('{}\t-->\t{}\t(Actual: {})'.format(input_features, prediction, actual))

# %% [markdown]
# <a id='#Pickle'></a>

# %% [markdown]
# # Finalize the model
#
# [[ go back to the top ]](#Table-of-contents)
# ##### Finalize Your Model with pickle
# Pickle is the standard way of serializing objects in Python.
# You can use the pickle operation to serialize your machine learning algorithms and save the serialized format to a file.
# Later you can load this file to deserialize your model and use it to make new predictions.
# <br>
# #Running the example saves the model to finalized_model.sav in your local working directory<br>
# import pickle<br>
# test_size = 0.33<br>
# seed = 7<br>
# X_train, X_test, Y_train, Y_test = cross_validation.train_test_split(X, Y, test_size=test_size, random_state=seed)<br>
# #Fit the model on 33%<br>
# model = LogisticRegression()<br>
# model.fit(X_train, Y_train)<br>
# #save the model to disk<br>
# filename = 'finalized_model.sav'<br>
# pickle.dump(model, open(filename, 'wb'))<br>
# <br>
# #load the model from disk<br>
# loaded_model = pickle.load(open(filename, 'rb'))<br>
# result = loaded_model.score(X_test, Y_test)<br>
# print(result)<br>

# %% [markdown]
# <a id='#time'></a>

# %% [markdown]
# # If I had more time ....
#
# [[ go back to the top ]](#Table-of-contents)

# %% [markdown]
# <a id='#Acknowledgement'></a>

# %% [markdown]
# # Acknowledgements
#
# [[ go back to the top ]](#Table-of-contents)
# <br>
# <br>
# http://www.markhneedham.com/blog/2015/02/15/pythonscikit-learn-calculating-tfidf-on-how-i-met-your-mother-transcripts/<br>
# http://machinelearningmastery.com<br>
# Notebook by [Randal S. Olson](http://www.randalolson.com/)<br>
# http://www.ultravioletanalytics.com<br>
# https://www.analyticsvidhya.com<br>
# https://sebastianraschka.com/<br>
